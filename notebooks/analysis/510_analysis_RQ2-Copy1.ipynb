# %% [markdown]
# # Homegrown vs Foreign
# ### Are homegrown players generally the best in their respective leagues or are they inferior to the foreign players playing in that league? Are these findings portrayed in the FIFA 18’s ratings.

# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline

# %%
RQ2 = pd.read_csv(('../../data/analysis/RQ2.csv'))
RQ2 = RQ2.drop('Unnamed: 0', 1)
RQ2 = RQ2.iloc[1:]

# %%
RQ2
# Out:
#                         Players    Position    Clubs  \
# 1                  Lionel Messi     Forward     BARC
# 2             Cristiano Ronaldo     Forward     MADR
# 3            Zlatan Ibrahimovic     Forward      PSG
# 4                   Luis Suarez     Forward     BARC
# 5                   Luis Suarez     Forward    LPOOL
# 6                Edinson Cavani     Forward     NAPO
# 7                 Gabriel Jesus     Forward     MCFC
# 8            Robert Lewandowski     Forward      BM1
# 9                     Max Kruse  Midfielder      WB1
# 10                Sergio Romero  Goalkeeper     MUFC
# 11              Valentin Rosier    Defender      NaN
# 12           Robert Lewandowski     Forward      BD1
# 13                  Timo Werner     Forward      NaN
# 14              Gonzalo Higuain     Forward     NAPO
# 15                Tobias Sippel  Goalkeeper     MON1
# 16                Sergio Aguero     Forward     MCFC
# 17                  Gareth Bale  Midfielder    SPURS
# 18                  Gareth Bale  Midfielder     MADR
# 19    Pierre Emerick Aubameyang     Forward      BD1
# 20                   Harry Kane     Forward    SPURS
# 21               Edinson Cavani     Forward      PSG
# 22                       Neymar     Forward     BARC
# 23              Bafetimbi Gomis     Forward     OLMA
# 24                Karim Benzema     Forward     MADR
# 25    Pierre Emerick Aubameyang     Forward     ASSE
# 26           Zlatan Ibrahimovic     Forward     MUFC
# 27                Ciro Immobile     Forward     TOCA
# 28              Gonzalo Higuain     Forward     JUVE
# 29              Kevin De Bruyne  Midfielder      VFL
# 30                Ciro Immobile     Forward     LAZI
# ...                         ...         ...      ...
# 4527            Stefanos Kapino  Goalkeeper      NaN
# 4528              Marcelo Silva    Defender      NaN
# 4529            Anthony Mandrea  Goalkeeper     NICE
# 4530          Costel Pantilimon  Goalkeeper      WFC
# 4531             Mateo Pavlovic    Defender      WB1
# 4532          Marc-Oliver Kempf    Defender       EF
# 4533       Odisseas Vlachodimos  Goalkeeper      VFB
# 4534            Massimo Zappino  Goalkeeper      NaN
# 4535                 Brad Smith    Defender      BOU
# 4536          Markus Steinhofer    Defender     BETI
# 4537                 Kevin Diks    Defender     FIOR
# 4538                Bryan Passi    Defender     MHSC
# 4539            Tobias Pachonik    Defender      FCN
# 4540              Salvador Ruiz    Defender      NaN
# 4541           Alberto Brignoli  Goalkeeper      NaN
# 4542               Luis Martins    Defender      NaN
# 4543           Jonas Fohrenbach    Defender      SCF
# 4544                Rodrigo Ely    Defender     MILA
# 4545          Michele Camporese    Defender      NaN
# 4546            Igor Lichnovsky    Defender      NaN
# 4547               Joan Hartock  Goalkeeper      NaN
# 4548         Nathaniel Chalobah    Defender      BUR
# 4549              Oguchi Onyewu    Defender     MALA
# 4550               Daniel Potts    Defender  WESTHAM
# 4551          Luca-Milan Zander    Defender      WB1
# 4552            Raffaele Pucino    Defender      NaN
# 4553              Brandon Mason    Defender      WFC
# 4554            James Tavernier    Defender     NEWU
# 4555              Michael Ciani    Defender     RCDE
# 4556               Morgan Poaty    Defender     MHSC
#
#                         league   age    nationality  overall  \
# 1     Spanish Primera Division  30.0      Argentina     93.0
# 2     Spanish Primera Division  32.0       Portugal     94.0
# 3       English Premier League  35.0         Sweden     88.0
# 4     Spanish Primera Division  30.0        Uruguay     92.0
# 5     Spanish Primera Division  30.0        Uruguay     92.0
# 6               French Ligue 1  30.0        Uruguay     87.0
# 7       English Premier League  20.0         Brazil     81.0
# 8            German Bundesliga  28.0         Poland     91.0
# 9            German Bundesliga  29.0        Germany     82.0
# 10      English Premier League  30.0      Argentina     80.0
# 11              French Ligue 1  20.0         France     66.0
# 12           German Bundesliga  28.0         Poland     91.0
# 13           German Bundesliga  21.0        Germany     82.0
# 14             Italian Serie A  29.0      Argentina     90.0
# 15           German Bundesliga  29.0        Germany     74.0
# 16      English Premier League  29.0      Argentina     89.0
# 17    Spanish Primera Division  27.0          Wales     89.0
# 18    Spanish Primera Division  27.0          Wales     89.0
# 19           German Bundesliga  28.0          Gabon     88.0
# 20      English Premier League  23.0        England     86.0
# 21              French Ligue 1  30.0        Uruguay     87.0
# 22              French Ligue 1  25.0         Brazil     92.0
# 23           Turkish Super Lig  31.0         France     79.0
# 24    Spanish Primera Division  29.0         France     86.0
# 25           German Bundesliga  28.0          Gabon     88.0
# 26      English Premier League  35.0         Sweden     88.0
# 27             Italian Serie A  27.0          Italy     83.0
# 28             Italian Serie A  29.0      Argentina     90.0
# 29      English Premier League  26.0        Belgium     89.0
# 30             Italian Serie A  27.0          Italy     83.0
# ...                        ...   ...            ...      ...
# 4527        Greek Super League  23.0         Greece     77.0
# 4528   USA Major League Soccer  28.0        Uruguay     71.0
# 4529            French Ligue 1  20.0         France     64.0
# 4530  Spanish Primera Division  30.0        Romania     76.0
# 4531            French Ligue 1  27.0        Croatia     71.0
# 4532         German Bundesliga  22.0        Germany     74.0
# 4533        Greek Super League  23.0        Germany     70.0
# 4534           Italian Serie B  36.0         Brazil     66.0
# 4535    English Premier League  23.0      Australia     65.0
# 4536      German 2. Bundesliga  31.0        Germany     70.0
# 4537        Holland Eredivisie  20.0    Netherlands     71.0
# 4538            French Ligue 2  19.0         France     62.0
# 4539           Italian Serie B  22.0        Germany     66.0
# 4540  Spanish Primera Division  22.0          Spain     66.0
# 4541           Italian Serie A  25.0          Italy     70.0
# 4542  Portuguese Primeira Liga  25.0       Portugal     70.0
# 4543            German 3. Liga  21.0        Germany     66.0
# 4544  Spanish Primera Division  23.0         Brazil     74.0
# 4545           Italian Serie B  25.0          Italy     69.0
# 4546           Mexican Liga MX  23.0          Chile     68.0
# 4547            French Ligue 2  30.0         France     66.0
# 4548    English Premier League  22.0        England     75.0
# 4549   USA Major League Soccer  35.0  United States     69.0
# 4550        English League Two  23.0        England     61.0
# 4551      German 2. Bundesliga  21.0        Germany     64.0
# 4552           Italian Serie B  26.0          Italy     70.0
# 4553    English Premier League  19.0        England     66.0
# 4554      Scottish Premiership  25.0        England     71.0
# 4555   USA Major League Soccer  33.0         France     72.0
# 4556            French Ligue 1  19.0         France     63.0
#
#                 Continent Homegrown  Overall Apps  Average Form  \
# 1           South America     False         168.0      8.255952
# 2                  Europe     False         164.0      7.926829
# 3                  Europe     False         122.0      7.286885
# 4           South America     False          99.0      7.252525
# 5           South America     False          66.0      6.666667
# 6           South America     False          34.0      6.352941
# 7           South America     False          10.0      6.300000
# 8                  Europe     False          96.0      6.229167
# 9                  Europe      True          23.0      6.130435
# 10          South America     False           6.0      6.000000
# 11                 Europe      True           3.0      6.000000
# 12                 Europe     False          64.0      5.781250
# 13                 Europe      True          31.0      5.645161
# 14          South America     False         104.0      5.576923
# 15                 Europe      True           2.0      5.500000
# 16          South America     False         147.0      5.496599
# 17                 Europe     False          33.0      5.454545
# 18                 Europe     False         100.0      5.450000
# 19                 Africa     False         128.0      5.445312
# 20                 Europe      True         116.0      5.362069
# 21          South America     False         133.0      5.338346
# 22          South America     False         124.0      5.306452
# 23                 Europe     False          31.0      5.290323
# 24                 Europe     False         150.0      5.273333
# 25                 Africa     False          37.0      5.216216
# 26                 Europe     False          28.0      5.214286
# 27                 Europe      True          33.0      5.212121
# 28          South America     False          38.0      5.210526
# 29                 Europe     False          34.0      5.147059
# 30                 Europe      True          37.0      5.135135
# ...                   ...       ...           ...           ...
# 4527               Europe     False           2.0     -0.500000
# 4528        South America     False           2.0     -0.500000
# 4529               Europe      True           2.0     -0.500000
# 4530               Europe     False           2.0     -0.500000
# 4531               Europe     False           4.0     -0.500000
# 4532               Europe      True           5.0     -0.600000
# 4533               Europe     False           3.0     -0.666667
# 4534        South America     False           4.0     -0.750000
# 4535  Australia / Oceania     False           5.0     -1.000000
# 4536               Europe     False           3.0     -1.000000
# 4537               Europe     False           2.0     -1.000000
# 4538               Europe     False           3.0     -1.000000
# 4539               Europe     False           2.0     -1.000000
# 4540               Europe      True           2.0     -1.000000
# 4541               Europe      True           3.0     -1.000000
# 4542               Europe     False           5.0     -1.200000
# 4543               Europe     False           3.0     -1.333333
# 4544        South America     False           3.0     -1.333333
# 4545               Europe     False           2.0     -1.500000
# 4546        South America     False           2.0     -1.500000
# 4547               Europe     False           2.0     -1.500000
# 4548               Europe      True           4.0     -1.500000
# 4549        North America     False           2.0     -1.500000
# 4550               Europe     False           2.0     -1.500000
# 4551               Europe     False           2.0     -2.000000
# 4552               Europe     False           3.0     -2.000000
# 4553               Europe      True           2.0     -2.000000
# 4554               Europe     False           2.0     -2.500000
# 4555               Europe     False           2.0     -2.500000
# 4556               Europe      True           3.0     -3.000000
#
#       Goals/Games Ratio  Assists/Games Ratio  Clean Sheets/Games Ratio
# 1              1.065476             0.386905                  0.000000
# 2              1.054878             0.317073                  0.000000
# 3              0.926230             0.311475                  0.000000
# 4              0.848485             0.424242                  0.000000
# 5              0.818182             0.272727                  0.000000
# 6              0.852941             0.117647                  0.000000
# 7              0.700000             0.400000                  0.000000
# 8              0.802083             0.125000                  0.000000
# 9              0.652174             0.304348                  0.000000
# 10             0.000000             0.000000                  0.833333
# 11             0.000000             0.000000                  1.000000
# 12             0.687500             0.187500                  0.000000
# 13             0.677419             0.161290                  0.000000
# 14             0.682692             0.153846                  0.000000
# 15             0.000000             0.000000                  1.000000
# 16             0.673469             0.149660                  0.000000
# 17             0.636364             0.181818                  0.000000
# 18             0.540000             0.330000                  0.000000
# 19             0.664062             0.132812                  0.000000
# 20             0.672414             0.112069                  0.000000
# 21             0.654135             0.105263                  0.000000
# 22             0.548387             0.306452                  0.000000
# 23             0.645161             0.096774                  0.000000
# 24             0.520000             0.273333                  0.000000
# 25             0.513514             0.243243                  0.000000
# 26             0.607143             0.178571                  0.000000
# 27             0.666667             0.121212                  0.000000
# 28             0.631579             0.078947                  0.000000
# 29             0.294118             0.588235                  0.000000
# 30             0.621622             0.081081                  0.000000
# ...                 ...                  ...                       ...
# 4527           0.000000             0.000000                  0.000000
# 4528           0.000000             0.000000                  0.000000
# 4529           0.000000             0.000000                  0.000000
# 4530           0.000000             0.000000                  0.000000
# 4531           0.000000             0.000000                  0.000000
# 4532           0.000000             0.000000                  0.000000
# 4533           0.000000             0.000000                  0.000000
# 4534           0.000000             0.000000                  0.000000
# 4535           0.000000             0.000000                  0.000000
# 4536           0.000000             0.000000                  0.000000
# 4537           0.000000             0.000000                  0.000000
# 4538           0.000000             0.000000                  0.000000
# 4539           0.000000             0.000000                  0.000000
# 4540           0.000000             0.000000                  0.000000
# 4541           0.000000             0.000000                  0.000000
# 4542           0.000000             0.000000                  0.000000
# 4543           0.000000             0.000000                  0.000000
# 4544           0.000000             0.000000                  0.000000
# 4545           0.000000             0.000000                  0.000000
# 4546           0.000000             0.000000                  0.000000
# 4547           0.000000             0.000000                  0.000000
# 4548           0.000000             0.000000                  0.000000
# 4549           0.000000             0.000000                  0.000000
# 4550           0.000000             0.000000                  0.000000
# 4551           0.000000             0.000000                  0.000000
# 4552           0.000000             0.000000                  0.000000
# 4553           0.000000             0.000000                  0.000000
# 4554           0.000000             0.000000                  0.000000
# 4555           0.000000             0.000000                  0.000000
# 4556           0.000000             0.000000                  0.000000
#
# [4556 rows x 14 columns]

# %% [markdown]
# ### Part 1:

# %%
Europe_Avg = RQ2.loc[RQ2['Continent'] == 'Europe', 'Average Form'].mean()
South_America_Avg = RQ2.loc[RQ2['Continent'] == 'South America', 'Average Form'].mean()
North_America_Avg = RQ2.loc[RQ2['Continent'] == 'North America', 'Average Form'].mean()
Africa_Avg = RQ2.loc[RQ2['Continent'] == 'Africa', 'Average Form'].mean()
Australia_Oceania_Avg = RQ2.loc[RQ2['Continent'] == 'Australia / Oceania', 'Average Form'].mean()

# %%
columns = ['Continent','Form']
df = pd.DataFrame(columns=columns)
df = df.fillna(0) # with 0s rather than NaNs

# %%
df['Form']=Europe_Avg,South_America_Avg,North_America_Avg,Africa_Avg,Australia_Oceania_Avg

# %%
df['Continent'] = ['Europe','South America','North America','Africa','Australia / Oceania']
df= df.set_index('Continent')

# %%
df
# Out:
#                          Form
# Continent
# Europe               2.147463
# South America        2.380199
# North America        2.101697
# Africa               2.152423
# Australia / Oceania  1.651337

# %%
explode = (0,0.2,0,0,0)
labels = ["Europe","South America","North America","Africa","Australia / Oceania"]
df.plot(subplots=True,kind='pie',figsize=(9,9),fontsize=14,explode=explode,autopct='%1.1f%%',shadow=True,labels=labels,labeldistance=1.4)
plt.legend(loc='right', bbox_to_anchor=(1.45, .55))
plt.title('Average Form Per Region',fontsize=10)
# Out:
# Text(0.5,1,'Average Form Per Region')

# %%
RQ3_2 = pd.read_csv(('../../data/analysis/RQ2.csv'))
RQ3_2 = RQ3_2.drop('Unnamed: 0', 1)
RQ3_2 = RQ3_2.iloc[1:]

# %%
RQ3_2.head(5)
# Out:
#               Players Position  Clubs                    league   age  \
# 1        Lionel Messi  Forward   BARC  Spanish Primera Division  30.0
# 2   Cristiano Ronaldo  Forward   MADR  Spanish Primera Division  32.0
# 3  Zlatan Ibrahimovic  Forward    PSG    English Premier League  35.0
# 4         Luis Suarez  Forward   BARC  Spanish Primera Division  30.0
# 5         Luis Suarez  Forward  LPOOL  Spanish Primera Division  30.0
#
#   nationality  overall  skill_moves 16/17 16/17.1     ...      12/13.4  \
# 1   Argentina     93.0          4.0  34.0   270.0     ...         12.0
# 2    Portugal     94.0          5.0  29.0   195.0     ...         11.0
# 3      Sweden     88.0          4.0   0.0     0.0     ...          8.0
# 4     Uruguay     92.0          4.0  36.0   241.0     ...          0.0
# 5     Uruguay     92.0          4.0   0.0     0.0     ...          5.0
#
#   12/13.5 12/13.6 12/13.7 12/13.8      Continent Homegrown Overall Points  \
# 1     0.0     1.0     0.0     4.0  South America     False         1387.0
# 2     0.0     9.0     0.0     4.0         Europe     False         1300.0
# 3     0.0     9.0     1.0     1.0         Europe     False          889.0
# 4     0.0     0.0     0.0     0.0  South America     False          718.0
# 5     0.0    10.0     0.0     0.0  South America     False          440.0
#
#   Overall Apps Average Form
# 1        168.0     8.255952
# 2        164.0     7.926829
# 3        122.0     7.286885
# 4         99.0     7.252525
# 5         66.0     6.666667
#
# [5 rows x 58 columns]

# %%
Homegrown_EPL = (RQ3_2.loc[RQ3_2.nationality=='England'])
Homegrown_EPL = Homegrown_EPL.loc[Homegrown_EPL.league=='English Premier League']

Foreign_EPL = (RQ3_2.loc[RQ3_2.nationality!='England'])
Foreign_EPL = Foreign_EPL.loc[Foreign_EPL.league=='English Premier League']

Homegrown_BUN = (RQ3_2.loc[RQ3_2.nationality=='Germany'])
Homegrown_BUN = Homegrown_BUN.loc[Homegrown_BUN.league=='German Bundesliga']

Foreign_BUN = (RQ3_2.loc[RQ3_2.nationality!='Germany'])
Foreign_BUN = Foreign_BUN.loc[Foreign_BUN.league=='German Bundesliga']

Homegrown_LAL = (RQ3_2.loc[RQ3_2.nationality=='Spain'])
Homegrown_LAL = Homegrown_LAL.loc[Homegrown_LAL.league=='Spanish Primera Division']

Foreign_LAL = (RQ3_2.loc[RQ3_2.nationality!='Spain'])
Foreign_LAL = Foreign_LAL.loc[Foreign_LAL.league=='Spanish Primera Division']

Homegrown_FRA = (RQ3_2.loc[RQ3_2.nationality=='France'])
Homegrown_FRA = Homegrown_FRA.loc[Homegrown_FRA.league=='French Ligue 1']

Foreign_FRA = (RQ3_2.loc[RQ3_2.nationality!='France'])
Foreign_FRA = Foreign_FRA.loc[Foreign_FRA.league=='French Ligue 1']

Homegrown_SEI = (RQ3_2.loc[RQ3_2.nationality=='Italy'])
Homegrown_SEI = Homegrown_SEI.loc[Homegrown_SEI.league=='Italian Serie A']

Foreign_SEI = (RQ3_2.loc[RQ3_2.nationality!='Italy'])
Foreign_SEI = Foreign_SEI.loc[Foreign_SEI.league=='Italian Serie A']

# %%
avg = {'age':'mean','league':'first','overall':'mean','Points':'mean','Average Goals':'mean','Average Assists':'mean',
           'Average Yellow':'mean','Average Red':'mean','Average Form':'mean'}
Average = ['league','age','nationality','overall','Average Points',
           'Average Form','Average Goals','Average Assists','Average Red','Average Yellow']

# %%
Avg_English = (Homegrown_EPL.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_EPL.columns))
Avg_English = Avg_English[Average]

Avg_Spanish = (Homegrown_LAL.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_LAL.columns))
Avg_Spanish = Avg_Spanish[Average]

Avg_German = (Homegrown_BUN.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_BUN.columns))
Avg_German = Avg_German[Average]

Avg_French = (Homegrown_FRA.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_FRA.columns))
Avg_French = Avg_French[Average]

Avg_Italian = (Homegrown_SEI.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_SEI.columns))
Avg_Italian = Avg_Italian[Average]


Avg_English_Foreign = (Foreign_EPL.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_EPL.columns))
Avg_English_Foreign = Avg_English_Foreign[Average]

Avg_Spanish_Foreign = (Foreign_LAL.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_LAL.columns))
Avg_Spanish_Foreign = Avg_Spanish_Foreign[Average]

Avg_German_Foreign = (Foreign_BUN.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_BUN.columns))
Avg_German_Foreign =  Avg_German_Foreign[Average]

Avg_French_Foreign = (Foreign_FRA.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_FRA.columns))
Avg_French_Foreign = Avg_French_Foreign[Average]

Avg_Italian_Foreign = (Foreign_SEI.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_SEI.columns))
Avg_Italian_Foreign = Avg_Italian_Foreign[Average]
# Out:
# C:\Users\Mark\Desktop\Anaconda3\lib\site-packages\pandas\core\groupby.py:4036: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Points'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-d804fdd0262a> in <module>()
# ----> 1 Avg_English = (Homegrown_EPL.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_EPL.columns))
#       2 Avg_English = Avg_English[Average]
#       3
#       4 Avg_Spanish = (Homegrown_LAL.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_LAL.columns))
#       5 Avg_Spanish = Avg_Spanish[Average]
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    4034         versionadded=''))
#    4035     def aggregate(self, arg, *args, **kwargs):
# -> 4036         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4037
#    4038     agg = aggregate
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\groupby.py in aggregate(self, arg, *args, **kwargs)
#    3466
#    3467         _level = kwargs.pop('_level', None)
# -> 3468         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3469         if how is None:
#    3470             return result
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     571
#     572                 try:
# --> 573                     result = _agg(arg, _agg_1dim)
#     574                 except SpecificationError:
#     575
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\base.py in _agg(arg, func)
#     522                 result = compat.OrderedDict()
#     523                 for fname, agg_how in compat.iteritems(arg):
# --> 524                     result[fname] = func(fname, agg_how)
#     525                 return result
#     526
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\base.py in _agg_1dim(name, how, subset)
#     501                 aggregate a 1-dim with how
#     502                 """
# --> 503                 colg = self._gotitem(name, ndim=1, subset=subset)
#     504                 if colg.ndim != 1:
#     505                     raise SpecificationError("nested dictionary is ambiguous "
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\groupby.py in _gotitem(self, key, ndim, subset)
#    4061         elif ndim == 1:
#    4062             if subset is None:
# -> 4063                 subset = self.obj[key]
#    4064             return SeriesGroupBy(subset, selection=key,
#    4065                                  grouper=self.grouper)
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    1962             return self._getitem_multilevel(key)
#    1963         else:
# -> 1964             return self._getitem_column(key)
#    1965
#    1966     def _getitem_column(self, key):
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    1969         # get column
#    1970         if self.columns.is_unique:
# -> 1971             return self._get_item_cache(key)
#    1972
#    1973         # duplicate columns & possible reduce dimensionality
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1643         res = cache.get(item)
#    1644         if res is None:
# -> 1645             values = self._data.get(item)
#    1646             res = self._box_item_values(item, values)
#    1647             cache[item] = res
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# ~\Desktop\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
# -> 2444                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2445
#    2446         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Points'

# %%
HomegrownPlayers = [Avg_English,Avg_Spanish,Avg_German,Avg_French,Avg_Italian]
ForeignPlayers = [Avg_English_Foreign,Avg_Spanish_Foreign,Avg_German_Foreign,Avg_French_Foreign,Avg_Italian_Foreign]

AverageHomegrown = pd.concat(HomegrownPlayers)
AverageForeign = pd.concat(ForeignPlayers)

AverageHomegrown['Homegrown'] = True
AverageForeign['Homegrown'] = False

All_Players = [AverageForeign,AverageHomegrown]
Total_Average = pd.concat(All_Players)

Total_Average['nationality'] = Total_Average.fillna('Foreign')

Total_Average = Total_Average.sort_values(by=['Average Form'],ascending=False)

Total_Average = Total_Average.set_index('league')

# %%
Total_Average

# %%
Total_Average['Performance'] =  Total_Average['Average Points'] / Total_Average.overall

# %%
Total_Average

# %%
HEPL = len(Homegrown_EPL)
HBUN = len(Homegrown_BUN)
HLAL = len(Homegrown_LAL)
FEPL = len(Foreign_EPL)
FBUN = len(Foreign_BUN)
FLAL = len(Foreign_LAL)
HFRA = len(Homegrown_FRA)
HSEI = len(Homegrown_SEI)
FFRA = len(Foreign_FRA)
FSEI = len(Foreign_SEI)


columns = ['Homegrown','Foreign']
df = pd.DataFrame(columns=columns)
df = df.fillna(0) # with 0s rather than NaNs
df['Homegrown']=HEPL,HBUN,HLAL,HFRA,HSEI
df['Foreign']=FEPL,FBUN,FLAL,FFRA,FSEI
df = df.transpose()
df.columns = ['EPL', 'BUN','LAL','FRA','SEI']
df['Total'] = df.sum(axis=1)

# %%
df

# %%
explode = (0.07, 0)
labels = ["Homegrown","Foreign"]
df.plot(subplots=True,kind='pie',y='Total',figsize=(9,9),fontsize=14,explode=explode,autopct='%1.1f%%',shadow=True,labels=labels,labeldistance=1.4)
plt.legend(loc='right', bbox_to_anchor=(1.45, .55))
plt.title('Homegrown vs Foreign',fontsize=10)

# %%
the_grid = GridSpec(6,6)

df.plot(figsize=(20,20))

plt.subplot(the_grid[4, 2], aspect=1)
explode2 = (0.1, 0)
plt.pie(df['EPL'],labels=['Homegrown','Foreign'],labeldistance=1.2,startangle=120,autopct='%.1f%%',shadow=True, radius=2,colors=['blueviolet','lawngreen'],explode=explode2)
plt.gca().set_title('EPL',color='white',fontsize=20)
centre_circle = plt.Circle((0,0),0.99,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)


plt.subplot(the_grid[3, 0], aspect=1)
explode3 = (0, 0.1)
plt.pie(df['BUN'],labels=['Homegrown','Foreign'],labeldistance=1.1,startangle=70,autopct='%.1f%%',shadow=True, radius=2,colors=['firebrick','dimgrey'],explode=explode3)
plt.gca().set_title('BUN',color='white',fontsize=20)
centre_circle = plt.Circle((0,0),0.99,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.subplot(the_grid[3, 4], aspect=1)
explode4 = (0, 0.1)
plt.pie(df['LAL'],labels=['Homegrown','Foreign'],labeldistance=1.2,startangle=120,autopct='%.1f%%',shadow=True, radius=2,explode=explode4,colors=['darkorange','gold'])
plt.gca().set_title('LAL',color='white',fontsize=20)
centre_circle = plt.Circle((0,0),0.99,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.subplot(the_grid[5, 0], aspect=1)
explode3 = (0, 0.1)
plt.pie(df['FRA'],labels=['Homegrown','Foreign'],labeldistance=1.1,startangle=60,autopct='%.1f%%',shadow=True, radius=2,colors=['lightblue','lightgrey'],explode=explode3)
plt.gca().set_title('FRA',color='white',fontsize=20)
centre_circle = plt.Circle((0,0),0.99,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.subplot(the_grid[5, 4], aspect=1)
explode4 = (0, 0.1)
plt.pie(df['SEI'],labels=['Homegrown','Foreign'],labeldistance=1.2,startangle=120,autopct='%.1f%%',shadow=True, radius=2,explode=explode4,colors=['salmon','yellowgreen'])
plt.gca().set_title('SEI',color='white',fontsize=20)
centre_circle = plt.Circle((0,0),0.99,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

# %%
test = Total_Average[['overall','Homegrown']]
test = test.transpose()
test.columns = ['LAL F', 'EPL F','SEI F','BUN F','EPL H','FRA F','BUN H','FRA H','SEI H','LAL H']
cols = ['LAL H', 'LAL F', 'BUN H', 'BUN F', 'EPL H', 'EPL F','SEI H', 'SEI F','FRA H', 'FRA F']
test = test[cols]
test = test.transpose()

# %%
labels = ['LAL Homegrown','LAL Foreign','BUN Homegrown','BUN Foreign','EPL Homegrown','EPL Foreign','SEI Homegrown','SEI Foreign','FRA Homegrown','FRA Foreign']
test.plot(x=test.index, y='overall',figsize=(12,12),kind='bar',color=[['gold','gold','firebrick','firebrick','blueviolet','blueviolet','green','green','blue','blue']])
axes = plt.gca()
axes.set_xticklabels(labels)
axes.set_ylim([73,79.5])

# %%
Homegrown_LAL_GK = Homegrown_LAL.loc[Homegrown_LAL.Position=='Goalkeeper']
Homegrown_LAL_DF = Homegrown_LAL.loc[Homegrown_LAL.Position=='Defender']
Homegrown_LAL_MD = Homegrown_LAL.loc[Homegrown_LAL.Position=='Midfielder']
Homegrown_LAL_FW = Homegrown_LAL.loc[Homegrown_LAL.Position=='Forward']

Homegrown_BUN_GK = Homegrown_BUN.loc[Homegrown_BUN.Position=='Goalkeeper']
Homegrown_BUN_DF = Homegrown_BUN.loc[Homegrown_BUN.Position=='Defender']
Homegrown_BUN_MD = Homegrown_BUN.loc[Homegrown_BUN.Position=='Midfielder']
Homegrown_BUN_FW = Homegrown_BUN.loc[Homegrown_BUN.Position=='Forward']

Homegrown_EPL_GK = Homegrown_EPL.loc[Homegrown_EPL.Position=='Goalkeeper']
Homegrown_EPL_DF = Homegrown_EPL.loc[Homegrown_EPL.Position=='Defender']
Homegrown_EPL_MD = Homegrown_EPL.loc[Homegrown_EPL.Position=='Midfielder']
Homegrown_EPL_FW = Homegrown_EPL.loc[Homegrown_EPL.Position=='Forward']

Foreign_LAL_GK = Foreign_LAL.loc[Foreign_LAL.Position=='Goalkeeper']
Foreign_LAL_DF = Foreign_LAL.loc[Foreign_LAL.Position=='Defender']
Foreign_LAL_MD = Foreign_LAL.loc[Foreign_LAL.Position=='Midfielder']
Foreign_LAL_FW = Foreign_LAL.loc[Foreign_LAL.Position=='Forward']

Foreign_BUN_GK = Foreign_BUN.loc[Foreign_BUN.Position=='Goalkeeper']
Foreign_BUN_DF = Foreign_BUN.loc[Foreign_BUN.Position=='Defender']
Foreign_BUN_MD = Foreign_BUN.loc[Foreign_BUN.Position=='Midfielder']
Foreign_BUN_FW = Foreign_BUN.loc[Foreign_BUN.Position=='Forward']

Foreign_EPL_GK = Foreign_EPL.loc[Foreign_EPL.Position=='Goalkeeper']
Foreign_EPL_DF = Foreign_EPL.loc[Foreign_EPL.Position=='Defender']
Foreign_EPL_MD = Foreign_EPL.loc[Foreign_EPL.Position=='Midfielder']
Foreign_EPL_FW = Foreign_EPL.loc[Foreign_EPL.Position=='Forward']

# %%
avg = {'age':'mean','league':'first','overall':'mean','Average Points':'mean','Average Goals':'mean','Average Assists':'mean',
           'Average Yellow':'mean','Average Red':'mean','Average Form':'mean','Position':'first'}

# %%
Avg_English_GK = (Homegrown_EPL_GK.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_EPL_GK.columns))
Avg_Spanish_GK = (Homegrown_LAL_GK.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_LAL_GK.columns))
Avg_German_GK = (Homegrown_BUN_GK.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_BUN_GK.columns))

Avg_English_Foreign_GK = (Foreign_EPL_GK.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_EPL_GK.columns))
Avg_Spanish_Foreign_GK = (Foreign_LAL_GK.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_LAL_GK.columns))
Avg_German_Foreign_GK = (Foreign_BUN_GK.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_BUN_GK.columns))

Avg_English_DF = (Homegrown_EPL_DF.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_EPL_DF.columns))
Avg_Spanish_DF = (Homegrown_LAL_DF.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_LAL_DF.columns))
Avg_German_DF = (Homegrown_BUN_DF.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_BUN_DF.columns))

Avg_English_Foreign_DF = (Foreign_EPL_DF.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_EPL_DF.columns))
Avg_Spanish_Foreign_DF = (Foreign_LAL_DF.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_LAL_DF.columns))
Avg_German_Foreign_DF = (Foreign_BUN_DF.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_BUN_DF.columns))

Avg_English_MD = (Homegrown_EPL_MD.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_EPL_MD.columns))
Avg_Spanish_MD = (Homegrown_LAL_MD.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_LAL_MD.columns))
Avg_German_MD = (Homegrown_BUN_MD.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_BUN_MD.columns))

Avg_English_Foreign_MD = (Foreign_EPL_MD.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_EPL_MD.columns))
Avg_Spanish_Foreign_MD = (Foreign_LAL_MD.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_LAL_MD.columns))
Avg_German_Foreign_MD = (Foreign_BUN_MD.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_BUN_MD.columns))

Avg_English_FW = (Homegrown_EPL_FW.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_EPL_FW.columns))
Avg_Spanish_FW = (Homegrown_LAL_FW.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_LAL_FW.columns))
Avg_German_FW = (Homegrown_BUN_FW.groupby(['nationality'], sort=False, as_index=False).agg(avg).reindex(columns=Homegrown_BUN_FW.columns))

Avg_English_Foreign_FW = (Foreign_EPL_FW.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_EPL_FW.columns))
Avg_Spanish_Foreign_FW = (Foreign_LAL_FW.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_LAL_FW.columns))
Avg_German_Foreign_FW = (Foreign_BUN_FW.groupby(['Homegrown'], sort=False, as_index=False).agg(avg).reindex(columns=Foreign_BUN_FW.columns))

# %%
HomegrownPlayers_GK = [Avg_English_GK,Avg_Spanish_GK,Avg_German_GK]
ForeignPlayers_GK = [Avg_English_Foreign_GK,Avg_Spanish_Foreign_GK,Avg_German_Foreign_GK]

HomegrownPlayers_DF = [Avg_English_DF,Avg_Spanish_DF,Avg_German_DF]
ForeignPlayers_DF = [Avg_English_Foreign_DF,Avg_Spanish_Foreign_DF,Avg_German_Foreign_DF]

HomegrownPlayers_MD = [Avg_English_MD,Avg_Spanish_MD,Avg_German_MD]
ForeignPlayers_MD = [Avg_English_Foreign_MD,Avg_Spanish_Foreign_MD,Avg_German_Foreign_MD]

HomegrownPlayers_FW = [Avg_English_FW,Avg_Spanish_FW,Avg_German_FW]
ForeignPlayers_FW = [Avg_English_Foreign_FW,Avg_Spanish_Foreign_FW,Avg_German_Foreign_FW]

HomegrownPlayers_GK = pd.concat(HomegrownPlayers_GK)
HomegrownPlayers_DF = pd.concat(HomegrownPlayers_DF)
HomegrownPlayers_MD = pd.concat(HomegrownPlayers_MD)
HomegrownPlayers_FW = pd.concat(HomegrownPlayers_FW)

ForeignPlayers_GK = pd.concat(ForeignPlayers_GK)
ForeignPlayers_DF = pd.concat(ForeignPlayers_DF)
ForeignPlayers_MD = pd.concat(ForeignPlayers_MD)
ForeignPlayers_FW = pd.concat(ForeignPlayers_FW)

HomegrownPlayers_GK = HomegrownPlayers_GK.drop(['Players','club'], 1)
HomegrownPlayers_DF = HomegrownPlayers_DF.drop(['Players','club'], 1)
HomegrownPlayers_MD = HomegrownPlayers_MD.drop(['Players','club'], 1)
HomegrownPlayers_FW = HomegrownPlayers_FW.drop(['Players','club'], 1)

ForeignPlayers_GK = ForeignPlayers_GK.drop(['Players','club'], 1)
ForeignPlayers_DF = ForeignPlayers_DF.drop(['Players','club'], 1)
ForeignPlayers_MD = ForeignPlayers_MD.drop(['Players','club'], 1)
ForeignPlayers_FW = ForeignPlayers_FW.drop(['Players','club'], 1)

# %%
HomegrownPlayers_Positions = [HomegrownPlayers_GK,HomegrownPlayers_DF,HomegrownPlayers_MD,HomegrownPlayers_FW]
ForeignPlayers_Positions = [ForeignPlayers_GK,ForeignPlayers_DF,ForeignPlayers_MD,ForeignPlayers_FW]

AverageHomegrown_Positions = pd.concat(HomegrownPlayers_Positions)
AverageForeign_Positions = pd.concat(ForeignPlayers_Positions)
AverageHomegrown_Positions ['Homegrown'] = True
AverageForeign_Positions ['Homegrown'] = False

AverageForeign_Positions = AverageForeign_Positions.fillna('Foreign')

# %%
All_Players_Positions = [AverageForeign_Positions,AverageHomegrown_Positions]
Total_Average_Position = pd.concat(All_Players_Positions)
Total_Average_Position = Total_Average_Position.sort_values(['Position', 'league'], ascending=True)

# %%
Total_Average_Position = Total_Average_Position.set_index('league')
Total_Average_Position
