# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
from matplotlib.gridspec import GridSpec
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image

# %%
RQ4 = pd.read_csv(('../../data/analysis/RQ3.csv'))
RQ4 = RQ4.drop('Unnamed: 0', 1)
RQ4 = RQ4.iloc[1:]

# %%
RQ4
# Out:
#                   Players                       club  \
# 1         Aaron Cresswell            West Ham United
# 2            Aaron Hughes        Heart of Midlothian
# 3              Aaron Hunt               Hamburger SV
# 4            Aaron Lennon                    Everton
# 5            Aaron Niguez                Real Oviedo
# 6            Aaron Ramsey                    Arsenal
# 7           Abdoul Camara       En Avant de Guingamp
# 8          Abdoul Sissoko       Akhisar Belediyespor
# 9      Abdoulaye Doucoure                    Watford
# 10        Abdoulaye Keita                Le Havre AC
# 11        Abdoulaye Toure                  FC Nantes
# 12           Abel Aguilar  Asociacion Deportivo Cali
# 13         Abel Hernandez                  Hull City
# 14          Achraf Lazaar           Benevento Calcio
# 15    Adalberto Penaranda                  Malaga CF
# 16         Adam Armstrong           Bolton Wanderers
# 17          Adam Federici                Bournemouth
# ...

# %%
RQ4 = RQ4.sort_values(['Average Form','Players'],ascending=False)
RQ4 = RQ4.reset_index()
RQ4.drop(RQ4.columns[0], axis=1, inplace=True)
RQ4.head(3)
# Out:
#              Players            club                    league   age  \
# 0       Lionel Messi    FC Barcelona  Spanish Primera Division  30.0
# 1  Cristiano Ronaldo  Real Madrid CF  Spanish Primera Division  32.0
# 2        Luis Suarez    FC Barcelona  Spanish Primera Division  30.0
#
#   nationality Position  overall  potential  \
# 0   Argentina  Forward     93.0       93.0
# 1    Portugal  Forward     94.0       94.0
# 2     Uruguay  Forward     92.0       92.0
#
#                                           photo      Continent  Average Form
# 0  https://cdn.sofifa.org/18/players/158023.png  South America      8.255952
# 1   https://cdn.sofifa.org/18/players/20801.png         Europe      7.926829
# 2  https://cdn.sofifa.org/18/players/176580.png  South America      7.018182

# %%
RQ4_Best = RQ4[RQ4['age']<34] #best players
RQ4_Youth = RQ4[RQ4['age']<=20] #best young players
RQ4_Oldies = RQ4[RQ4['age']>29] #best old players

# %%
RQ4_Best_Top = RQ4_Best.sort_values(['Average Form'], ascending=[False])
RQ4_Best_Top_GK = RQ4_Best.loc[RQ4_Best.Position=='Goalkeeper']
RQ4_Best_Top_GK_Str = RQ4_Best_Top_GK['overall'].astype(str) 
RQ4_Best_Top_GK_Sum = RQ4_Best_Top_GK['overall'].astype(float) 

RQ4_Best_Top = RQ4_Best.sort_values(['Average Form'], ascending=[False])
RQ4_Best_Top_DF = RQ4_Best.loc[RQ4_Best.Position=='Defender']
RQ4_Best_Top_DF_Str = RQ4_Best_Top_DF['overall'].astype(str)
RQ4_Best_Top_DF_Sum = RQ4_Best_Top_DF['overall'].astype(float) 

RQ4_Best_Top = RQ4_Best.sort_values(['Average Form'], ascending=[False])
RQ4_Best_Top_MD = RQ4_Best.loc[RQ4_Best.Position=='Midfielder']
RQ4_Best_Top_MD_Str = RQ4_Best_Top_MD['overall'].astype(str)
RQ4_Best_Top_MD_Sum = RQ4_Best_Top_MD['overall'].astype(float) 

RQ4_Best_Top = RQ4_Best.sort_values(['Average Form'], ascending=[False])
RQ4_Best_Top_FW = RQ4_Best.loc[RQ4_Best.Position=='Forward']
RQ4_Best_Top_FW_Str = RQ4_Best_Top_FW['overall'].astype(str)
RQ4_Best_Top_FW_Sum = RQ4_Best_Top_FW['overall'].astype(float) 

RQ4_Youth_Top = RQ4_Youth.sort_values(['Average Form'], ascending=[False])
RQ4_Youth_Top_GK = RQ4_Youth.loc[RQ4_Youth.Position=='Goalkeeper']
RQ4_Youth_Top_GK_Str = RQ4_Youth_Top_GK['overall'].astype(str) 
RQ4_Youth_Top_GK_Sum = RQ4_Youth_Top_GK['overall'].astype(float) 

RQ4_Youth_Top = RQ4_Youth.sort_values(['Average Form'], ascending=[False])
RQ4_Youth_Top_DF = RQ4_Youth.loc[RQ4_Youth.Position=='Defender']
RQ4_Youth_Top_DF_Str = RQ4_Youth_Top_DF['overall'].astype(str)
RQ4_Youth_Top_DF_Sum = RQ4_Youth_Top_DF['overall'].astype(float) 

RQ4_Youth_Top = RQ4_Youth.sort_values(['Average Form'], ascending=[False])
RQ4_Youth_Top_MD = RQ4_Youth.loc[RQ4_Youth.Position=='Midfielder']
RQ4_Youth_Top_MD_Str = RQ4_Youth_Top_MD['overall'].astype(str)
RQ4_Youth_Top_MD_Sum = RQ4_Youth_Top_MD['overall'].astype(float) 

RQ4_Youth_Top = RQ4_Youth.sort_values(['Average Form'], ascending=[False])
RQ4_Youth_Top_FW = RQ4_Youth.loc[RQ4_Youth.Position=='Forward']
RQ4_Youth_Top_FW_Str = RQ4_Youth_Top_FW['overall'].astype(str)
RQ4_Youth_Top_FW_Sum = RQ4_Youth_Top_FW['overall'].astype(float)

RQ4_Oldies_Top = RQ4_Oldies.sort_values(['Average Form'], ascending=[False])
RQ4_Oldies_Top_GK = RQ4_Oldies.loc[RQ4_Oldies.Position=='Goalkeeper']
RQ4_Oldies_Top_GK_Str = RQ4_Oldies_Top_GK['overall'].astype(str) 
RQ4_Oldies_Top_GK_Sum = RQ4_Oldies_Top_GK['overall'].astype(float) 

RQ4_Oldies_Top = RQ4_Oldies.sort_values(['Average Form'], ascending=[False])
RQ4_Oldies_Top_DF = RQ4_Oldies.loc[RQ4_Oldies.Position=='Defender']
RQ4_Oldies_Top_DF_Str = RQ4_Oldies_Top_DF['overall'].astype(str)
RQ4_Oldies_Top_DF_Sum = RQ4_Oldies_Top_DF['overall'].astype(float) 

RQ4_Oldies_Top = RQ4_Oldies.sort_values(['Average Form'], ascending=[False])
RQ4_Oldies_Top_MD = RQ4_Oldies.loc[RQ4_Oldies.Position=='Midfielder']
RQ4_Oldies_Top_MD_Str = RQ4_Oldies_Top_MD['overall'].astype(str)
RQ4_Oldies_Top_MD_Sum = RQ4_Oldies_Top_MD['overall'].astype(float) 

RQ4_Oldies_Top = RQ4_Oldies.sort_values(['Average Form'], ascending=[False])
RQ4_Oldies_Top_FW = RQ4_Oldies.loc[RQ4_Oldies.Position=='Forward']
RQ4_Oldies_Top_FW_Str = RQ4_Oldies_Top_FW['overall'].astype(str)
RQ4_Oldies_Top_FW_Sum = RQ4_Oldies_Top_FW['overall'].astype(float)

# %%
RQ4_Best_Top_GK.iloc[0]
# Out:
# Players                                            Jan Oblak
# club                                         Atletico Madrid
# league                              Spanish Primera Division
# age                                                       24
# nationality                                         Slovenia
# Position                                          Goalkeeper
# overall                                                   88
# potential                                                 93
# photo           https://cdn.sofifa.org/18/players/200389.png
# Continent                                             Europe
# Average Form                                         4.21519
# Name: 44, dtype: object

# %%
def XI(position):
    SquadDB = RQ4_Best.copy()
    
    store = []
    for x in position:
        
        store.append([ x ,SquadDB.loc[[SquadDB[SquadDB['Position'] == x ]['Average Form'].idxmax()]]['Players'].to_string(index = False), SquadDB[SquadDB['Position'] == x ]['Average Form'].max(),SquadDB[SquadDB['Position'] == x ]['photo'].unique(),SquadDB[SquadDB['Position'] == x ]['overall'].max()])
        
        SquadDB.drop(SquadDB[SquadDB['Position'] == x ]['Average Form'].idxmax(), inplace = True)
     
    return pd.DataFrame(np.array(store).reshape(11,5), columns = ['Position', 'Players','Average Form','photo','overall']).to_string(index = False)

XI442 = ['Goalkeeper', 'Defender', 'Defender', 'Defender', 'Defender', 'Midfielder', 'Midfielder', 'Midfielder', 'Midfielder', 'Forward', 'Forward']

RQ4Best = (XI(XI442))

# %%
RQ4Best = RQ4Best.replace('h...','')
RQ4Best = RQ4Best.replace('...','')
RQ4Best = RQ4Best.replace('[','')
RQ4Best = RQ4Best.replace(',','')
lst = RQ4Best.split()
data = [lst[pos:pos+6] for pos in range(0, len(lst), 6)]
RQ4Best = pd.DataFrame(data[1:], columns=data[0])
RQ4Best['Players'] = RQ4Best['Players'] +' ' +  RQ4Best['Average']
RQ4Best = RQ4Best.drop('Average',1)

# %%
RQ4Best
# Out:
#       Position            Players     Form  \
# 0   Goalkeeper          Jan Oblak  4.21519
# 1     Defender        David Alaba  4.62121
# 2     Defender     Mattia Caldara  4.51613
# 3     Defender        Aleix Vidal      4.5
# 4     Defender        Alex Sandro  4.26531
# 5   Midfielder        Gareth Bale  5.45113
# 6   Midfielder          Max Kruse  5.01754
# 7   Midfielder       Arjen Robben  4.92523
# 8   Midfielder         Marco Reus  4.80645
# 9      Forward       Lionel Messi  8.25595
# 10     Forward  Cristiano Ronaldo  7.92683
#
#                                            photo overall
# 0   https://cdn.sofifa.org/18/players/200389.png      92
# 1   https://cdn.sofifa.org/18/players/197445.png      90
# 2   https://cdn.sofifa.org/18/players/220477.png      90
# 3   https://cdn.sofifa.org/18/players/202493.png      90
# 4   https://cdn.sofifa.org/18/players/191043.png      90
# 5   https://cdn.sofifa.org/18/players/173731.png      90
# ...

# %%
def XI(position):
    SquadDB = RQ4_Youth.copy()
    
    store = []
    for x in position:
        
        store.append([ x ,SquadDB.loc[[SquadDB[SquadDB['Position'] == x ]['Average Form'].idxmax()]]['Players'].to_string(index = False), SquadDB[SquadDB['Position'] == x ]['Average Form'].max(),SquadDB[SquadDB['Position'] == x ]['photo'].unique(),SquadDB[SquadDB['Position'] == x ]['overall'].max()])
        
        SquadDB.drop(SquadDB[SquadDB['Position'] == x ]['Average Form'].idxmax(), inplace = True)
     
    return pd.DataFrame(np.array(store).reshape(11,5), columns = ['Position', 'Players','Average Form','photo','overall']).to_string(index = False)

XI442 = ['Goalkeeper', 'Defender', 'Defender', 'Defender', 'Defender', 'Midfielder', 'Midfielder', 'Midfielder', 'Midfielder', 'Forward', 'Forward']

RQ4Youth = (XI(XI442))

# %%
RQ4Youth = RQ4Youth.replace('h...','')
RQ4Youth = RQ4Youth.replace('...','')
RQ4Youth = RQ4Youth.replace('[','')
RQ4Youth = RQ4Youth.replace(',','')
lst = RQ4Youth.split()
data = [lst[pos:pos+6] for pos in range(0, len(lst), 6)]
RQ4Youth = pd.DataFrame(data[1:], columns=data[0])
RQ4Youth['Players'] = RQ4Youth['Players'] +' ' +  RQ4Youth['Average']
RQ4Youth = RQ4Youth.drop('Average',1)

# %%
RQ4Youth
# Out:
#       Position               Players     Form  \
# 0   Goalkeeper  Gianluigi Donnarumma  2.97059
# 1     Defender             Issa Diop  3.01961
# 2     Defender   Timothy Fosu-Mensah  2.83333
# 3     Defender         Joris Gnagnon  2.41176
# 4     Defender       Davide Calabria  2.05263
# 5   Midfielder       Ousmane Dembele  3.96552
# 6   Midfielder     Christian Pulisic  2.57895
# 7   Midfielder   Adalberto Penaranda  2.54839
# 8   Midfielder          Nadiem Amiri  2.35385
# 9      Forward       Marcus Rashford  2.93023
# 10     Forward     Kelechi Iheanacho  2.80435
#
#                                            photo overall
# 0   https://cdn.sofifa.org/18/players/230621.png      82
# 1   https://cdn.sofifa.org/18/players/231633.png      78
# 2   https://cdn.sofifa.org/18/players/232270.png      78
# 3   https://cdn.sofifa.org/18/players/231361.png      78
# 4   https://cdn.sofifa.org/18/players/228881.png      78
# 5   https://cdn.sofifa.org/18/players/231443.png      83
# ...

# %%
def XI(position):
    SquadDB = RQ4_Oldies.copy()
    
    store = []
    for x in position:
        
        store.append([ x ,SquadDB.loc[[SquadDB[SquadDB['Position'] == x ]['Average Form'].idxmax()]]['Players'].to_string(index = False), SquadDB[SquadDB['Position'] == x ]['Average Form'].max(),SquadDB[SquadDB['Position'] == x ]['photo'].unique(),SquadDB[SquadDB['Position'] == x ]['overall'].max()])
        
        SquadDB.drop(SquadDB[SquadDB['Position'] == x ]['Average Form'].idxmax(), inplace = True)
     
    return pd.DataFrame(np.array(store).reshape(11,5), columns = ['Position', 'Players','Average Form','photo','overall']).to_string(index = False)

XI442 = ['Goalkeeper', 'Defender', 'Defender', 'Defender', 'Defender', 'Midfielder', 'Midfielder', 'Midfielder', 'Midfielder', 'Forward', 'Forward']

RQ4Oldies = (XI(XI442))

# %%
overrated_players= overrated.replace('h...','')
overrated_players= overrated.replace('...','')
overrated_players= overrated.replace('[','')
overrated_players= overrated.replace(',','')
lst = overrated_players.split()
data = [lst[pos:pos+6] for pos in range(0, len(lst), 6)]
overrated_players= pd.DataFrame(data[1:], columns=data[0])
overrated ['Players'] = overrated ['Players'] +' ' +  overrated ['Average']
overrated_players= overrated.drop('Average',1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00aafd23a970> in <module>()
# ----> 1 overrated_players= overrated.replace('h...','')
#       2 overrated_players= overrated.replace('...','')
#       3 overrated_players= overrated.replace('[','')
#       4 overrated_players= overrated.replace(',','')
#       5 lst = overrated_players.split()
#
# NameError: name 'overrated' is not defined

# %%
RQ4Oldies
# Out:
#       Position            Players     Form  \
# 0   Goalkeeper         Tom Starke      4.5
# 1     Defender        Diego Godin  4.13939
# 2     Defender  Giorgio Chiellini    4.125
# 3     Defender        Ashley Cole        4
# 4     Defender        Filipe Luis  3.95862
# 5   Midfielder       Arjen Robben  4.92523
# 6   Midfielder      Franck Ribery  4.63636
# 7   Midfielder    Alexander Meier  4.56303
# 8   Midfielder      Dimitri Payet  4.00578
# 9      Forward       Lionel Messi  8.25595
# 10     Forward  Cristiano Ronaldo  7.92683
#
#                                            photo overall
# 0   https://cdn.sofifa.org/18/players/107713.png      92
# 1   https://cdn.sofifa.org/18/players/182493.png      90
# 2   https://cdn.sofifa.org/18/players/138956.png      90
# 3    https://cdn.sofifa.org/18/players/34079.png      90
# 4   https://cdn.sofifa.org/18/players/164169.png      90
# 5     https://cdn.sofifa.org/18/players/9014.png      89
# ...

# %%
RQ4Oldies = RQ4Oldies.reset_index()
RQ4Oldies = RQ4Oldies.drop('index',1)
RQ4Oldies['Form'] = RQ4Oldies['Form'].astype(float)
RQ4Oldies['Form'] = RQ4Oldies['Form'].round(2)
RQ4Oldies[['Form','overall']] = RQ4Oldies[['Form','overall']].astype(str)
RQ4Oldies['photo'] = RQ4Oldies['photo'].replace('/18/','/1x/18/', regex=True)
RQ4Best = RQ4Best.reset_index()
RQ4Best = RQ4Best.drop('index',1)
RQ4Best['Form'] = RQ4Best['Form'].astype(float)
RQ4Best['Form'] = RQ4Best['Form'].round(2)
RQ4Best[['Form','overall']] = RQ4Best[['Form','overall']].astype(str)
RQ4Best['photo'] = RQ4Best['photo'].replace('/18/','/1x/18/', regex=True)

RQ4Youth = RQ4Youth.reset_index()
RQ4Youth = RQ4Youth.drop('index',1)
RQ4Youth['Form'] = RQ4Youth['Form'].astype(float)
RQ4Youth['Form'] = RQ4Youth['Form'].round(2)
RQ4Youth[['Form','overall']] = RQ4Youth[['Form','overall']].astype(str)
RQ4Youth['photo'] = RQ4Youth['photo'].replace('/18/','/1x/18/', regex=True)

# %%
Best_Squad_Rating = (RQ4_Best_Top_FW_Sum.iloc[0]+ RQ4_Best_Top_FW_Sum.iloc[1]  +RQ4_Best_Top_DF_Sum.iloc[0] +RQ4_Best_Top_DF_Sum.iloc[1] +RQ4_Best_Top_DF_Sum.iloc[2] +RQ4_Best_Top_DF_Sum.iloc[3]+RQ4_Best_Top_MD_Sum.iloc[0]+ RQ4_Best_Top_MD_Sum.iloc[1]+ RQ4_Best_Top_MD_Sum.iloc[2]+ RQ4_Best_Top_MD_Sum.iloc[3]+RQ4_Best_Top_GK_Sum.iloc[0])/11
Oldies_Squad_Rating = (RQ4_Oldies_Top_FW_Sum.iloc[0]+ RQ4_Oldies_Top_FW_Sum.iloc[1]  +RQ4_Oldies_Top_DF_Sum.iloc[0] +RQ4_Oldies_Top_DF_Sum.iloc[1] +RQ4_Oldies_Top_DF_Sum.iloc[2] +RQ4_Oldies_Top_DF_Sum.iloc[3]+RQ4_Oldies_Top_MD_Sum.iloc[0]+ RQ4_Oldies_Top_MD_Sum.iloc[1]+ RQ4_Oldies_Top_MD_Sum.iloc[2]+ RQ4_Oldies_Top_MD_Sum.iloc[3]+RQ4_Oldies_Top_GK_Sum.iloc[0])/11
Youth_Squad_Rating = (RQ4_Youth_Top_FW_Sum.iloc[0]+ RQ4_Youth_Top_FW_Sum.iloc[1]  +RQ4_Youth_Top_DF_Sum.iloc[0] +RQ4_Youth_Top_DF_Sum.iloc[1] +RQ4_Youth_Top_DF_Sum.iloc[2] +RQ4_Youth_Top_DF_Sum.iloc[3]+RQ4_Youth_Top_MD_Sum.iloc[0]+ RQ4_Youth_Top_MD_Sum.iloc[1]+ RQ4_Youth_Top_MD_Sum.iloc[2]+ RQ4_Youth_Top_MD_Sum.iloc[3]+RQ4_Youth_Top_GK_Sum.iloc[0])/11

Best_Squad_Rating = Best_Squad_Rating.round(0)
Oldies_Squad_Rating = Oldies_Squad_Rating.round(0)
Youth_Squad_Rating = Youth_Squad_Rating.round(0)

Best_Squad_Rating = Best_Squad_Rating.astype(int)
Oldies_Squad_Rating = Oldies_Squad_Rating.astype(int)
Youth_Squad_Rating = Youth_Squad_Rating.astype(int)

Youth_Squad_Rating = Youth_Squad_Rating.astype(str)
Oldies_Squad_Rating = Oldies_Squad_Rating.astype(str)
Best_Squad_Rating = Best_Squad_Rating.astype(str)

# %%
JoinedBestImages = RQ4Best['photo'].as_matrix()

GK1 = mpimg.imread(JoinedBestImages[0])
DF1 = mpimg.imread(JoinedBestImages[1])
DF2 = mpimg.imread(JoinedBestImages[2])
DF3 = mpimg.imread(JoinedBestImages[3])
DF4 = mpimg.imread(JoinedBestImages[4])
MD1 = mpimg.imread(JoinedBestImages[5])
MD2 = mpimg.imread(JoinedBestImages[6])
MD3 = mpimg.imread(JoinedBestImages[7])
MD4 = mpimg.imread(JoinedBestImages[8])
FW1 = mpimg.imread(JoinedBestImages[9])
FW2 = mpimg.imread(JoinedBestImages[10])

# %%
f, axarr = plt.subplots(4,7,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()
axarr[0,0].set_visible(False)
axarr[0,1].set_visible(False)
axarr[0,3].set_visible(False)
axarr[0,5].set_visible(False)
axarr[0,6].set_visible(False)
axarr[1,0].set_visible(False)
axarr[1,1].set_visible(False)
axarr[1,4].set_visible(False)
axarr[2,0].set_visible(False)
axarr[2,1].set_visible(False)
axarr[2,4].set_visible(False)
axarr[3,0].set_visible(False)
axarr[3,1].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,6].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,2].set_visible(False)
axarr[3,6].set_visible(False)


axarr[0,2].set_title('Squad Rating: ' + Best_Squad_Rating)
axarr[0,2].axis('off')

axarr[0,4].imshow(GK1)
axarr[0,4].set_title(RQ4Best['Players'].loc[0] + '\n' + ' Form: ' + RQ4Best['Form'].loc[0] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_GK_Str.iloc[0])
axarr[0,4].axis('off')


axarr[1,2].imshow(DF1)
axarr[1,2].set_title(RQ4Best['Players'].loc[1] + '\n' + ' Form: ' + RQ4Best['Form'].loc[1] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_DF_Str.iloc[0])
axarr[1,2].axis('off')


axarr[1,3].imshow(DF2)
axarr[1,3].set_title(RQ4Best['Players'].loc[2] + '\n' + ' Form: ' + RQ4Best['Form'].loc[2] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_DF_Str.iloc[1])
axarr[1,3].axis('off')


axarr[1,5].imshow(DF3)
axarr[1,5].set_title(RQ4Best['Players'].loc[3] + '\n' + ' Form: ' + RQ4Best['Form'].loc[3] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_DF_Str.iloc[2])
axarr[1,5].axis('off')


axarr[1,6].imshow(DF4)
axarr[1,6].set_title(RQ4Best['Players'].loc[4] + '\n' + ' Form: ' + RQ4Best['Form'].loc[4] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_DF_Str.iloc[3])
axarr[1,6].axis('off')


axarr[2,2].imshow(MD1)
axarr[2,2].set_title(RQ4Best['Players'].loc[5] + '\n' + ' Form: ' + RQ4Best['Form'].loc[5] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_MD_Str.iloc[0])
axarr[2,2].axis('off')


axarr[2,3].imshow(MD2)
axarr[2,3].set_title(RQ4Best['Players'].loc[6] + '\n' + ' Form: ' + RQ4Best['Form'].loc[6] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_MD_Str.iloc[1])
axarr[2,3].axis('off')


axarr[2,5].imshow(MD3)
axarr[2,5].set_title(RQ4Best['Players'].loc[7] + '\n' + ' Form: ' + RQ4Best['Form'].loc[7] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_MD_Str.iloc[2])
axarr[2,5].axis('off')


axarr[2,6].imshow(MD4)
axarr[2,6].set_title(RQ4Best['Players'].loc[8] + '\n' + ' Form: ' + RQ4Best['Form'].loc[8] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_MD_Str.iloc[3])
axarr[2,6].axis('off')


axarr[3,3].imshow(FW1)
axarr[3,3].set_title(RQ4Best['Players'].loc[9] + '\n' + ' Form: ' + RQ4Best['Form'].loc[9] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_FW_Str.iloc[0])
axarr[3,3].axis('off')

axarr[3,5].imshow(FW2)
axarr[3,5].set_title(RQ4Best['Players'].loc[10] + '\n' + ' Form: ' + RQ4Best['Form'].loc[10] + '\n' + ' FIFA Overall: ' + RQ4_Best_Top_FW_Str.iloc[0])
axarr[3,5].axis('off')

f.savefig('../../data/analysis/Best.png')

# %%
RQ4Youth
# Out:
#       Position               Players  Form  \
# 0   Goalkeeper  Gianluigi Donnarumma  2.97
# 1     Defender             Issa Diop  3.02
# 2     Defender   Timothy Fosu-Mensah  2.83
# 3     Defender         Joris Gnagnon  2.41
# 4     Defender       Davide Calabria  2.05
# 5   Midfielder       Ousmane Dembele  3.97
# 6   Midfielder     Christian Pulisic  2.58
# 7   Midfielder   Adalberto Penaranda  2.55
# 8   Midfielder          Nadiem Amiri  2.35
# 9      Forward       Marcus Rashford  2.93
# 10     Forward     Kelechi Iheanacho   2.8
#
#                                               photo overall
# 0   https://cdn.sofifa.org/1x/18/players/230621.png      82
# 1   https://cdn.sofifa.org/1x/18/players/231633.png      78
# 2   https://cdn.sofifa.org/1x/18/players/232270.png      78
# 3   https://cdn.sofifa.org/1x/18/players/231361.png      78
# 4   https://cdn.sofifa.org/1x/18/players/228881.png      78
# 5   https://cdn.sofifa.org/1x/18/players/231443.png      83
# ...

# %%
JoinedYouthImages = RQ4Youth['photo'].as_matrix()

GK1 = mpimg.imread(JoinedYouthImages[0])
DF1 = mpimg.imread(JoinedYouthImages[1])
DF2 = mpimg.imread(JoinedYouthImages[2])
DF3 = mpimg.imread(JoinedYouthImages[3])
DF4 = mpimg.imread(JoinedYouthImages[4])
MD1 = mpimg.imread(JoinedYouthImages[5])
MD2 = mpimg.imread(JoinedYouthImages[6])
MD3 = mpimg.imread(JoinedYouthImages[7])
MD4 = mpimg.imread(JoinedYouthImages[8])
FW1 = mpimg.imread(JoinedYouthImages[9])
FW2 = mpimg.imread(JoinedYouthImages[10])

# %%
f, axarr = plt.subplots(4,7,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()
axarr[0,0].set_visible(False)
axarr[0,1].set_visible(False)
axarr[0,3].set_visible(False)
axarr[0,5].set_visible(False)
axarr[0,6].set_visible(False)
axarr[1,0].set_visible(False)
axarr[1,1].set_visible(False)
axarr[1,4].set_visible(False)
axarr[2,0].set_visible(False)
axarr[2,1].set_visible(False)
axarr[2,4].set_visible(False)
axarr[3,0].set_visible(False)
axarr[3,1].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,6].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,2].set_visible(False)
axarr[3,6].set_visible(False)


axarr[0,2].set_title('Squad Rating: ' + Youth_Squad_Rating)
axarr[0,2].axis('off')

axarr[0,4].imshow(GK1)
axarr[0,4].set_title(RQ4Youth['Players'].loc[0] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[0] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_GK_Str.iloc[0])
axarr[0,4].axis('off')


axarr[1,2].imshow(DF1)
axarr[1,2].set_title(RQ4Youth['Players'].loc[1] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[1] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_DF_Str.iloc[0])
axarr[1,2].axis('off')


axarr[1,3].imshow(DF2)
axarr[1,3].set_title(RQ4Youth['Players'].loc[2] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[2] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_DF_Str.iloc[1])
axarr[1,3].axis('off')


axarr[1,5].imshow(DF3)
axarr[1,5].set_title(RQ4Youth['Players'].loc[3] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[3] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_DF_Str.iloc[2])
axarr[1,5].axis('off')


axarr[1,6].imshow(DF4)
axarr[1,6].set_title(RQ4Youth['Players'].loc[4] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[4] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_DF_Str.iloc[3])
axarr[1,6].axis('off')


axarr[2,2].imshow(MD1)
axarr[2,2].set_title(RQ4Youth['Players'].loc[5] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[5] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_MD_Str.iloc[0])
axarr[2,2].axis('off')


axarr[2,3].imshow(MD2)
axarr[2,3].set_title(RQ4Youth['Players'].loc[6] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[6] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_MD_Str.iloc[1])
axarr[2,3].axis('off')


axarr[2,5].imshow(MD3)
axarr[2,5].set_title(RQ4Youth['Players'].loc[7] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[7] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_MD_Str.iloc[2])
axarr[2,5].axis('off')


axarr[2,6].imshow(MD4)
axarr[2,6].set_title(RQ4Youth['Players'].loc[8] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[8] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_MD_Str.iloc[3])
axarr[2,6].axis('off')


axarr[3,3].imshow(FW1)
axarr[3,3].set_title(RQ4Youth['Players'].loc[9] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[9] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_FW_Str.iloc[0])
axarr[3,3].axis('off')

axarr[3,5].imshow(FW2)
axarr[3,5].set_title(RQ4Youth['Players'].loc[10] + '\n' + ' Form: ' + RQ4Youth['Form'].loc[10] + '\n' + ' FIFA Overall: ' + RQ4_Youth_Top_FW_Str.iloc[0])
axarr[3,5].axis('off')

f.savefig('../../data/analysis/Youth.png')

# %%
JoinedOldiesImages = RQ4Oldies['photo'].as_matrix()

GK1 = mpimg.imread(JoinedOldiesImages[0])
DF1 = mpimg.imread(JoinedOldiesImages[1])
DF2 = mpimg.imread(JoinedOldiesImages[2])
DF3 = mpimg.imread(JoinedOldiesImages[3])
DF4 = mpimg.imread(JoinedOldiesImages[4])
MD1 = mpimg.imread(JoinedOldiesImages[5])
MD2 = mpimg.imread(JoinedOldiesImages[6])
MD3 = mpimg.imread(JoinedOldiesImages[7])
MD4 = mpimg.imread(JoinedOldiesImages[8])
FW1 = mpimg.imread(JoinedOldiesImages[9])
FW2 = mpimg.imread(JoinedOldiesImages[10])

# %%
RQ4Oldies['overall'].sum()
# Out:
# '9290909090898989899494'

# %%
f, axarr = plt.subplots(4,7,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()
axarr[0,0].set_visible(False)
axarr[0,1].set_visible(False)
axarr[0,3].set_visible(False)
axarr[0,5].set_visible(False)
axarr[0,6].set_visible(False)
axarr[1,0].set_visible(False)
axarr[1,1].set_visible(False)
axarr[1,4].set_visible(False)
axarr[2,0].set_visible(False)
axarr[2,1].set_visible(False)
axarr[2,4].set_visible(False)
axarr[3,0].set_visible(False)
axarr[3,1].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,6].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,2].set_visible(False)
axarr[3,6].set_visible(False)


axarr[0,2].set_title('Squad Rating: ' + Oldies_Squad_Rating)
axarr[0,2].axis('off')

axarr[0,4].imshow(GK1)
axarr[0,4].set_title(RQ4Oldies['Players'].loc[0] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[0] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_GK_Str.iloc[0])
axarr[0,4].axis('off')


axarr[1,2].imshow(DF1)
axarr[1,2].set_title(RQ4Oldies['Players'].loc[1] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[1] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_DF_Str.iloc[0])
axarr[1,2].axis('off')


axarr[1,3].imshow(DF2)
axarr[1,3].set_title(RQ4Oldies['Players'].loc[2] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[2] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_DF_Str.iloc[1])
axarr[1,3].axis('off')


axarr[1,5].imshow(DF3)
axarr[1,5].set_title(RQ4Oldies['Players'].loc[3] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[3] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_DF_Str.iloc[2])
axarr[1,5].axis('off')


axarr[1,6].imshow(DF4)
axarr[1,6].set_title(RQ4Oldies['Players'].loc[4] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[4] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_DF_Str.iloc[3])
axarr[1,6].axis('off')


axarr[2,2].imshow(MD1)
axarr[2,2].set_title(RQ4Oldies['Players'].loc[5] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[5] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_MD_Str.iloc[0])
axarr[2,2].axis('off')


axarr[2,3].imshow(MD2)
axarr[2,3].set_title(RQ4Oldies['Players'].loc[6] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[6] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_MD_Str.iloc[1])
axarr[2,3].axis('off')


axarr[2,5].imshow(MD3)
axarr[2,5].set_title(RQ4Oldies['Players'].loc[7] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[7] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_MD_Str.iloc[2])
axarr[2,5].axis('off')


axarr[2,6].imshow(MD4)
axarr[2,6].set_title(RQ4Oldies['Players'].loc[8] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[8] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_MD_Str.iloc[3])
axarr[2,6].axis('off')


axarr[3,3].imshow(FW1)
axarr[3,3].set_title(RQ4Oldies['Players'].loc[9] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[9] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_FW_Str.iloc[0])
axarr[3,3].axis('off')

axarr[3,5].imshow(FW2)
axarr[3,5].set_title(RQ4Oldies['Players'].loc[10] + '\n' + ' Form: ' + RQ4Oldies['Form'].loc[10] + '\n' + ' FIFA Overall: ' + RQ4_Oldies_Top_FW_Str.iloc[0])
axarr[3,5].axis('off')

f.savefig('../../data/analysis/Oldies.png')

# %%
RQ4 = RQ4.sort_values(['overall','Players'],ascending=False)
RQ4 = RQ4.reset_index()
RQ4['Form'] = RQ4['Average Form']
RQ4.drop(RQ4.columns[[0,11]], axis=1, inplace=True)
RQ4.head(10)
RQ4_Best = RQ4[RQ4['age']<34] #best players
RQ4_Youth = RQ4[RQ4['age']<=20] #best young players
RQ4_Oldies = RQ4[RQ4['age']>29] #best old players

# %%
RQ4_Best['photo'] = RQ4_Best['photo'].astype(str)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
def XI(position):
    SquadDB = RQ4_Best.copy()
    
    store = []
    for x in position:
        
        store.append([ x ,SquadDB.loc[[SquadDB[SquadDB['Position'] == x ]['overall'].idxmax()]]['Players'].to_string(index = False), SquadDB[SquadDB['Position'] == x ]['overall'].max(),SquadDB[SquadDB['Position'] == x ]['photo'].unique()])
        
        SquadDB.drop(SquadDB[SquadDB['Position'] == x ]['overall'].idxmax(), inplace = True)
     
    return pd.DataFrame(np.array(store).reshape(11,4), columns = ['Position', 'Players','overall','photo']).to_string(index = False)

XI442 = ['Goalkeeper', 'Defender', 'Defender', 'Defender', 'Defender', 'Midfielder', 'Midfielder', 'Midfielder', 'Midfielder', 'Forward', 'Forward']

RQ4Best2 = (XI(XI442))


def XI(position):
    SquadDB = RQ4_Oldies.copy()
    
    store = []
    for x in position:
        
        store.append([ x ,SquadDB.loc[[SquadDB[SquadDB['Position'] == x ]['overall'].idxmax()]]['Players'].to_string(index = False), SquadDB[SquadDB['Position'] == x ]['overall'].max(),SquadDB[SquadDB['Position'] == x ]['photo'].unique()])
        
        SquadDB.drop(SquadDB[SquadDB['Position'] == x ]['overall'].idxmax(), inplace = True)
     
    return pd.DataFrame(np.array(store).reshape(11,4), columns = ['Position', 'Players','overall','photo']).to_string(index = False)

XI442 = ['Goalkeeper', 'Defender', 'Defender', 'Defender', 'Defender', 'Midfielder', 'Midfielder', 'Midfielder', 'Midfielder', 'Forward', 'Forward']

RQ4Oldies2 = (XI(XI442))


def XI(position):
    SquadDB = RQ4_Youth.copy()
    
    store = []
    for x in position:
        
        store.append([ x ,SquadDB.loc[[SquadDB[SquadDB['Position'] == x ]['overall'].idxmax()]]['Players'].to_string(index = False), SquadDB[SquadDB['Position'] == x ]['overall'].max(),SquadDB[SquadDB['Position'] == x ]['photo'].unique()])
        
        SquadDB.drop(SquadDB[SquadDB['Position'] == x ]['overall'].idxmax(), inplace = True)
     
    return pd.DataFrame(np.array(store).reshape(11,4), columns = ['Position', 'Players','overall','photo']).to_string(index = False)

XI442 = ['Goalkeeper', 'Defender', 'Defender', 'Defender', 'Defender', 'Midfielder', 'Midfielder', 'Midfielder', 'Midfielder', 'Forward', 'Forward']

RQ4Youth2 = (XI(XI442))

# %%
RQ4Best2 = RQ4Best2.replace('h...','')
RQ4Best2 = RQ4Best2.replace('...','')
RQ4Best2 = RQ4Best2.replace('[','')
RQ4Best2 = RQ4Best2.replace(',','')
RQ4Best2 = RQ4Best2.replace('De Bruyne','De-Bruyne')
lst = RQ4Best2.split()
data = [lst[pos:pos+5] for pos in range(0, len(lst), 5)]
RQ4Best2 = pd.DataFrame(data[1:], columns=data[0])
RQ4Best2['Goalkeeper'] = RQ4Best2['Goalkeeper'].shift(1)
cols = RQ4Best2.columns.tolist()
cols = cols[-1:] + cols[:-1]
RQ4Best2 = RQ4Best2[cols]
RQ4Best2 = RQ4Best2.fillna('Goalkeeper')

RQ4Youth2 = RQ4Youth2.replace('h...','')
RQ4Youth2 = RQ4Youth2.replace('...','')
RQ4Youth2 = RQ4Youth2.replace('[','')
RQ4Youth2 = RQ4Youth2.replace(',','')
RQ4Youth2 = RQ4Youth2.replace('De Bruyne','De-Bruyne')
lst = RQ4Youth2.split()
data = [lst[pos:pos+5] for pos in range(0, len(lst), 5)]
RQ4Youth2 = pd.DataFrame(data[1:], columns=data[0])
RQ4Youth2['Goalkeeper'] = RQ4Youth2['Goalkeeper'].shift(1)
cols = RQ4Youth2.columns.tolist()
cols = cols[-1:] + cols[:-1]
RQ4Youth2 = RQ4Youth2[cols]
RQ4Youth2 = RQ4Youth2.fillna('Goalkeeper')

RQ4Oldies2 = RQ4Oldies2.replace('h...','')
RQ4Oldies2 = RQ4Oldies2.replace('...','')
RQ4Oldies2 = RQ4Oldies2.replace('[','')
RQ4Oldies2 = RQ4Oldies2.replace(',','')
RQ4Oldies2 = RQ4Oldies2.replace('De Bruyne','De-Bruyne')
lst = RQ4Oldies2.split()
data = [lst[pos:pos+5] for pos in range(0, len(lst), 5)]
RQ4Oldies2 = pd.DataFrame(data[1:], columns=data[0])
RQ4Oldies2['Goalkeeper'] = RQ4Oldies2['Goalkeeper'].shift(1)
cols = RQ4Oldies2.columns.tolist()
cols = cols[-1:] + cols[:-1]
RQ4Oldies2 = RQ4Oldies2[cols]
RQ4Oldies2 = RQ4Oldies2.fillna('Goalkeeper')

# %%
RQ4Oldies2
# Out:
#     Goalkeeper   Position    Players overall  \
# 0   Goalkeeper     Manuel      Neuer      92
# 1     Defender     Sergio      Ramos      90
# 2     Defender    Giorgio  Chiellini      89
# 3     Defender     Thiago      Silva      88
# 4     Defender   Leonardo    Bonucci      88
# 5   Midfielder       Luka     Modric      89
# 6   Midfielder      Arjen     Robben      88
# 7   Midfielder      David      Silva      87
# 8   Midfielder     Arturo      Vidal      87
# 9      Forward  Cristiano    Ronaldo      94
# 10     Forward     Lionel      Messi      93
#
#                                            photo
# 0   https://cdn.sofifa.org/18/players/167495.png
# 1   https://cdn.sofifa.org/18/players/155862.png
# 2   https://cdn.sofifa.org/18/players/138956.png
# 3   https://cdn.sofifa.org/18/players/164240.png
# 4   https://cdn.sofifa.org/18/players/184344.png
# 5   https://cdn.sofifa.org/18/players/177003.png
# 6     https://cdn.sofifa.org/18/players/9014.png
# ...

# %%
RQ4Best2 = RQ4Best2.reset_index()
RQ4Best2 = RQ4Best2.drop('index',1)
RQ4Best2['Players'] = RQ4Best2['Position'] + ' ' + RQ4Best2['Players']
RQ4Best2['Position'] = RQ4Best2[['Goalkeeper']]
RQ4Best2['overall'] = RQ4Best2['overall'].astype(str)
RQ4Best2 = RQ4Best2.drop('Goalkeeper',1)
RQ4Best2['photo'] = RQ4Best2['photo'].replace('/18/','/1x/18/', regex=True)

RQ4Youth2 = RQ4Youth2.reset_index()
RQ4Youth2 = RQ4Youth2.drop('index',1)
RQ4Youth2['Players'] = RQ4Youth2['Position'] + ' ' + RQ4Youth2['Players']
RQ4Youth2['Position'] = RQ4Youth2[['Goalkeeper']]
RQ4Youth2['overall'] = RQ4Youth2['overall'].astype(str)
RQ4Youth2 = RQ4Youth2.drop('Goalkeeper',1)
RQ4Youth2['photo'] = RQ4Youth2['photo'].replace('/18/','/1x/18/', regex=True)


RQ4Oldies2 = RQ4Oldies2.reset_index()
RQ4Oldies2 = RQ4Oldies2.drop('index',1)
RQ4Oldies2['Players'] = RQ4Oldies2['Position'] + ' ' + RQ4Oldies2['Players']
RQ4Oldies2['Position'] = RQ4Oldies2[['Goalkeeper']]
RQ4Oldies2['overall'] = RQ4Oldies2['overall'].astype(str)
RQ4Oldies2 = RQ4Oldies2.drop('Goalkeeper',1)
RQ4Oldies2['photo'] = RQ4Oldies2['photo'].replace('/18/','/1x/18/', regex=True)

# %%
RQ4Best2
# Out:
#       Position            Players overall  \
# 0   Goalkeeper       Manuel Neuer      92
# 1     Defender       Sergio Ramos      90
# 2     Defender  Giorgio Chiellini      89
# 3     Defender       Thiago Silva      88
# 4     Defender       Mats Hummels      88
# 5   Midfielder         Toni Kroos      90
# 6   Midfielder        Eden Hazard      90
# 7   Midfielder        Luka Modric      89
# 8   Midfielder    Kevin De-Bruyne      89
# 9      Forward  Cristiano Ronaldo      94
# 10     Forward       Lionel Messi      93
#
#                                               photo
# 0   https://cdn.sofifa.org/1x/18/players/167495.png
# 1   https://cdn.sofifa.org/1x/18/players/155862.png
# 2   https://cdn.sofifa.org/1x/18/players/138956.png
# 3   https://cdn.sofifa.org/1x/18/players/164240.png
# 4   https://cdn.sofifa.org/1x/18/players/178603.png
# 5   https://cdn.sofifa.org/1x/18/players/182521.png
# 6   https://cdn.sofifa.org/1x/18/players/183277.png
# ...

# %%
RQ4_Best2 = RQ4_Best
RQ4_Youth2 = RQ4_Youth
RQ4_Oldies2 = RQ4_Oldies

RQ4_Best2_Top = RQ4_Best2.sort_values(['Form'], ascending=[False])
RQ4_Best2_Top_GK = RQ4_Best2.loc[RQ4_Best2.Position=='Goalkeeper']
RQ4_Best2_Top_GK_Str = RQ4_Best2_Top_GK['overall'].astype(str) 
RQ4_Best2_Top_GK_Sum = RQ4_Best2_Top_GK['overall'].astype(float) 

RQ4_Best2_Top = RQ4_Best2.sort_values(['Form'], ascending=[False])
RQ4_Best2_Top_DF = RQ4_Best2.loc[RQ4_Best2.Position=='Defender']
RQ4_Best2_Top_DF_Str = RQ4_Best2_Top_DF['overall'].astype(str)
RQ4_Best2_Top_DF_Sum = RQ4_Best2_Top_DF['overall'].astype(float) 

RQ4_Best2_Top = RQ4_Best2.sort_values(['Form'], ascending=[False])
RQ4_Best2_Top_MD = RQ4_Best2.loc[RQ4_Best2.Position=='Midfielder']
RQ4_Best2_Top_MD_Str = RQ4_Best2_Top_MD['overall'].astype(str)
RQ4_Best2_Top_MD_Sum = RQ4_Best2_Top_MD['overall'].astype(float) 

RQ4_Best2_Top = RQ4_Best2.sort_values(['Form'], ascending=[False])
RQ4_Best2_Top_FW = RQ4_Best2.loc[RQ4_Best2.Position=='Forward']
RQ4_Best2_Top_FW_Str = RQ4_Best2_Top_FW['overall'].astype(str)
RQ4_Best2_Top_FW_Sum = RQ4_Best2_Top_FW['overall'].astype(float) 

RQ4_Youth2_Top = RQ4_Youth2.sort_values(['Form'], ascending=[False])
RQ4_Youth2_Top_GK = RQ4_Youth2.loc[RQ4_Youth2.Position=='Goalkeeper']
RQ4_Youth2_Top_GK_Str = RQ4_Youth2_Top_GK['overall'].astype(str) 
RQ4_Youth2_Top_GK_Sum = RQ4_Youth2_Top_GK['overall'].astype(float) 

RQ4_Youth2_Top = RQ4_Youth2.sort_values(['Form'], ascending=[False])
RQ4_Youth2_Top_DF = RQ4_Youth2.loc[RQ4_Youth2.Position=='Defender']
RQ4_Youth2_Top_DF_Str = RQ4_Youth2_Top_DF['overall'].astype(str)
RQ4_Youth2_Top_DF_Sum = RQ4_Youth2_Top_DF['overall'].astype(float) 

RQ4_Youth2_Top = RQ4_Youth2.sort_values(['Form'], ascending=[False])
RQ4_Youth2_Top_MD = RQ4_Youth2.loc[RQ4_Youth2.Position=='Midfielder']
RQ4_Youth2_Top_MD_Str = RQ4_Youth2_Top_MD['overall'].astype(str)
RQ4_Youth2_Top_MD_Sum = RQ4_Youth2_Top_MD['overall'].astype(float) 

RQ4_Youth2_Top = RQ4_Youth2.sort_values(['Form'], ascending=[False])
RQ4_Youth2_Top_FW = RQ4_Youth2.loc[RQ4_Youth2.Position=='Forward']
RQ4_Youth2_Top_FW_Str = RQ4_Youth2_Top_FW['overall'].astype(str)
RQ4_Youth2_Top_FW_Sum = RQ4_Youth2_Top_FW['overall'].astype(float)

RQ4_Oldies2_Top = RQ4_Oldies2.sort_values(['Form'], ascending=[False])
RQ4_Oldies2_Top_GK = RQ4_Oldies2.loc[RQ4_Oldies2.Position=='Goalkeeper']
RQ4_Oldies2_Top_GK_Str = RQ4_Oldies2_Top_GK['overall'].astype(str) 
RQ4_Oldies2_Top_GK_Sum = RQ4_Oldies2_Top_GK['overall'].astype(float) 

RQ4_Oldies2_Top = RQ4_Oldies2.sort_values(['Form'], ascending=[False])
RQ4_Oldies2_Top_DF = RQ4_Oldies2.loc[RQ4_Oldies2.Position=='Defender']
RQ4_Oldies2_Top_DF_Str = RQ4_Oldies2_Top_DF['overall'].astype(str)
RQ4_Oldies2_Top_DF_Sum = RQ4_Oldies2_Top_DF['overall'].astype(float) 

RQ4_Oldies2_Top = RQ4_Oldies2.sort_values(['Form'], ascending=[False])
RQ4_Oldies2_Top_MD = RQ4_Oldies2.loc[RQ4_Oldies2.Position=='Midfielder']
RQ4_Oldies2_Top_MD_Str = RQ4_Oldies2_Top_MD['overall'].astype(str)
RQ4_Oldies2_Top_MD_Sum = RQ4_Oldies2_Top_MD['overall'].astype(float) 

RQ4_Oldies2_Top = RQ4_Oldies2.sort_values(['Form'], ascending=[False])
RQ4_Oldies2_Top_FW = RQ4_Oldies2.loc[RQ4_Oldies2.Position=='Forward']
RQ4_Oldies2_Top_FW_Str = RQ4_Oldies2_Top_FW['overall'].astype(str)
RQ4_Oldies2_Top_FW_Sum = RQ4_Oldies2_Top_FW['overall'].astype(float)

# %%
Best2_Squad_Rating = (RQ4_Best2_Top_FW_Sum.iloc[0]+ RQ4_Best2_Top_FW_Sum.iloc[1]  +RQ4_Best2_Top_DF_Sum.iloc[0] +RQ4_Best2_Top_DF_Sum.iloc[1] +RQ4_Best2_Top_DF_Sum.iloc[2] +RQ4_Best2_Top_DF_Sum.iloc[3]+RQ4_Best2_Top_MD_Sum.iloc[0]+ RQ4_Best2_Top_MD_Sum.iloc[1]+ RQ4_Best2_Top_MD_Sum.iloc[2]+ RQ4_Best2_Top_MD_Sum.iloc[3]+RQ4_Best2_Top_GK_Sum.iloc[0])/11
Oldies2_Squad_Rating = (RQ4_Oldies2_Top_FW_Sum.iloc[0]+ RQ4_Oldies2_Top_FW_Sum.iloc[1]  +RQ4_Oldies2_Top_DF_Sum.iloc[0] +RQ4_Oldies2_Top_DF_Sum.iloc[1] +RQ4_Oldies2_Top_DF_Sum.iloc[2] +RQ4_Oldies2_Top_DF_Sum.iloc[3]+RQ4_Oldies2_Top_MD_Sum.iloc[0]+ RQ4_Oldies2_Top_MD_Sum.iloc[1]+ RQ4_Oldies2_Top_MD_Sum.iloc[2]+ RQ4_Oldies2_Top_MD_Sum.iloc[3]+RQ4_Oldies2_Top_GK_Sum.iloc[0])/11
Youth2_Squad_Rating = (RQ4_Youth2_Top_FW_Sum.iloc[0]+ RQ4_Youth2_Top_FW_Sum.iloc[1]  +RQ4_Youth2_Top_DF_Sum.iloc[0] +RQ4_Youth2_Top_DF_Sum.iloc[1] +RQ4_Youth2_Top_DF_Sum.iloc[2] +RQ4_Youth2_Top_DF_Sum.iloc[3]+RQ4_Youth2_Top_MD_Sum.iloc[0]+ RQ4_Youth2_Top_MD_Sum.iloc[1]+ RQ4_Youth2_Top_MD_Sum.iloc[2]+ RQ4_Youth2_Top_MD_Sum.iloc[3]+RQ4_Youth2_Top_GK_Sum.iloc[0])/11

Best2_Squad_Rating = Best2_Squad_Rating.round(0)
Oldies2_Squad_Rating = Oldies2_Squad_Rating.round(0)
Youth2_Squad_Rating = Youth2_Squad_Rating.round(0)

Best2_Squad_Rating = Best2_Squad_Rating.astype(int)
Oldies2_Squad_Rating = Oldies2_Squad_Rating.astype(int)
Youth2_Squad_Rating = Youth2_Squad_Rating.astype(int)

Youth2_Squad_Rating = Youth2_Squad_Rating.astype(str)
Oldies2_Squad_Rating = Oldies2_Squad_Rating.astype(str)
Best2_Squad_Rating = Best2_Squad_Rating.astype(str)

# %%
JoinedBest2Images = RQ4Best2['photo'].as_matrix()

Best2GK1 = mpimg.imread(JoinedBest2Images[0])
Best2DF1 = mpimg.imread(JoinedBest2Images[1])
Best2DF2 = mpimg.imread(JoinedBest2Images[2])
Best2DF3 = mpimg.imread(JoinedBest2Images[3])
Best2DF4 = mpimg.imread(JoinedBest2Images[4])
Best2MD1 = mpimg.imread(JoinedBest2Images[5])
Best2MD2 = mpimg.imread(JoinedBest2Images[6])
Best2MD3 = mpimg.imread(JoinedBest2Images[7])
Best2MD4 = mpimg.imread(JoinedBest2Images[8])
Best2FW1 = mpimg.imread(JoinedBest2Images[9])
Best2FW2 = mpimg.imread(JoinedBest2Images[10])

JoinedOldies2Images = RQ4Oldies2['photo'].as_matrix()

Oldies2GK1 = mpimg.imread(JoinedOldies2Images[0])
Oldies2DF1 = mpimg.imread(JoinedOldies2Images[1])
Oldies2DF2 = mpimg.imread(JoinedOldies2Images[2])
Oldies2DF3 = mpimg.imread(JoinedOldies2Images[3])
Oldies2DF4 = mpimg.imread(JoinedOldies2Images[4])
Oldies2MD1 = mpimg.imread(JoinedOldies2Images[5])
Oldies2MD2 = mpimg.imread(JoinedOldies2Images[6])
Oldies2MD3 = mpimg.imread(JoinedOldies2Images[7])
Oldies2MD4 = mpimg.imread(JoinedOldies2Images[8])
Oldies2FW1 = mpimg.imread(JoinedOldies2Images[9])
Oldies2FW2 = mpimg.imread(JoinedOldies2Images[10])

JoinedYouth2Images = RQ4Youth2['photo'].as_matrix()

Youth2GK1 = mpimg.imread(JoinedYouth2Images[0])
Youth2DF1 = mpimg.imread(JoinedYouth2Images[1])
Youth2DF2 = mpimg.imread(JoinedYouth2Images[2])
Youth2DF3 = mpimg.imread(JoinedYouth2Images[3])
Youth2DF4 = mpimg.imread(JoinedYouth2Images[4])
Youth2MD1 = mpimg.imread(JoinedYouth2Images[5])
Youth2MD2 = mpimg.imread(JoinedYouth2Images[6])
Youth2MD3 = mpimg.imread(JoinedYouth2Images[7])
Youth2MD4 = mpimg.imread(JoinedYouth2Images[8])
Youth2FW1 = mpimg.imread(JoinedYouth2Images[9])
Youth2FW2 = mpimg.imread(JoinedYouth2Images[10])

# %%
f, axarr = plt.subplots(4,7,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()
axarr[0,0].set_visible(False)
axarr[0,1].set_visible(False)
axarr[0,3].set_visible(False)
axarr[0,5].set_visible(False)
axarr[0,6].set_visible(False)
axarr[1,0].set_visible(False)
axarr[1,1].set_visible(False)
axarr[1,4].set_visible(False)
axarr[2,0].set_visible(False)
axarr[2,1].set_visible(False)
axarr[2,4].set_visible(False)
axarr[3,0].set_visible(False)
axarr[3,1].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,6].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,2].set_visible(False)
axarr[3,6].set_visible(False)

axarr[0,2].set_title('Squad Rating: ' + Best2_Squad_Rating)
axarr[0,2].axis('off')

axarr[0,4].imshow(Best2GK1)
axarr[0,4].set_title(RQ4Best2['Players'].loc[0] + '\n' +' FIFA Overall: ' + RQ4Best2['overall'].loc[0])
axarr[0,4].axis('off')


axarr[1,2].imshow(Best2DF1)
axarr[1,2].set_title(RQ4Best2['Players'].loc[1] + '\n' +  ' FIFA Overall: ' + RQ4Best2['overall'].loc[1])
axarr[1,2].axis('off')


axarr[1,3].imshow(Best2DF2)
axarr[1,3].set_title(RQ4Best2['Players'].loc[2] + '\n'  + ' FIFA Overall: ' + RQ4Best2['overall'].loc[2])
axarr[1,3].axis('off')


axarr[1,5].imshow(Best2DF3)
axarr[1,5].set_title(RQ4Best2['Players'].loc[3] + '\n' +   ' FIFA Overall: ' + RQ4Best2['overall'].loc[3])
axarr[1,5].axis('off')


axarr[1,6].imshow(Best2DF4)
axarr[1,6].set_title(RQ4Best2['Players'].loc[4] + '\n'  + ' FIFA Overall: ' + RQ4Best2['overall'].loc[4])
axarr[1,6].axis('off')


axarr[2,2].imshow(Best2MD1)
axarr[2,2].set_title(RQ4Best2['Players'].loc[5] + '\n'  + ' FIFA Overall: ' + RQ4Best2['overall'].loc[5])
axarr[2,2].axis('off')


axarr[2,3].imshow(Best2MD2)
axarr[2,3].set_title(RQ4Best2['Players'].loc[6] + '\n'  + ' FIFA Overall: ' + RQ4Best2['overall'].loc[6])
axarr[2,3].axis('off')


axarr[2,5].imshow(Best2MD3)
axarr[2,5].set_title(RQ4Best2['Players'].loc[7] + '\n'  + ' FIFA Overall: ' + RQ4Best2['overall'].loc[7])
axarr[2,5].axis('off')


axarr[2,6].imshow(Best2MD4)
axarr[2,6].set_title(RQ4Best2['Players'].loc[8] + '\n' + ' FIFA Overall: ' + RQ4Best2['overall'].loc[8])
axarr[2,6].axis('off')


axarr[3,3].imshow(Best2FW1)
axarr[3,3].set_title(RQ4Best2['Players'].loc[9] + '\n' + ' FIFA Overall: ' + RQ4Best2['overall'].loc[9])
axarr[3,3].axis('off')

axarr[3,5].imshow(Best2FW2)
axarr[3,5].set_title(RQ4Best2['Players'].loc[10] + '\n' + ' FIFA Overall: ' + RQ4Best2['overall'].loc[10])
axarr[3,5].axis('off')

f.savefig('../../data/analysis/Best2.png')

# %%
f, axarr = plt.subplots(4,7,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()
axarr[0,0].set_visible(False)
axarr[0,1].set_visible(False)
axarr[0,3].set_visible(False)
axarr[0,5].set_visible(False)
axarr[0,6].set_visible(False)
axarr[1,0].set_visible(False)
axarr[1,1].set_visible(False)
axarr[1,4].set_visible(False)
axarr[2,0].set_visible(False)
axarr[2,1].set_visible(False)
axarr[2,4].set_visible(False)
axarr[3,0].set_visible(False)
axarr[3,1].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,6].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,2].set_visible(False)
axarr[3,6].set_visible(False)

axarr[0,2].set_title('Squad Rating: ' + Youth2_Squad_Rating)
axarr[0,2].axis('off')

axarr[0,4].imshow(Youth2GK1)
axarr[0,4].set_title(RQ4Youth2['Players'].loc[0] + '\n' +' FIFA Overall: ' + RQ4Youth2['overall'].loc[0])
axarr[0,4].axis('off')


axarr[1,2].imshow(Youth2DF1)
axarr[1,2].set_title(RQ4Youth2['Players'].loc[1] + '\n' +  ' FIFA Overall: ' + RQ4Youth2['overall'].loc[1])
axarr[1,2].axis('off')


axarr[1,3].imshow(Youth2DF2)
axarr[1,3].set_title(RQ4Youth2['Players'].loc[2] + '\n'  + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[2])
axarr[1,3].axis('off')


axarr[1,5].imshow(Youth2DF3)
axarr[1,5].set_title(RQ4Youth2['Players'].loc[3] + '\n' +   ' FIFA Overall: ' + RQ4Youth2['overall'].loc[3])
axarr[1,5].axis('off')


axarr[1,6].imshow(Youth2DF4)
axarr[1,6].set_title(RQ4Youth2['Players'].loc[4] + '\n'  + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[4])
axarr[1,6].axis('off')


axarr[2,2].imshow(Youth2MD1)
axarr[2,2].set_title(RQ4Youth2['Players'].loc[5] + '\n'  + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[5])
axarr[2,2].axis('off')


axarr[2,3].imshow(Youth2MD2)
axarr[2,3].set_title(RQ4Youth2['Players'].loc[6] + '\n'  + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[6])
axarr[2,3].axis('off')


axarr[2,5].imshow(Youth2MD3)
axarr[2,5].set_title(RQ4Youth2['Players'].loc[7] + '\n'  + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[7])
axarr[2,5].axis('off')


axarr[2,6].imshow(Youth2MD4)
axarr[2,6].set_title(RQ4Youth2['Players'].loc[8] + '\n' + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[8])
axarr[2,6].axis('off')


axarr[3,3].imshow(Youth2FW1)
axarr[3,3].set_title(RQ4Youth2['Players'].loc[9] + '\n' + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[9])
axarr[3,3].axis('off')

axarr[3,5].imshow(Youth2FW2)
axarr[3,5].set_title(RQ4Youth2['Players'].loc[10] + '\n' + ' FIFA Overall: ' + RQ4Youth2['overall'].loc[10])
axarr[3,5].axis('off')

f.savefig('../../data/analysis/Youth2.png')

# %%
f, axarr = plt.subplots(4,7,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()
axarr[0,0].set_visible(False)
axarr[0,1].set_visible(False)
axarr[0,3].set_visible(False)
axarr[0,5].set_visible(False)
axarr[0,6].set_visible(False)
axarr[1,0].set_visible(False)
axarr[1,1].set_visible(False)
axarr[1,4].set_visible(False)
axarr[2,0].set_visible(False)
axarr[2,1].set_visible(False)
axarr[2,4].set_visible(False)
axarr[3,0].set_visible(False)
axarr[3,1].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,6].set_visible(False)
axarr[3,4].set_visible(False)
axarr[3,2].set_visible(False)
axarr[3,6].set_visible(False)

axarr[0,2].set_title('Squad Rating: ' + Oldies2_Squad_Rating)
axarr[0,2].axis('off')

axarr[0,4].imshow(Oldies2GK1)
axarr[0,4].set_title(RQ4Oldies2['Players'].loc[0] + '\n' +' FIFA Overall: ' + RQ4Oldies2['overall'].loc[0])
axarr[0,4].axis('off')


axarr[1,2].imshow(Oldies2DF1)
axarr[1,2].set_title(RQ4Oldies2['Players'].loc[1] + '\n' +  ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[1])
axarr[1,2].axis('off')


axarr[1,3].imshow(Oldies2DF2)
axarr[1,3].set_title(RQ4Oldies2['Players'].loc[2] + '\n'  + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[2])
axarr[1,3].axis('off')


axarr[1,5].imshow(Oldies2DF3)
axarr[1,5].set_title(RQ4Oldies2['Players'].loc[3] + '\n' +   ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[3])
axarr[1,5].axis('off')


axarr[1,6].imshow(Oldies2DF4)
axarr[1,6].set_title(RQ4Oldies2['Players'].loc[4] + '\n'  + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[4])
axarr[1,6].axis('off')


axarr[2,2].imshow(Oldies2MD1)
axarr[2,2].set_title(RQ4Oldies2['Players'].loc[5] + '\n'  + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[5])
axarr[2,2].axis('off')


axarr[2,3].imshow(Oldies2MD2)
axarr[2,3].set_title(RQ4Oldies2['Players'].loc[6] + '\n'  + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[6])
axarr[2,3].axis('off')


axarr[2,5].imshow(Oldies2MD3)
axarr[2,5].set_title(RQ4Oldies2['Players'].loc[7] + '\n'  + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[7])
axarr[2,5].axis('off')


axarr[2,6].imshow(Oldies2MD4)
axarr[2,6].set_title(RQ4Oldies2['Players'].loc[8] + '\n' + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[8])
axarr[2,6].axis('off')


axarr[3,3].imshow(Oldies2FW1)
axarr[3,3].set_title(RQ4Oldies2['Players'].loc[9] + '\n' + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[9])
axarr[3,3].axis('off')

axarr[3,5].imshow(Oldies2FW2)
axarr[3,5].set_title(RQ4Oldies2['Players'].loc[10] + '\n' + ' FIFA Overall: ' + RQ4Oldies2['overall'].loc[10])
axarr[3,5].axis('off')

f.savefig('../../data/analysis/Oldies2.png')

# %%
Oldies = mpimg.imread('../../data/analysis/Oldies.png')
Oldies2 = mpimg.imread('../../data/analysis/Oldies2.png')

# %%
f, axarr = plt.subplots(2,2,figsize=(15,15),facecolor='lightgreen')
fig = plt.figure()

axarr[0,0].imshow(Oldies)
axarr[0,0].set_title('FIFA Overall: ' )
axarr[0,0].axis('off')


axarr[0,1].imshow(Oldies2)
axarr[0,1].set_title('\n' +  ' FIFA Overall: ')
axarr[0,1].axis('off')

f.savefig('../../data/analysis/Oldies3.png')
