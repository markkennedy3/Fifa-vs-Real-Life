# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## Are homegrown players generally the best in their respective leagues or are they inferior to the foreign players playing in that league? Are these findings portrayed in the FIFA 18’s ratings.

# %%
RQ31617 = pd.read_csv("../../data/prep/Joined1617.csv")

# %%
RQ31617 = RQ31617[[
'name',
'full_name',
 'club',
 'age',
 'league',
 'birth_date',
 'nationality',
 'overall',
 'potential',
 'international_reputation',
 'skill_moves',
'Players',
 'Points',
 'Clubs',
 'Position',
 'Start',
 'Goals',
 'A',
 'CS',
 'CS part',
 'Yellow',
 'Red',
 'Sub',
 'CO',
 'Off',
 'Pen SV',
 'Pen M',
 'Goals conceded',
 'Conceded 1+',
 'OG',
 'Firstname']]

# %%
names=RQ31617['nationality'].unique().tolist()

# %%
RQ31617['IR'] = RQ31617['international_reputation']
RQ31617.drop('international_reputation', axis=1, inplace=True)

# %%
Homegrown_EPL = (RQ31617.loc[RQ31617.nationality=='England'])
Homegrown_EPL = Homegrown_EPL.loc[Homegrown_EPL.league=='English Premier League']

Foreign_EPL = (RQ31617.loc[RQ31617.nationality!='England'])
Foreign_EPL = Foreign_EPL.loc[Foreign_EPL.league=='English Premier League']

# %% [markdown]
# Homegrown_BUN = Homegrown_BUN.loc[Homegrown_BUN.Position=='Defender']
# Could be usedfor XI's

# %%
Homegrown_BUN = (RQ31617.loc[RQ31617.nationality=='Germany'])
Homegrown_BUN = Homegrown_BUN.loc[Homegrown_BUN.league=='German Bundesliga']

Foreign_BUN = (RQ31617.loc[RQ31617.nationality!='Germany'])
Foreign_BUN = Foreign_BUN.loc[Foreign_BUN.league=='German Bundesliga']

# %%
Homegrown_BUN.head(5)
# Out:
#           name       full_name               club  age             league  \
# 5     M. Neuer    Manuel Neuer   FC Bayern Munich   31  German Bundesliga
# 25  J. Boateng  Jerome Boateng   FC Bayern Munich   28  German Bundesliga
# 27  M. Hummels    Mats Hummels   FC Bayern Munich   28  German Bundesliga
# 52   T. Muller   Thomas Muller   FC Bayern Munich   27  German Bundesliga
# 54     M. Reus      Marco Reus  Borussia Dortmund   28  German Bundesliga
#
#     birth_date nationality  overall  potential  skill_moves ... Sub  CO Off  \
# 5   1986-03-27     Germany       92         92            1 ...   0   0   0
# 25  1988-09-03     Germany       88         88            2 ...   9   3   4
# 27  1988-12-16     Germany       88         88            2 ...   5   3   3
# 52  1989-09-13     Germany       86         86            3 ...   6   4   5
# 54  1989-05-31     Germany       86         86            4 ...   1   1  10
#
#    Pen SV  Pen M  Goals conceded  Conceded 1+  OG  Firstname  IR
# 5       0      0              13            1   0     Manuel   5
# 25      0      0              12            4   0     Jerome   4
# 27      0      0              16            2   0       Mats   4
# 52      0      0               0            0   0     Thomas   4
# 54      0      0               0            0   0      Marco   4
#
# [5 rows x 31 columns]

# %%
Foreign_BUN.head(5)
# Out:
#               name                  full_name               club  age  \
# 6   R. Lewandowski         Robert Lewandowski   FC Bayern Munich   28
# 23   P. Aubameyang  Pierre-Emerick Aubameyang  Borussia Dortmund   28
# 32       A. Robben               Arjen Robben   FC Bayern Munich   33
# 37        A. Vidal               Arturo Vidal   FC Bayern Munich   30
# 46    J. Rodriguez            James Rodriguez   FC Bayern Munich   25
#
#                league  birth_date  nationality  overall  potential  \
# 6   German Bundesliga  1988-08-21       Poland       91         91
# 23  German Bundesliga  1989-06-18        Gabon       88         88
# 32  German Bundesliga  1984-01-23  Netherlands       88         88
# 37  German Bundesliga  1987-05-22        Chile       87         87
# 46  German Bundesliga  1991-07-12     Colombia       86         89
#
#     skill_moves ... Sub  CO Off Pen SV  Pen M  Goals conceded  Conceded 1+  \
# 6             3 ...   2   2   3      0      0               0            0
# 23            3 ...   2   1   5      0      2               0            0
# 32            4 ...   9   5   9      0      0               0            0
# 37            3 ...   9   6   9      0      0               0            0
# 46            4 ...  17   9   8      0      0               0            0
#
#     OG  Firstname  IR
# 6    0     Robert   4
# 23   0     Pierre   3
# 32   0      Arjen   4
# 37   0     Arturo   4
# 46   0      James   4
#
# [5 rows x 31 columns]

# %%
Homegrown_LAL = (RQ31617.loc[RQ31617.nationality=='Spain'])
Homegrown_LAL = Homegrown_LAL.loc[Homegrown_LAL.league=='Spanish Primera Division']

Foreign_LAL = (RQ31617.loc[RQ31617.nationality!='Spain'])
Foreign_LAL = Foreign_LAL.loc[Foreign_LAL.league=='Spanish Primera Division']

# %%
Homegrown_LAL.head(5)
# Out:
#                name                       full_name            club  age  \
# 11     Sergio Ramos             Sergio Ramos Garcia  Real Madrid CF   31
# 38      Aleix Vidal              Aleix Vidal Parreu    FC Barcelona   27
# 48             Isco  Francisco Roman Alarcon Suarez  Real Madrid CF   25
# 53  Sergio Busquets          Sergio Busquets Burgos    FC Barcelona   28
# 77       Jordi Alba                Jordi Alba Ramos    FC Barcelona   28
#
#                       league  birth_date nationality  overall  potential  \
# 11  Spanish Primera Division  1986-03-30       Spain       90         90
# 38  Spanish Primera Division  1989-08-21       Spain       76         76
# 48  Spanish Primera Division  1992-04-21       Spain       86         90
# 53  Spanish Primera Division  1988-07-16       Spain       86         86
# 77  Spanish Primera Division  1989-03-21       Spain       85         85
#
#     skill_moves ... Sub  CO Off Pen SV  Pen M  Goals conceded  Conceded 1+  \
# 11            3 ...   1   0   1      0      0              35           12
# 38            3 ...   5   1   0      0      0               3            1
# 48            4 ...  18  12  13      0      0               0            0
# 53            3 ...   1   0   9      0      0               0            0
# 77            3 ...  13   5   2      0      0              27            9
#
#     OG  Firstname  IR
# 11   1     Sergio   4
# 38   0      Aleix   2
# 48   0       Isco   3
# 53   0     Sergio   4
# 77   0      Jordi   3
#
# [5 rows x 31 columns]

# %%
Foreign_LAL.head(5)
# Out:
#                 name                     full_name            club  age  \
# 0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro  Real Madrid CF   32
# 1           L. Messi                  Lionel Messi    FC Barcelona   30
# 3          L. Suarez                   Luis Suarez    FC Barcelona   30
# 4          L. Suarez               Leonardo Suarez   Villarreal CF   21
# 9           T. Kroos                    Toni Kroos  Real Madrid CF   27
#
#                      league  birth_date nationality  overall  potential  \
# 0  Spanish Primera Division  1985-02-05    Portugal       94         94
# 1  Spanish Primera Division  1987-06-24   Argentina       93         93
# 3  Spanish Primera Division  1987-01-24     Uruguay       92         92
# 4  Spanish Primera Division  1996-03-30   Argentina       68         79
# 9  Spanish Primera Division  1990-01-04     Germany       90         90
#
#    skill_moves ... Sub  CO Off Pen SV  Pen M  Goals conceded  Conceded 1+  OG  \
# 0            5 ...   0   0   5      0      1               0            0   0
# 1            4 ...   2   2   4      0      1               0            0   0
# 3            4 ...   3   2   9      0      0               0            0   0
# 4            3 ...   8   3   0      0      0               0            0   0
# 9            3 ...   4   1   4      0      0               0            0   0
#
#    Firstname  IR
# 0  Cristiano   5
# 1     Lionel   5
# 3       Luis   5
# 4   Leonardo   1
# 9       Toni   4
#
# [5 rows x 31 columns]

# %%
d = {'age':'mean','league':'first','birth_date':'first','overall':'mean','potential':'mean',
'IR':'mean','Position':'first','skill_moves':'mean','Players':'first', 'Points':'mean',
 'Clubs':'first','Position':'first','Start':'mean','Goals':'mean','A':'mean','CS':'mean',
 'CS part':'mean','Yellow':'mean','Red':'mean','Sub':'mean','CO':'mean','Off':'mean','Pen SV':'mean',
 'Pen M':'mean','Goals conceded':'mean','Conceded 1+':'mean','OG':'mean'}

# %%
Homegrown_EPL['Homegrown'] = Homegrown_EPL['nationality'] == 'England'
Foreign_EPL['Homegrown'] = Foreign_EPL['nationality'] == 'England'

Homegrown_BUN['Homegrown'] = Homegrown_BUN['nationality'] == 'Germany'
Foreign_BUN['Homegrown'] = Foreign_BUN['nationality'] == 'Germany'

Homegrown_LAL['Homegrown'] = Homegrown_LAL['nationality'] == 'Spain'
Foreign_LAL['Homegrown'] = Foreign_LAL['nationality'] == 'Spain'

# %%
Foreign_EPL.head(5)
# Out:
#             name              full_name               club  age  \
# 7         De Gea  David De Gea Quintana  Manchester United   26
# 8      E. Hazard            Eden Hazard            Chelsea   26
# 12  K. De Bruyne        Kevin De Bruyne    Manchester City   26
# 13   T. Courtois       Thibaut Courtois            Chelsea   25
# 14    A. Sanchez         Alexis Sanchez            Arsenal   28
#
#                     league  birth_date nationality  overall  potential  \
# 7   English Premier League  1990-11-07       Spain       90         92
# 8   English Premier League  1991-01-07     Belgium       90         91
# 12  English Premier League  1991-06-28     Belgium       89         92
# 13  English Premier League  1992-05-11     Belgium       89         92
# 14  English Premier League  1988-12-19       Chile       89         89
#
#     skill_moves    ...     CO  Off Pen SV Pen M  Goals conceded  Conceded 1+  \
# 7             1    ...      0    0      0     0              29            8
# 8             4    ...      0   25      0     1               0            0
# 12            4    ...      3   11      0     1               0            0
# 13            1    ...      0    0      0     0              28            8
# 14            4    ...      2    8      0     1               0            0
#
#     OG  Firstname  IR  Homegrown
# 7    0      David   4      False
# 8    0       Eden   4      False
# 12   0      Kevin   4      False
# 13   0    Thibaut   4      False
# 14   0     Alexis   4      False
#
# [5 rows x 32 columns]

# %%
Homegrown_EPL
# Out:
#                        name                full_name                  club  \
# 45                  H. Kane               Harry Kane     Tottenham Hotspur
# 47             J. Rodriguez            Jay Rodriguez  West Bromwich Albion
# 92                  D. Alli                Dele Alli     Tottenham Hotspur
# 110               G. Cahill              Gary Cahill               Chelsea
# 144               K. Walker              Kyle Walker       Manchester City
#       skill_moves    ...      CO  Off Pen SV Pen M  Goals conceded  \
# 45              3    ...       1   16      0     1               0
# 47              3    ...      15    6      0     0               0
# 92              4    ...       2   13      0     0               0
# 110             2    ...       1    1      0     0              30
# 144             2    ...       2    5      0     0              23
# 151             4    ...       4   17      0     0               0
# 180             4    ...       1    0      0     0               0
# 194             4    ...       4   13      0     0               0
# 196             2    ...       2    3      0     0               0
# 207             3    ...       0    1      0     0              41
# 214             3    ...       0    2      0     0               0
# 226             4    ...      13    7      0     0               0
# 227             3    ...       0    3      0     0              12
# 231             3    ...       0    3      0     1              34
# 242             4    ...      16    8      0     0               0
# 253             3    ...       2    8      0     0               0
# 254             2    ...       0    0      0     0              49
# 256             1    ...       0    0      0     0               8
# 262             3    ...       4   13      0     0               0
# 272             2    ...       5    1      0     0              16
# 273             3    ...       7    7      0     0               0
# 289             1    ...       0    0      1     0              48
# 296             3    ...      10    9      0     0               0
# 334             4    ...      13   11      0     0               0
# 336             2    ...       0    1      0     0              14
# 349             4    ...       0    6      0     0               0
# 356             3    ...       8    6      0     0               0
# 380             2    ...       0    1      0     0              36
# 384             3    ...       5   13      0     1               0
# 385             1    ...       0    0      0     0              51
# ...           ...    ...      ..  ...    ...   ...             ...
# 1839            1    ...       0    0      0     0               0
# 1852            2    ...       5    1      0     0               0
# 1904            3    ...       1    0      0     0               0
# 1907            1    ...       0    0      0     0               0
# 1961            2    ...       2    3      0     0              21
# 1965            2    ...       6    1      0     0               0
# 1967            2    ...       6    5      0     0               0
# 1996            2    ...       8    0      0     0               0
# 2043            2    ...       1    0      0     0               9
# 2044            3    ...       2    0      0     0               0
# 2049            3    ...       1    0      0     0               0
# 2125            3    ...       0    0      0     0               0
# 2131            3    ...       0    0      0     0               0
# 2135            3    ...       4    3      0     0               0
# 2140            2    ...       5    3      0     0               0
# 2141            3    ...       0    0      0     0               0
# 2168            3    ...       0    0      0     0               0
# 2172            2    ...       0    0      0     0               0
# 2227            2    ...       1    0      0     0               1
# 2238            2    ...       4    1      0     0               0
# 2255            1    ...       0    0      0     0               0
# 2257            2    ...       0    0      0     0               0
# 2259            3    ...       0    0      0     0               0
# 2264            2    ...       1    4      0     0              11
# 2274            3    ...       0    0      0     0               0
# 2292            2    ...       1    0      0     0               0
# 2307            2    ...       0    0      0     0               0
# 2319            3    ...       0    0      0     0               0
# 2324            1    ...       0    0      0     0               0
# 2344            1    ...       0    0      0     0              62
#
#       Conceded 1+  OG  Firstname  IR  Homegrown
# 45              0   0      Harry   3       True
# 47              0   0        Jay   2       True
# 92              0   0       Dele   3       True
# 110             9   1       Gary   3       True
# 144             5   0       Kyle   3       True
# 151             0   0       Adam   3       True
# 180             0   0      Angel   1       True
# 194             0   0     Raheem   3       True
# 196             0   0       Eric   2       True
# 207            16   0  Nathaniel   2       True
# 214             0   0     Jordan   2       True
# 226             0   0     Daniel   3       True
# 227             2   0      Danny   3       True
# 231            14   0   Leighton   3       True
# 242             0   0     Marcus   2       True
# 253             0   0      Jamie   3       True
# 254            24   0    Michael   2       True
# 256             5   0       Jack   2       True
# 262             0   0       Ross   2       True
# 272             7   0      Chris   3       True
# 273             0   0       Jack   3       True
# 289            23   0        Tom   2       True
# 296             0   0      Wayne   4       True
# 334             0   0       Alex   2       True
# 336             2   0       Phil   2       True
# 349             0   0    Michail   2       True
# 356             0   0      Danny   3       True
# 380            20   0       Ryan   2       True
# 384             0   0       Theo   3       True
# 385            19   0        Ben   2       True
# ...           ...  ..        ...  ..        ...
# 1839            0   0     Stuart   1       True
# 1852            0   0      Trent   1       True
# 1904            0   0     Sullay   1       True
# 1907            0   0        Ben   1       True
# 1961            9   0      Mason   1       True
# 1965            0   0       Josh   1       True
# 1967            0   0    Dominic   1       True
# 1996            0   0        Sam   1       True
# 2043            7   0    Brandon   1       True
# 2044            0   0   Oviemuno   1       True
# 2049            0   0    Ainsley   1       True
# 2125            0   0      Chuba   1       True
# 2131            0   0       Jake   1       True
# 2135            0   0        Sam   1       True
# 2140            0   0    Ademola   1       True
# 2141            0   0    Demetri   1       True
# 2168            0   0    Zachary   1       True
# 2172            0   0      Tosin   1       True
# 2227            0   0     Jonjoe   1       True
# 2238            0   0     Jerome   1       True
# 2255            0   0      Aaron   1       True
# 2257            0   0        Tom   1       True
# 2259            0   0     Marcus   1       True
# 2264            8   0       Josh   1       True
# 2274            0   0     Nathan   1       True
# 2292            0   0    Michael   1       True
# 2307            0   0       Luke   1       True
# 2319            0   0     Samuel   1       True
# 2324            0   0       Alex   1       True
# 2344           31   0        Joe   3       True
#
# [142 rows x 32 columns]

# %%
Avg_English = (Homegrown_EPL.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_EPL.columns))
Avg_Spanish = (Homegrown_LAL.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_LAL.columns))
Avg_German = (Homegrown_BUN.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_BUN.columns))

Avg_English_Foreign = (Foreign_EPL.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_EPL.columns))
Avg_Spanish_Foreign = (Foreign_LAL.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_LAL.columns))
Avg_German_Foreign = (Foreign_BUN.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_BUN.columns))

# %%
Avg_English
# Out:
#    name  full_name  club        age                  league  birth_date  \
# 0   NaN        NaN   NaN  25.176056  English Premier League  1993-07-28
#
#   nationality    overall  potential  skill_moves    ...            CO  \
# 0     England  73.788732  79.267606     2.478873    ...      3.197183
#
#         Off    Pen SV     Pen M  Goals conceded  Conceded 1+        OG  \
# 0  3.802817  0.014085  0.035211       12.450704     6.140845  0.105634
#
#    Firstname        IR  Homegrown
# 0        NaN  1.605634        NaN
#
# [1 rows x 32 columns]

# %%
Avg_English_Foreign
# Out:
#    name  full_name  club        age                  league  birth_date  \
# 0   NaN        NaN   NaN  26.681452  English Premier League  1990-11-07
#
#    nationality    overall  potential  skill_moves    ...            CO  \
# 0          NaN  77.435484  80.520161     2.596774    ...      4.020161
#
#         Off    Pen SV    Pen M  Goals conceded  Conceded 1+        OG  \
# 0  4.399194  0.048387  0.08871       11.080645     5.129032  0.040323
#
#    Firstname        IR  Homegrown
# 0        NaN  2.020161      False
#
# [1 rows x 32 columns]

# %%
HomegrownPlayers = [Avg_English,Avg_Spanish,Avg_German]
ForeignPlayers = [Avg_English_Foreign,Avg_Spanish_Foreign,Avg_German_Foreign]

# %%
AverageHomegrown = pd.concat(HomegrownPlayers)
AverageForeign = pd.concat(ForeignPlayers)

# %%
AverageHomegrown['Homegrown'] = True
AverageForeign['Homegrown'] = False

# %%
All_Players = [AverageForeign,AverageHomegrown]
Total_Average = pd.concat(All_Players)

# %%
cols= ['age','league','nationality','overall','potential','IR','skill_moves',
 'Points','Start','Goals','A','Yellow','Red','Sub','CO','Off','Homegrown']

# %%
Total_Average = Total_Average[cols]
Total_Average = Total_Average.fillna('Foreign')

# %%
Total_Average.set_index('Homegrown')
# Out:
#                  age                    league nationality    overall  \
# Homegrown
# False      26.681452    English Premier League     Foreign  77.435484
# False      26.046358  Spanish Primera Division     Foreign  78.112583
# False      25.337209         German Bundesliga     Foreign  75.540698
# True       25.176056    English Premier League     England  73.788732
# True       25.690141  Spanish Primera Division       Spain  75.091549
# True       25.022472         German Bundesliga     Germany  74.028090
#
#            potential        IR  skill_moves     Points      Start     Goals  \
# Homegrown
# False      80.520161  2.020161     2.596774  59.810484  18.169355  2.701613
# False      81.443709  1.841060     2.841060  59.854305  17.523179  3.066225
# False      79.668605  1.726744     2.651163  51.191860  15.994186  2.459302
# True       79.267606  1.605634     2.478873  50.380282  16.415493  2.014085
# True       79.232394  1.443662     2.443662  48.415493  15.647887  2.042254
# True       78.691011  1.662921     2.314607  43.432584  13.825843  1.668539
#
#                   A    Yellow       Red       Sub        CO       Off
# Homegrown
# False      1.725806  3.157258  0.068548  8.963710  4.020161  4.399194
# False      1.754967  3.688742  0.079470  9.649007  4.152318  5.655629
# False      1.552326  2.877907  0.098837  8.040698  3.930233  4.529070
# True       1.352113  2.542254  0.042254  7.619718  3.197183  3.802817
# True       1.500000  3.450704  0.077465  9.725352  4.274648  3.887324
# True       1.410112  2.280899  0.022472  8.589888  3.202247  3.438202

# %%
Total_Average['Performance'] = Total_Average.overall / Total_Average.overall

# %%
Total_Average
# Out:
#          age                    league nationality    overall  potential  \
# 0  26.681452    English Premier League     Foreign  77.435484  80.520161
# 0  26.046358  Spanish Primera Division     Foreign  78.112583  81.443709
# 0  25.337209         German Bundesliga     Foreign  75.540698  79.668605
# 0  25.176056    English Premier League     England  73.788732  79.267606
# 0  25.690141  Spanish Primera Division       Spain  75.091549  79.232394
# 0  25.022472         German Bundesliga     Germany  74.028090  78.691011
#
#          IR  skill_moves     Points      Start     Goals         A    Yellow  \
# 0  2.020161     2.596774  59.810484  18.169355  2.701613  1.725806  3.157258
# 0  1.841060     2.841060  59.854305  17.523179  3.066225  1.754967  3.688742
# 0  1.726744     2.651163  51.191860  15.994186  2.459302  1.552326  2.877907
# 0  1.605634     2.478873  50.380282  16.415493  2.014085  1.352113  2.542254
# 0  1.443662     2.443662  48.415493  15.647887  2.042254  1.500000  3.450704
# 0  1.662921     2.314607  43.432584  13.825843  1.668539  1.410112  2.280899
#
#         Red       Sub        CO       Off  Homegrown  Performance
# 0  0.068548  8.963710  4.020161  4.399194      False          1.0
# 0  0.079470  9.649007  4.152318  5.655629      False          1.0
# 0  0.098837  8.040698  3.930233  4.529070      False          1.0
# 0  0.042254  7.619718  3.197183  3.802817       True          1.0
# 0  0.077465  9.725352  4.274648  3.887324       True          1.0
# 0  0.022472  8.589888  3.202247  3.438202       True          1.0

# %%
HEPL = len(Homegrown_EPL)
HBUN = len(Homegrown_BUN)
HLAL = len(Homegrown_LAL)
FEPL = len(Foreign_EPL)
FBUN = len(Foreign_BUN)
FLAL = len(Foreign_LAL)

# %%
FLAL
# Out:
# 151

# %%
columns = ['Homegrown','Foreign']
df = pd.DataFrame(columns=columns)
df = df.fillna(0) # with 0s rather than NaNs

# %%
df['Homegrown']=HEPL,HBUN,HLAL
df['Foreign']=FEPL,FBUN,FLAL

# %%
df.reset_index()
# Out:
#    index  Homegrown  Foreign
# 0      0        142      248
# 1      1        178      172
# 2      2        142      151

# %%
df = df.transpose()

# %%
df['Total'] = df.sum(axis=1)

# %%
df = df.drop(df.columns[[0, 1, 2]], axis=1)

# %%
explode = (0.07, 0)
labels = ["Homegrown","Foreign"]
df.plot(subplots=True,kind='pie',figsize=(9,9),fontsize=14,explode=explode,autopct='%1.1f%%',shadow=True,labels=labels,labeldistance=1.4)
plt.legend(loc='right', bbox_to_anchor=(1.45, .55))
plt.title('Homegrown vs Foreign',fontsize=10)
# Out:
# Text(0.5,1,'Homegrown vs Foreign')

# %%
test = Total_Average[['overall','Homegrown']]

# %%
test
# Out:
#      overall  Homegrown
# 0  77.435484      False
# 0  78.112583      False
# 0  75.540698      False
# 0  73.788732       True
# 0  75.091549       True
# 0  74.028090       True

# %%
home = test.loc[test['Homegrown'] == 1, 'overall'].sum()

# %%
fore = test.loc[test['Homegrown'] != 1, 'overall'].sum()

# %%
home/fore
# Out:
# 0.9646006469726413

# %%
Homegrown_LAL_GK = Homegrown_LAL.loc[Homegrown_LAL.Position=='Goalkeeper']
Homegrown_LAL_DF = Homegrown_LAL.loc[Homegrown_LAL.Position=='Defender']
Homegrown_LAL_MD = Homegrown_LAL.loc[Homegrown_LAL.Position=='Midfielder']
Homegrown_LAL_FW = Homegrown_LAL.loc[Homegrown_LAL.Position=='Forward']

Homegrown_BUN_GK = Homegrown_BUN.loc[Homegrown_BUN.Position=='Goalkeeper']
Homegrown_BUN_DF = Homegrown_BUN.loc[Homegrown_BUN.Position=='Defender']
Homegrown_BUN_MD = Homegrown_BUN.loc[Homegrown_BUN.Position=='Midfielder']
Homegrown_BUN_FW = Homegrown_BUN.loc[Homegrown_BUN.Position=='Forward']

Homegrown_EPL_GK = Homegrown_EPL.loc[Homegrown_EPL.Position=='Goalkeeper']
Homegrown_EPL_DF = Homegrown_EPL.loc[Homegrown_EPL.Position=='Defender']
Homegrown_EPL_MD = Homegrown_EPL.loc[Homegrown_EPL.Position=='Midfielder']
Homegrown_EPL_FW = Homegrown_EPL.loc[Homegrown_EPL.Position=='Forward']

Foreign_LAL_GK = Foreign_LAL.loc[Foreign_LAL.Position=='Goalkeeper']
Foreign_LAL_DF = Foreign_LAL.loc[Foreign_LAL.Position=='Defender']
Foreign_LAL_MD = Foreign_LAL.loc[Foreign_LAL.Position=='Midfielder']
Foreign_LAL_FW = Foreign_LAL.loc[Foreign_LAL.Position=='Forward']

Foreign_BUN_GK = Foreign_BUN.loc[Foreign_BUN.Position=='Goalkeeper']
Foreign_BUN_DF = Foreign_BUN.loc[Foreign_BUN.Position=='Defender']
Foreign_BUN_MD = Foreign_BUN.loc[Foreign_BUN.Position=='Midfielder']
Foreign_BUN_FW = Foreign_BUN.loc[Foreign_BUN.Position=='Forward']

Foreign_EPL_GK = Foreign_EPL.loc[Foreign_EPL.Position=='Goalkeeper']
Foreign_EPL_DF = Foreign_EPL.loc[Foreign_EPL.Position=='Defender']
Foreign_EPL_MD = Foreign_EPL.loc[Foreign_EPL.Position=='Midfielder']
Foreign_EPL_FW = Foreign_EPL.loc[Foreign_EPL.Position=='Forward']

# %%
d = {'age':'mean','league':'first','birth_date':'first','overall':'mean','potential':'mean',
'IR':'mean','Position':'first','skill_moves':'mean','Players':'first', 'Points':'mean',
 'Clubs':'first','Position':'first','Start':'mean','Goals':'mean','A':'mean','CS':'mean',
 'CS part':'mean','Yellow':'mean','Red':'mean','Sub':'mean','CO':'mean','Off':'mean','Pen SV':'mean',
 'Pen M':'mean','Goals conceded':'mean','Conceded 1+':'mean','OG':'mean'}

# %%
Avg_English_GK = (Homegrown_EPL_GK.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_EPL_GK.columns))
Avg_Spanish_GK = (Homegrown_LAL_GK.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_LAL_GK.columns))
Avg_German_GK = (Homegrown_BUN_GK.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_BUN_GK.columns))

Avg_English_Foreign_GK = (Foreign_EPL_GK.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_EPL_GK.columns))
Avg_Spanish_Foreign_GK = (Foreign_LAL_GK.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_LAL_GK.columns))
Avg_German_Foreign_GK = (Foreign_BUN_GK.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_BUN_GK.columns))

Avg_English_DF = (Homegrown_EPL_DF.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_EPL_DF.columns))
Avg_Spanish_DF = (Homegrown_LAL_DF.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_LAL_DF.columns))
Avg_German_DF = (Homegrown_BUN_DF.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_BUN_DF.columns))

Avg_English_Foreign_DF = (Foreign_EPL_DF.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_EPL_DF.columns))
Avg_Spanish_Foreign_DF = (Foreign_LAL_DF.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_LAL_DF.columns))
Avg_German_Foreign_DF = (Foreign_BUN_DF.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_BUN_DF.columns))

Avg_English_MD = (Homegrown_EPL_MD.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_EPL_MD.columns))
Avg_Spanish_MD = (Homegrown_LAL_MD.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_LAL_MD.columns))
Avg_German_MD = (Homegrown_BUN_MD.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_BUN_MD.columns))

Avg_English_Foreign_MD = (Foreign_EPL_MD.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_EPL_MD.columns))
Avg_Spanish_Foreign_MD = (Foreign_LAL_MD.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_LAL_MD.columns))
Avg_German_Foreign_MD = (Foreign_BUN_MD.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_BUN_MD.columns))

Avg_English_FW = (Homegrown_EPL_FW.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_EPL_FW.columns))
Avg_Spanish_FW = (Homegrown_LAL_FW.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_LAL_FW.columns))
Avg_German_FW = (Homegrown_BUN_FW.groupby(['nationality'], sort=False, as_index=False).agg(d).reindex(columns=Homegrown_BUN_FW.columns))

Avg_English_Foreign_FW = (Foreign_EPL_FW.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_EPL_FW.columns))
Avg_Spanish_Foreign_FW = (Foreign_LAL_FW.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_LAL_FW.columns))
Avg_German_Foreign_FW = (Foreign_BUN_FW.groupby(['Homegrown'], sort=False, as_index=False).agg(d).reindex(columns=Foreign_BUN_FW.columns))

# %%
HomegrownPlayers_GK = [Avg_English_GK,Avg_Spanish_GK,Avg_German_GK]
ForeignPlayers_GK = [Avg_English_Foreign_GK,Avg_Spanish_Foreign_GK,Avg_German_Foreign_GK]

HomegrownPlayers_DF = [Avg_English_DF,Avg_Spanish_DF,Avg_German_DF]
ForeignPlayers_DF = [Avg_English_Foreign_DF,Avg_Spanish_Foreign_DF,Avg_German_Foreign_DF]

HomegrownPlayers_MD = [Avg_English_MD,Avg_Spanish_MD,Avg_German_MD]
ForeignPlayers_MD = [Avg_English_Foreign_MD,Avg_Spanish_Foreign_MD,Avg_German_Foreign_MD]

HomegrownPlayers_FW = [Avg_English_FW,Avg_Spanish_FW,Avg_German_FW]
ForeignPlayers_FW = [Avg_English_Foreign_FW,Avg_Spanish_Foreign_FW,Avg_German_Foreign_FW]

# %%
HomegrownPlayers_GK = pd.concat(HomegrownPlayers_GK)
HomegrownPlayers_DF = pd.concat(HomegrownPlayers_DF)
HomegrownPlayers_MD = pd.concat(HomegrownPlayers_MD)
HomegrownPlayers_FW = pd.concat(HomegrownPlayers_FW)

ForeignPlayers_GK = pd.concat(ForeignPlayers_GK)
ForeignPlayers_DF = pd.concat(ForeignPlayers_DF)
ForeignPlayers_MD = pd.concat(ForeignPlayers_MD)
ForeignPlayers_FW = pd.concat(ForeignPlayers_FW)

# %%
HomegrownPlayers_Positions = [HomegrownPlayers_GK,HomegrownPlayers_DF,HomegrownPlayers_MD,HomegrownPlayers_FW]
ForeignPlayers_Positions = [ForeignPlayers_GK,ForeignPlayers_DF,ForeignPlayers_MD,ForeignPlayers_FW]

# %%
AverageHomegrown_Positions = pd.concat(HomegrownPlayers_Positions)
AverageForeign_Positions = pd.concat(ForeignPlayers_Positions)
AverageHomegrown_Positions ['Homegrown'] = True
AverageForeign_Positions ['Homegrown'] = False

# %%
All_Players_Positions = [AverageForeign_Positions,AverageHomegrown_Positions]
Total_Average_Position = pd.concat(All_Players_Positions)

# %%
AverageHomegrown_Positions['Position']
# Out:
# 0    Goalkeeper
# 0    Goalkeeper
# 0    Goalkeeper
# 0      Defender
# 0      Defender
# 0      Defender
# 0    Midfielder
# 0    Midfielder
# 0    Midfielder
# 0       Forward
# 0       Forward
# 0       Forward
# Name: Position, dtype: object

# %%
cols2 = ['age','league','Position','overall','potential','Homegrown','skill_moves',
 'Points','Start','Goals','A','Yellow','Red','Sub','CO','Off']

# %%
Total_Average_Position = Total_Average_Position[cols2]
Total_Average_Position = Total_Average_Position.fillna('Foreign')

# %%
Total_Average_Position = Total_Average_Position.set_index('Position')

# %%
Total_Average_Position
# Out:
#                   age                    league    overall  potential  \
# Position
# Goalkeeper  30.370370    English Premier League  78.037037  79.296296
# Goalkeeper  27.700000  Spanish Primera Division  79.400000  81.700000
# Goalkeeper  28.666667         German Bundesliga  75.583333  78.166667
# Defender    27.426667    English Premier League  77.413333  79.720000
# Defender    26.239130  Spanish Primera Division  77.891304  81.065217
# Defender    4.695652  0.086957   8.369565  1.739130   2.804348
# Defender    3.600000  0.100000   6.100000  2.280000   2.360000
# Midfielder  3.785714  0.091837   8.346939  4.979592   6.887755
# Midfielder  3.450000  0.100000   9.733333  4.983333   6.233333
# Midfielder  3.028169  0.070423   8.859155  4.619718   5.464789
# Forward     2.187500  0.062500  10.833333  7.520833   5.958333
# Forward     3.571429  0.057143  10.085714  7.000000  10.000000
# Forward     2.205128  0.128205   9.333333  6.000000   7.000000
# Goalkeeper  0.692308  0.000000   4.769231  0.000000   0.000000
# Goalkeeper  0.941176  0.058824  13.294118  0.117647   0.058824
# Goalkeeper  0.379310  0.000000  12.551724  0.034483   0.034483
# Defender    3.142857  0.020408   7.102041  1.816327   1.612245
# Defender    4.121951  0.146341   7.780488  2.170732   1.756098
# Defender    2.680851  0.021277   7.276596  2.446809   2.255319
# Midfielder  2.763636  0.072727   8.418182  4.290909   5.709091
# Midfielder  4.092593  0.055556   9.703704  5.703704   5.629630
# Midfielder  2.558442  0.012987   7.688312  3.909091   4.727273
# Forward     1.840000  0.040000   8.360000  5.160000   5.880000
# Forward     2.800000  0.033333  10.400000  6.933333   5.833333
# Forward     2.880000  0.080000   9.240000  6.120000   5.640000

# %%
HomegrownPlayers_GK
# Out:
#    name  full_name  club        age                    league  birth_date  \
# 0   NaN        NaN   NaN  27.769231    English Premier League  1993-03-10
# 0   NaN        NaN   NaN  26.352941  Spanish Primera Division  1989-06-28
# 0   NaN        NaN   NaN  27.620690         German Bundesliga  1986-03-27
#
#   nationality    overall  potential  skill_moves    ...            CO  \
# 0     England  72.846154  76.846154            1    ...      0.000000
# 0       Spain  73.764706  78.176471            1    ...      0.117647
# 0     Germany  73.068966  76.379310            1    ...      0.034483
#
#         Off    Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname  \
# 0  0.000000  0.153846     0       23.153846    10.923077   0        NaN
# 0  0.058824  0.352941     0       19.235294    10.176471   0        NaN
# 0  0.034483  0.379310     0       13.965517     6.482759   0        NaN
#
#          IR  Homegrown
# 0  1.461538        NaN
# 0  1.352941        NaN
# 0  1.551724        NaN
#
# [3 rows x 32 columns]

# %%
ForeignPlayers_GK
# Out:
#    name  full_name  club        age                    league  birth_date  \
# 0   NaN        NaN   NaN  30.370370    English Premier League  1990-11-07
# 0   NaN        NaN   NaN  27.700000  Spanish Primera Division  1993-01-07
# 0   NaN        NaN   NaN  28.666667         German Bundesliga  1990-11-14
#
#    nationality    overall  potential  skill_moves    ...            CO  \
# 0          NaN  78.037037  79.296296            1    ...      0.148148
# 0          NaN  79.400000  81.700000            1    ...      0.300000
# 0          NaN  75.583333  78.166667            1    ...      0.000000
#
#         Off    Pen SV Pen M  Goals conceded  Conceded 1+        OG  Firstname  \
# 0  0.222222  0.444444     0        20.37037     9.037037  0.074074        NaN
# 0  0.100000  0.200000     0        15.60000     6.000000  0.100000        NaN
# 0  0.000000  0.333333     0        25.25000    12.083333  0.000000        NaN
#
#          IR  Homegrown
# 0  2.148148      False
# 0  2.100000      False
# 0  1.833333      False
#
# [3 rows x 32 columns]
