# %%
import os.path
import numpy as np
import pandas as pd

# %%
BPL1617 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=556")[0]
BUN1617 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=561")[0]
LAL1617 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=564")[0]

# %%
SEA1617 = [BPL1617,BUN1617,LAL1617]
SEA1617 = pd.concat(SEA1617)
SEA1617 = SEA1617.reset_index()

# %%
SEA1617.head()
# Out:
#    index         Players  Points  Clubs    Position  Start  Goals   A CS  \
# 0      0      Harry Kane     220  SPURS     Forward     29     29   7  -
# 1      1  Alexis Sanchez     219   ARSL     Forward     36     24  11  -
# 2      2   Romelu Lukaku     213   EVER     Forward     36     25   6  -
# 3      3     Diego Costa     179   CHEL     Forward     35     20   7  -
# 4      4       Dele Alli     179  SPURS  Midfielder     35     18   7  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    1   1   16       -     1               -           -
# 1       -  ...     0    2   2    8       -     1               -           -
# 2       -  ...     0    1   1    2       -     0               -           -
# 3       -  ...     0    1   0    8       -     1               -           -
# 4       -  ...     0    2   2   13       -     0               -           -
#
#   OG  More
# 0  0  More
# 1  0  More
# 2  0  More
# 3  0  More
# 4  0  More
#
# [5 rows x 21 columns]

# %%
SEA1617.drop(SEA1617.columns[[0,20]], axis=1, inplace=True)

# %%
SEA1617.head()
# Out:
#           Players  Points  Clubs    Position  Start  Goals   A CS CS part  \
# 0      Harry Kane     220  SPURS     Forward     29     29   7  -       -
# 1  Alexis Sanchez     219   ARSL     Forward     36     24  11  -       -
# 2   Romelu Lukaku     213   EVER     Forward     36     25   6  -       -
# 3     Diego Costa     179   CHEL     Forward     35     20   7  -       -
# 4       Dele Alli     179  SPURS  Midfielder     35     18   7  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       3    0    1   1   16      -      1              -           -   0
# 1       6    0    2   2    8      -      1              -           -   0
# 2       3    0    1   1    2      -      0              -           -   0
# 3      10    0    1   0    8      -      1              -           -   0
# 4       4    0    2   2   13      -      0              -           -   0

# %%
SEA1617.head()
# Out:
#           Players  Points  Clubs    Position  Start  Goals   A CS CS part  \
# 0      Harry Kane     220  SPURS     Forward     29     29   7  -       -
# 1  Alexis Sanchez     219   ARSL     Forward     36     24  11  -       -
# 2   Romelu Lukaku     213   EVER     Forward     36     25   6  -       -
# 3     Diego Costa     179   CHEL     Forward     35     20   7  -       -
# 4       Dele Alli     179  SPURS  Midfielder     35     18   7  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       3    0    1   1   16      -      1              -           -   0
# 1       6    0    2   2    8      -      1              -           -   0
# 2       3    0    1   1    2      -      0              -           -   0
# 3      10    0    1   0    8      -      1              -           -   0
# 4       4    0    2   2   13      -      0              -           -   0

# %%
SEA1617.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             333
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]
SEA1617[DashColumns] = SEA1617[DashColumns].replace('-' ,'0')

# %%
SEA1617.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1768 entries, 0 to 1767
# Data columns (total 19 columns):
# Players           1768 non-null object
# Points            1768 non-null int64
# Clubs             1435 non-null object
# Position          1768 non-null object
# Start             1768 non-null int64
# Goals             1768 non-null int64
# A                 1768 non-null int64
# CS                1768 non-null object
# CS part           1768 non-null object
# Yellow            1768 non-null int64
# Red               1768 non-null int64
# Sub               1768 non-null int64
# CO                1768 non-null int64
# Off               1768 non-null int64
# Pen SV            1768 non-null object
# Pen M             1768 non-null int64
# Goals conceded    1768 non-null object
# Conceded 1+       1768 non-null object
# OG                1768 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 262.5+ KB

# %%
SEA1617['CS'] = SEA1617['CS'].str.replace('%','').astype(np.int)
SEA1617['CS part'] = SEA1617['CS part'].str.replace('%','').astype(np.int)
SEA1617['Pen SV'] = SEA1617['Pen SV'].str.replace('%','').astype(np.int)
SEA1617['Goals conceded'] = SEA1617['Goals conceded'].str.replace('%','').astype(np.int)
SEA1617['Conceded 1+'] = SEA1617['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 1, 'FirstInitial'] = SEA1617['Players'].astype(str).str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 1, 'Firstname'] = SEA1617['Players'].str.split().str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 1, 'Surname'] = SEA1617['Players'].str.split().str[0]

SEA1617.loc[SEA1617['Players'].str.split().str.len() == 2, 'FirstInitial'] = SEA1617['Players'].astype(str).str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 2, 'Firstname'] = SEA1617['Players'].str.split().str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 2, 'Surname'] = SEA1617['Players'].str.split().str[-1]

SEA1617.loc[SEA1617['Players'].str.split().str.len() == 3, 'FirstInitial'] = SEA1617['Players'].astype(str).str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 3, 'Firstname'] = SEA1617['Players'].str.split().str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 3, 'Surname'] = SEA1617['Players'].str.split().str[-1]

SEA1617.loc[SEA1617['Players'].str.split().str.len() == 4, 'FirstInitial'] = SEA1617['Players'].astype(str).str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 4, 'Firstname'] = SEA1617['Players'].str.split().str[0]
SEA1617.loc[SEA1617['Players'].str.split().str.len() == 4, 'Surname'] = SEA1617['Players'].str.split().str[-1]

# %%
SEA1617.set_index(['Surname','FirstInitial'])
# Out:
#                                         Players  Points   Clubs    Position  \
# Surname      FirstInitial
# Kane         H                       Harry Kane     220   SPURS     Forward
# Sanchez      A                   Alexis Sanchez     219    ARSL     Forward
# Lukaku       R                    Romelu Lukaku     213    EVER     Forward
# Costa        D                      Diego Costa     179    CHEL     Forward
# Alli         D                        Dele Alli     179   SPURS  Midfielder
# Hazard       E                      Eden Hazard     168    CHEL  Midfielder
# Sigurdsson   G                 Gylfi Sigurdsson     157    SWAN  Midfielder
# Eriksen      C                Christian Eriksen     157   SPURS  Midfielder
# Aguero       S                    Sergio Aguero     156    MCFC     Forward
# Defoe        J                    Jermain Defoe     154    SUND     Forward
# Alonso       M                    Marcos Alonso     152    CHEL    Defender
# King         J                      Joshua King     150     BOU     Forward
# Cahill       G                      Gary Cahill     148    CHEL    Defender
# Bruyne       K                  Kevin De Bruyne     147    MCFC  Midfielder
# Ibrahimovic  Z               Zlatan Ibrahimovic     146    MUFC     Forward
# Coutinho     P                Philippe Coutinho     143   LPOOL  Midfielder
# Vardy        J                      Jamie Vardy     143  LEICSC     Forward
# Son          H                    Heung Min Son     143   SPURS  Midfielder
# Azpilicueta  C                Cesar Azpilicueta     142    CHEL    Defender
# Firmino      R                  Roberto Firmino     140   LPOOL  Midfielder
# Benteke      C                Christian Benteke     139    LCFC     Forward
# Llorente     F                Fernando Llorente     137    SWAN     Forward
# Ozil         M                       Mesut Ozil     130    ARSL  Midfielder
# Mane         S                       Sadio Mane     129   LPOOL  Midfielder
# Courtois     T                 Thibaut Courtois     127    CHEL  Goalkeeper
# Rodriguez    P                  Pedro Rodriguez     127    CHEL  Midfielder
# Walker       K                      Kyle Walker     127   SPURS    Defender
# Wijnaldum    G              Georginio Wijnaldum     124   LPOOL  Midfielder
# Lloris       H                      Hugo Lloris     123   SPURS  Goalkeeper
# Zaha         W                     Wilfred Zaha     123    LCFC     Forward
# ...                                         ...     ...     ...         ...
# Remiro       A                 Alejandro Remiro       0    ATBI  Goalkeeper
# Lazo         J                 Jose Carlos Lazo       0    VIAL  Midfielder
# Olabe        R                    Roberto Olabe       0     NaN  Midfielder
# Schiappacase N             Nicolas Schiappacase       0     NaN     Forward
# Escandell    A                  Aaron Escandell       0    MALA  Goalkeeper
# Carbonell    A                   Alex Carbonell       0    BARC  Midfielder
# Zakaria      M                 Mohammed Zakaria       0     NaN     Forward
# Vidal        N                      Nacho Vidal       0    VALA    Defender
# Lopez        B                      Borja Lopez       0    BARC    Defender
# Cardona      M                     Marc Cardona       0    BARC     Forward
# Garcia       A                      Alex Garcia       0     NaN    Defender
# Nunez        R                    Roberto Nunez       0     NaN     Forward
# Salvador     C                Cristian Salvador       0     NaN  Midfielder
# Munoz        R                     Rafael Munoz       0     NaN    Defender
# Tejero       A                    Alvaro Tejero       0    MADR    Defender
# Pozo         A                        Alex Pozo       0    SEVI  Midfielder
# Munoz        A                       Alex Munoz       0    SEVI    Defender
# Zubikarai    E                  Enaut Zubikarai       0    RESO  Goalkeeper
# Mena         P                        Pepe Mena       0    SEVI     Forward
# Monsalve     N                   Nacho Monsalve       0    RCDC    Defender
# Fernandez    A                 Alvaro Fernandez      -1    OSAS  Goalkeeper
# Martins      L                     Luis Martins      -1     NaN    Defender
# Brignoli     A                 Alberto Brignoli      -1     NaN  Goalkeeper
# Gago         R                     Roberto Gago      -2    RCDE  Goalkeeper
# Duarte       R                     Ruben Duarte      -2    RCDE    Defender
# Mustafi      S                 Shkodran Mustafi      -2    VALA    Defender
# Tano         T                             Tano      -3    OSAS    Defender
# Marquez      I                     Ivan Marquez      -3    OSAS    Defender
# Gonzalez     D                   Diego Gonzalez      -3    SEVI    Defender
# Ciani        M                    Michael Ciani      -4    RCDE    Defender
#
#                            Start  Goals   A  CS  CS part  Yellow  Red  Sub  \
# Surname      FirstInitial
# Kane         H                29     29   7   0        0       3    0    1
# Sanchez      A                36     24  11   0        0       6    0    2
# Lukaku       R                36     25   6   0        0       3    0    1
# Costa        D                35     20   7   0        0      10    0    1
# Alli         D                35     18   7   0        0       4    0    2
# Hazard       E                36     16   7   0        0       3    0    0
# Sigurdsson   G                37      9  13   0        0       2    0    1
# Eriksen      C                36      8  15   0        0       0    0    2
# Aguero       S                25     20   3   0        0       4    1    6
# Defoe        J                37     15   2   0        0       1    0    0
# Alonso       M                30      6   3  15        0       2    0    4
# King         J                31     16   2   0        0       1    0    5
# Cahill       G                36      6   0  15        1       5    0    2
# Bruyne       K                33      6  18   0        0       4    0    4
# Ibrahimovic  Z                27     17   5   0        0       7    0    1
# Coutinho     P                28     13   7   0        0       2    0    3
# Vardy        J                33     13   5   0        0       2    1    2
# Son          H                23     14   6   0        0       2    0   13
# Azpilicueta  C                38      1   4  16        0       4    0    0
# Firmino      R                34     11   7   0        0       5    0    1
# Benteke      C                36     15   2   0        0      10    0    0
# Llorente     F                28     15   1   0        0       2    0    5
# Ozil         M                32      8   9   0        0       2    0    1
# Mane         S                26     13   5   0        0       4    0    1
# Courtois     T                36      0   0  16        0       1    0    0
# Rodriguez    P                26      9   9   0        0       6    0   11
# Walker       K                31      0   6  14        1       8    0    4
# Wijnaldum    G                33      6   9   0        0       2    0    4
# Lloris       H                34      0   0  15        0       0    0    0
# Zaha         W                34      7   9   0        0       8    0    1
# ...                          ...    ...  ..  ..      ...     ...  ...  ...
# Remiro       A                 0      0   0   0        0       0    0    6
# Lazo         J                 0      0   0   0        0       0    0    1
# Olabe        R                 0      0   0   0        0       0    0    1
# Schiappacase N                 0      0   0   0        0       0    0    1
# Escandell    A                 0      0   0   0        0       0    0    2
# Carbonell    A                 0      0   0   0        0       0    0    1
# Zakaria      M                 0      0   0   0        0       0    0    1
# Vidal        N                 0      0   0   0        0       0    0    1
# Lopez        B                 0      0   0   0        0       0    0    1
# Cardona      M                 0      0   0   0        0       0    0    1
# Garcia       A                 0      0   0   0        0       0    0    1
# Nunez        R                 0      0   0   0        0       0    0    1
# Salvador     C                 0      0   0   0        0       0    0    1
# Munoz        R                 0      0   0   0        0       0    0    1
# Tejero       A                 0      0   0   0        0       0    0    2
# Pozo         A                 0      0   0   0        0       0    0    1
# Munoz        A                 0      0   0   0        0       0    0    1
# Zubikarai    E                 0      0   0   0        0       0    0    1
# Mena         P                 0      0   0   0        0       0    0    1
# Monsalve     N                 0      0   0   0        0       0    0    2
# Fernandez    A                 0      0   0   0        0       0    0    5
# Martins      L                 1      0   0   0        0       0    0    1
# Brignoli     A                 0      0   0   0        0       0    0   14
# Gago         R                 3      0   0   0        0       0    0   29
# Duarte       R                 1      0   0   0        0       1    0   26
# Mustafi      S                 0      0   0   0        0       0    0    1
# Tano         T                 9      0   0   0        0       2    0   11
# Marquez      I                 4      0   0   0        0       4    0    2
# Gonzalez     D                 0      0   0   0        0       0    0    4
# Ciani        M                 0      0   0   0        0       0    0    1
#
#                            CO  Off  Pen SV  Pen M  Goals conceded  \
# Surname      FirstInitial
# Kane         H              1   16       0      1               0
# Sanchez      A              2    8       0      1               0
# Lukaku       R              1    2       0      0               0
# Costa        D              0    8       0      1               0
# Alli         D              2   13       0      0               0
# Hazard       E              0   25       0      1               0
# Sigurdsson   G              1    2       0      0               0
# Eriksen      C              0   10       0      0               0
# Aguero       S              6    8       0      1               0
# Defoe        J              0    2       0      0               0
# Alonso       M              1    2       0      0              22
# King         J              5   13       0      1               0
# Cahill       G              1    1       0      0              30
# Bruyne       K              3   11       0      1               0
# Ibrahimovic  Z              1    0       0      1               0
# Coutinho     P              3   19       0      0               0
# Vardy        J              2    8       0      0               0
# Son          H             11   15       0      0               0
# Azpilicueta  C              0    0       0      0              33
# Firmino      R              1    7       0      0               0
# Benteke      C              0    7       0      2               0
# Llorente     F              5   14       0      0               0
# Ozil         M              1    8       0      0               0
# Mane         S              1   13       0      0               0
# Courtois     T              0    0       0      0              28
# Rodriguez    P              9   20       0      0               0
# Walker       K              2    5       0      0              23
# Wijnaldum    G              3    9       0      0               0
# Lloris       H              0    1       0      0              24
# Zaha         W              1    7       0      0               0
# ...                        ..  ...     ...    ...             ...
# Remiro       A              0    0       0      0               0
# Lazo         J              0    0       0      0               0
# Olabe        R              0    0       0      0               0
# Schiappacase N              0    0       0      0               0
# Escandell    A              0    0       0      0               0
# Carbonell    A              0    0       0      0               0
# Zakaria      M              0    0       0      0               0
# Vidal        N              0    0       0      0               0
# Lopez        B              0    0       0      0               0
# Cardona      M              0    0       0      0               0
# Garcia       A              0    0       0      0               0
# Nunez        R              0    0       0      0               0
# Salvador     C              0    0       0      0               0
# Munoz        R              0    0       0      0               0
# Tejero       A              1    0       0      0               2
# Pozo         A              0    0       0      0               0
# Munoz        A              0    0       0      0               0
# Zubikarai    E              0    0       0      0               0
# Mena         P              0    0       0      0               0
# Monsalve     N              0    0       0      0               0
# Fernandez    A              1    0       0      0               3
# Martins      L              1    1       0      0               6
# Brignoli     A              2    1       0      0               5
# Gago         R              1    0       0      0              13
# Duarte       R              2    1       0      0               8
# Mustafi      S              1    0       0      0               4
# Tano         T              2    3       0      0              32
# Marquez      I              0    0       0      0              11
# Gonzalez     D              3    0       0      0               9
# Ciani        M              1    0       0      0               6
#
#                            Conceded 1+  OG  Firstname
# Surname      FirstInitial
# Kane         H                       0   0      Harry
# Sanchez      A                       0   0     Alexis
# Lukaku       R                       0   0     Romelu
# Costa        D                       0   0      Diego
# Alli         D                       0   0       Dele
# Hazard       E                       0   0       Eden
# Sigurdsson   G                       0   0      Gylfi
# Eriksen      C                       0   0  Christian
# Aguero       S                       0   0     Sergio
# Defoe        J                       0   0    Jermain
# Alonso       M                       6   0     Marcos
# King         J                       0   0     Joshua
# Cahill       G                       9   1       Gary
# Bruyne       K                       0   0      Kevin
# Ibrahimovic  Z                       0   0     Zlatan
# Coutinho     P                       0   0   Philippe
# Vardy        J                       0   0      Jamie
# Son          H                       0   0      Heung
# Azpilicueta  C                      11   0      Cesar
# Firmino      R                       0   0    Roberto
# Benteke      C                       0   0  Christian
# Llorente     F                       0   0   Fernando
# Ozil         M                       0   0      Mesut
# Mane         S                       0   0      Sadio
# Courtois     T                       8   0    Thibaut
# Rodriguez    P                       0   0      Pedro
# Walker       K                       5   0       Kyle
# Wijnaldum    G                       0   0  Georginio
# Lloris       H                       5   0       Hugo
# Zaha         W                       0   0    Wilfred
# ...                                ...  ..        ...
# Remiro       A                       0   0  Alejandro
# Lazo         J                       0   0       Jose
# Olabe        R                       0   0    Roberto
# Schiappacase N                       0   0    Nicolas
# Escandell    A                       0   0      Aaron
# Carbonell    A                       0   0       Alex
# Zakaria      M                       0   0   Mohammed
# Vidal        N                       0   0      Nacho
# Lopez        B                       0   0      Borja
# Cardona      M                       0   0       Marc
# Garcia       A                       0   0       Alex
# Nunez        R                       0   0    Roberto
# Salvador     C                       0   0   Cristian
# Munoz        R                       0   0     Rafael
# Tejero       A                       1   0     Alvaro
# Pozo         A                       0   0       Alex
# Munoz        A                       0   0       Alex
# Zubikarai    E                       0   0      Enaut
# Mena         P                       0   0       Pepe
# Monsalve     N                       0   0      Nacho
# Fernandez    A                       2   0     Alvaro
# Martins      L                       4   0       Luis
# Brignoli     A                       3   0    Alberto
# Gago         R                       9   0    Roberto
# Duarte       R                       5   0      Ruben
# Mustafi      S                       3   0   Shkodran
# Tano         T                      21   0       Tano
# Marquez      I                       7   0       Ivan
# Gonzalez     D                       6   0      Diego
# Ciani        M                       5   0    Michael
#
# [1768 rows x 20 columns]

# %%
SEA1617.to_csv('../../data/prep/FANTASY1617.csv')
