# %%
import os.path
import numpy as np
import pandas as pd

# %%
Fifa = pd.read_csv("../../data/prep/FIFA18.csv")

# %%
Fantasy1516= pd.read_csv("../../data/prep/Fantasy1516.csv")

# %%
Join1516 = pd.merge(Fifa, Fantasy1516, on=['Surname','FirstInitial'])

# %%
Join1516.drop(Join1516.columns[[0]], axis=1, inplace=True)

# %%
Join1516.head()
# Out:
#        ID               name                     full_name  \
# 0   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 1  158023           L. Messi                  Lionel Messi
# 2  190871             Neymar    Neymar da Silva Santos Jr.
# 3  176580          L. Suarez                   Luis Suarez
# 4  225591          L. Suarez               Leonardo Suarez
#
#                   club                                club_logo  special  age  \
# 0       Real Madrid CF  https://cdn.sofifa.org/18/teams/243.png     2228   32
# 1         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2158   30
# 2  Paris Saint-Germain   https://cdn.sofifa.org/18/teams/73.png     2100   25
# 3         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2291   30
# 4        Villarreal CF  https://cdn.sofifa.org/18/teams/483.png     1673   21
#
#                      league  birth_date  height_cm    ...      CO Off  Pen SV  \
# 0  Spanish Primera Division  1985-02-05      185.0    ...       0   2       0
# 1  Spanish Primera Division  1987-06-24      170.0    ...       2   2       0
# 2            French Ligue 1  1992-02-05      175.0    ...       0   1       0
# 3  Spanish Primera Division  1987-01-24      182.0    ...       0   0       0
# 4  Spanish Primera Division  1996-03-30      167.0    ...       0   0       0
#
#   Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 0     2              0           0   0    36  7.611111  Cristiano
# 1     3              0           0   0    33  7.060606     Lionel
# 2     2              0           0   0    34  6.382353     Neymar
# 3     2              0           0   0    35  8.800000       Luis
# 4     2              0           0   0    35  8.800000       Luis
#
# [5 rows x 210 columns]

# %%
i = 0
array = []

while i < len(Join1516):
    if Join1516['Firstname'][i] in Join1516['name'][i] or Join1516['Firstname'][i] in Join1516['full_name'][i]:
        array.append(True)
        i+=1
    else:
        array.append(False)
        i+=1

# %%
array = np.array(array)

# %%
Join1516 = Join1516[array]

# %%
Error1516 = Join1516[(Join1516['Players'].isin(Join1516['Players'][Join1516['Players'].duplicated()]) | Join1516['full_name'].isin(Join1516['full_name'][Join1516['full_name'].duplicated()]))]
Error1516.head()
# Out:
#         ID          name                     full_name                club  \
# 13  192985  K. De Bruyne               Kevin De Bruyne     Manchester City
# 14  192985  K. De Bruyne               Kevin De Bruyne     Manchester City
# 46  176676       Marcelo       Marcelo Vieira da Silva      Real Madrid CF
# 47  176676       Marcelo       Marcelo Vieira da Silva      Real Madrid CF
# 48  180334       Marcelo  Marcelo Antonio Guedes Filho  Olympique Lyonnais
#
#                                   club_logo  special  age  \
# 13   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 14   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 46  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 47  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 48   https://cdn.sofifa.org/18/teams/66.png     1789   30
#
#                       league  birth_date  height_cm    ...      CO Off  \
# 13    English Premier League  1991-06-28      181.0    ...       3   4
# 14    English Premier League  1991-06-28      181.0    ...       0   1
# 46  Spanish Primera Division  1988-05-12      174.0    ...       0   0
# 47  Spanish Primera Division  1988-05-12      174.0    ...       2   3
# 48            French Ligue 1  1987-05-20      191.0    ...       0   0
#
#     Pen SV Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 13       0     0              0           0   0    25  4.520000      Kevin
# 14       0     0              0           0   0     2  1.500000      Kevin
# 46       0     0             34          18   0    19  1.736842    Marcelo
# 47       0     0             26           7   0    30  3.700000    Marcelo
# 48       0     0             34          18   0    19  1.736842    Marcelo
#
# [5 rows x 210 columns]

# %%
leagues = ['German Bundesliga','Spanish Primera Division','English Premier League','French Ligue 1','Italian Serie A']
TopLeagues1516 = Error1516[(Error1516.league.str.contains('|'.join(leagues)) == True) | Error1516['league'].isnull()]

# %%
Delete1516 = Error1516[Error1516.league.str.contains('|'.join(leagues)) == False]
Delete1516.head()
# Out:
#         ID          name                    full_name  \
# 50  205340       Marcelo  Marcelo dos Santos Ferreira
# 51  205340       Marcelo  Marcelo dos Santos Ferreira
# 58  214378      D. Silva                  David Silva
# 88  192009  J. Rodriguez       Jose Antonio Rodriguez
# 91  140038  J. Rodriguez         Juan Pablo Rodriguez
#
#                           club                                   club_logo  \
# 50                  Rio Ave FC     https://cdn.sofifa.org/18/teams/744.png
# 51                  Rio Ave FC     https://cdn.sofifa.org/18/teams/744.png
# 58  CD Los Millionarios Bogota  https://cdn.sofifa.org/18/teams/101105.png
# 88                Club Tijuana  https://cdn.sofifa.org/18/teams/111678.png
# 91            Monarcas Morelia    https://cdn.sofifa.org/18/teams/1028.png
#
#     special  age                    league  birth_date  height_cm    ...      \
# 50     1625   27  Portuguese Primeira Liga  1989-07-27      182.0    ...
# 51     1625   27  Portuguese Primeira Liga  1989-07-27      182.0    ...
# 58     1939   30       Colombian Primera A  1986-12-13      175.0    ...
# 88     1180   24           Mexican Liga MX  1992-07-04      185.0    ...
# 91     1852   37           Mexican Liga MX  1979-08-07      166.0    ...
#
#     CO Off  Pen SV Pen M Goals conceded Conceded 1+  OG  Apps      Form  \
# 50   0   0       0     0             34          18   0    19  1.736842
# 51   2   3       0     0             26           7   0    30  3.700000
# 58   2  12       0     0              0           0   0    24  4.166667
# 88   1   0       0     0              0           0   0     1  1.000000
# 91   2  10       0     0              0           0   1    32  1.718750
#
#     Firstname
# 50    Marcelo
# 51    Marcelo
# 58      David
# 88       Jose
# 91       Juan
#
# [5 rows x 210 columns]

# %%
Fix1516 = TopLeagues1516[(TopLeagues1516['Players'].isin(TopLeagues1516['Players'][TopLeagues1516['Players'].duplicated()]) | TopLeagues1516['full_name'].isin(TopLeagues1516['full_name'][TopLeagues1516['full_name'].duplicated()]))]
Fix1516.head()
# Out:
#         ID          name                     full_name                club  \
# 13  192985  K. De Bruyne               Kevin De Bruyne     Manchester City
# 14  192985  K. De Bruyne               Kevin De Bruyne     Manchester City
# 46  176676       Marcelo       Marcelo Vieira da Silva      Real Madrid CF
# 47  176676       Marcelo       Marcelo Vieira da Silva      Real Madrid CF
# 48  180334       Marcelo  Marcelo Antonio Guedes Filho  Olympique Lyonnais
#
#                                   club_logo  special  age  \
# 13   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 14   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 46  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 47  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 48   https://cdn.sofifa.org/18/teams/66.png     1789   30
#
#                       league  birth_date  height_cm    ...      CO Off  \
# 13    English Premier League  1991-06-28      181.0    ...       3   4
# 14    English Premier League  1991-06-28      181.0    ...       0   1
# 46  Spanish Primera Division  1988-05-12      174.0    ...       0   0
# 47  Spanish Primera Division  1988-05-12      174.0    ...       2   3
# 48            French Ligue 1  1987-05-20      191.0    ...       0   0
#
#     Pen SV Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 13       0     0              0           0   0    25  4.520000      Kevin
# 14       0     0              0           0   0     2  1.500000      Kevin
# 46       0     0             34          18   0    19  1.736842    Marcelo
# 47       0     0             26           7   0    30  3.700000    Marcelo
# 48       0     0             34          18   0    19  1.736842    Marcelo
#
# [5 rows x 210 columns]

# %%
Join1516 = Join1516[(~(Join1516.full_name.isin(Delete1516.full_name) & Join1516.birth_date.isin(Delete1516.birth_date)))]
Join1516 = Join1516[(~(Join1516.full_name.isin(Fix1516.full_name) & Join1516.birth_date.isin(Fix1516.birth_date)))]

# %%
Fixed1516 = Fix1516[Fix1516['full_name'] == Fix1516['Players']]
Fixed1516.head()
# Out:
#          ID          name        full_name             club  \
# 13   192985  K. De Bruyne  Kevin De Bruyne  Manchester City
# 14   192985  K. De Bruyne  Kevin De Bruyne  Manchester City
# 205  181458    I. Perisic     Ivan Perisic            Inter
# 206  181458    I. Perisic     Ivan Perisic            Inter
# 247  192387   C. Immobile    Ciro Immobile            Lazio
#
#                                   club_logo  special  age  \
# 13   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 14   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 205  https://cdn.sofifa.org/18/teams/44.png     2078   28
# 206  https://cdn.sofifa.org/18/teams/44.png     2078   28
# 247  https://cdn.sofifa.org/18/teams/46.png     1968   27
#
#                      league  birth_date  height_cm    ...      CO Off  Pen SV  \
# 13   English Premier League  1991-06-28      181.0    ...       3   4       0
# 14   English Premier League  1991-06-28      181.0    ...       0   1       0
# 205         Italian Serie A  1989-02-02      187.0    ...       0   1       0
# 206         Italian Serie A  1989-02-02      187.0    ...       8   8       0
# 247         Italian Serie A  1990-02-20      185.0    ...       4   4       0
#
#     Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 13      0              0           0   0    25  4.520000      Kevin
# 14      0              0           0   0     2  1.500000      Kevin
# 205     0              0           0   0     2  4.500000       Ivan
# 206     0              0           0   0    34  3.176471       Ivan
# 247     0              0           0   0     8  2.500000       Ciro
#
# [5 rows x 210 columns]

# %%
Fixed1516 = Fixed1516[(Fixed1516['Players'].isin(Fixed1516['Players'][Fixed1516['Players'].duplicated()]) | Fixed1516['full_name'].isin(Fixed1516['full_name'][Fixed1516['full_name'].duplicated()]))]
Fixed1516.head()
# Out:
#          ID          name        full_name             club  \
# 13   192985  K. De Bruyne  Kevin De Bruyne  Manchester City
# 14   192985  K. De Bruyne  Kevin De Bruyne  Manchester City
# 205  181458    I. Perisic     Ivan Perisic            Inter
# 206  181458    I. Perisic     Ivan Perisic            Inter
# 247  192387   C. Immobile    Ciro Immobile            Lazio
#
#                                   club_logo  special  age  \
# 13   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 14   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 205  https://cdn.sofifa.org/18/teams/44.png     2078   28
# 206  https://cdn.sofifa.org/18/teams/44.png     2078   28
# 247  https://cdn.sofifa.org/18/teams/46.png     1968   27
#
#                      league  birth_date  height_cm    ...      CO Off  Pen SV  \
# 13   English Premier League  1991-06-28      181.0    ...       3   4       0
# 14   English Premier League  1991-06-28      181.0    ...       0   1       0
# 205         Italian Serie A  1989-02-02      187.0    ...       0   1       0
# 206         Italian Serie A  1989-02-02      187.0    ...       8   8       0
# 247         Italian Serie A  1990-02-20      185.0    ...       4   4       0
#
#     Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 13      0              0           0   0    25  4.520000      Kevin
# 14      0              0           0   0     2  1.500000      Kevin
# 205     0              0           0   0     2  4.500000       Ivan
# 206     0              0           0   0    34  3.176471       Ivan
# 247     0              0           0   0     8  2.500000       Ciro
#
# [5 rows x 210 columns]

# %%
Fixed1516[Fixed1516.duplicated(['Players', 'Clubs', 'Points'])]
# Out:
#          ID       name       full_name       club  \
# 417  174379  G. Castro  Gonzalo Castro  Malaga CF
#
#                                    club_logo  special  age  \
# 417  https://cdn.sofifa.org/18/teams/573.png     1878   32
#
#                        league  birth_date  height_cm    ...      CO Off  \
# 417  Spanish Primera Division  1984-09-14      178.0    ...       9   9
#
#      Pen SV Pen M Goals conceded Conceded 1+  OG  Apps  Form  Firstname
# 417       0     0              0           0   0    25  3.04    Gonzalo
#
# [1 rows x 210 columns]

# %%
Fixed1516 = Fixed1516[~Fixed1516.duplicated(['Players', 'Clubs', 'Points'])]
Fixed1516.head()
# Out:
#          ID          name        full_name             club  \
# 13   192985  K. De Bruyne  Kevin De Bruyne  Manchester City
# 14   192985  K. De Bruyne  Kevin De Bruyne  Manchester City
# 205  181458    I. Perisic     Ivan Perisic            Inter
# 206  181458    I. Perisic     Ivan Perisic            Inter
# 247  192387   C. Immobile    Ciro Immobile            Lazio
#
#                                   club_logo  special  age  \
# 13   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 14   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 205  https://cdn.sofifa.org/18/teams/44.png     2078   28
# 206  https://cdn.sofifa.org/18/teams/44.png     2078   28
# 247  https://cdn.sofifa.org/18/teams/46.png     1968   27
#
#                      league  birth_date  height_cm    ...      CO Off  Pen SV  \
# 13   English Premier League  1991-06-28      181.0    ...       3   4       0
# 14   English Premier League  1991-06-28      181.0    ...       0   1       0
# 205         Italian Serie A  1989-02-02      187.0    ...       0   1       0
# 206         Italian Serie A  1989-02-02      187.0    ...       8   8       0
# 247         Italian Serie A  1990-02-20      185.0    ...       4   4       0
#
#     Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 13      0              0           0   0    25  4.520000      Kevin
# 14      0              0           0   0     2  1.500000      Kevin
# 205     0              0           0   0     2  4.500000       Ivan
# 206     0              0           0   0    34  3.176471       Ivan
# 247     0              0           0   0     8  2.500000       Ciro
#
# [5 rows x 210 columns]

# %%
d = {
 'ID' : 'first',
 'club_logo':'first',
 'special':'first',
 'age':'first',
 'league':'first',
 'birth_date':'first',
 'height_cm':'first',
 'weight_kg':'first',
 'body_type':'first',
 'real_face':'first',
 'flag':'first',
 'nationality':'first',
 'photo':'first',
 'eur_value':'first',
 'eur_wage':'first',
 'eur_release_clause':'first',
 'overall':'first',
 'potential':'first',
 'pac':'first',
 'sho':'first',
 'pas':'first',
 'dri':'first',
 'def':'first',
 'phy':'first',
 'international_reputation':'first',
 'skill_moves':'first',
 'weak_foot':'first',
 'work_rate_att':'first',
 'work_rate_def':'first',
 'preferred_foot':'first',
 'crossing':'first',
 'finishing':'first',
 'heading_accuracy':'first',
 'short_passing':'first',
 'volleys':'first',
 'dribbling':'first',
 'curve':'first',
 'free_kick_accuracy':'first',
 'long_passing':'first',
 'ball_control':'first',
 'acceleration':'first',
 'sprint_speed':'first',
 'agility':'first',
 'reactions':'first',
 'balance':'first',
 'shot_power':'first',
 'jumping':'first',
 'stamina':'first',
 'strength':'first',
 'long_shots':'first',
 'aggression':'first',
 'interceptions':'first',
 'positioning':'first',
 'vision':'first',
 'penalties':'first',
 'composure':'first',
 'marking':'first',
 'standing_tackle':'first',
 'sliding_tackle':'first',
 'gk_diving':'first',
 'gk_handling':'first',
 'gk_kicking':'first',
 'gk_positioning':'first',
 'gk_reflexes':'first',
 'rs':'first',
 'rw':'first',
 'rf':'first',
 'ram':'first',
 'rcm':'first',
 'rm':'first',
 'rdm':'first',
 'rcb':'first',
 'rb':'first',
 'rwb':'first',
 'st':'first',
 'lw':'first',
 'cf':'first',
 'cam':'first',
 'cm':'first',
 'lm':'first',
 'cdm':'first',
 'cb':'first',
 'lb':'first',
 'lwb':'first',
 'ls':'first',
 'lf':'first',
 'lam':'first',
 'lcm':'first',
 'ldm':'first',
 'lcb':'first',
 'gk':'first',
 '1_on_1_rush_trait':'first',
 'acrobatic_clearance_trait':'first',
 'argues_with_officials_trait':'first',
 'avoids_using_weaker_foot_trait':'first',
 'backs_into_player_trait':'first',
 'bicycle_kicks_trait':'first',
 'cautious_with_crosses_trait':'first',
 'chip_shot_trait':'first',
 'chipped_penalty_trait':'first',
 'comes_for_crosses_trait':'first',
 'corner_specialist_trait':'first',
 'diver_trait':'first',
 'dives_into_tackles_trait':'first',
 'diving_header_trait':'first',
 'driven_pass_trait':'first',
 'early_crosser_trait':'first',
 "fan's_favourite_trait":'first',
 'fancy_flicks_trait':'first',
 'finesse_shot_trait':'first',
 'flair_trait':'first',
 'flair_passes_trait':'first',
 'gk_flat_kick_trait':'first',
 'gk_long_throw_trait':'first',
 'gk_up_for_corners_trait':'first',
 'giant_throw_in_trait':'first',
 'inflexible_trait':'first',
 'injury_free_trait':'first',
 'injury_prone_trait':'first',
 'leadership_trait':'first',
 'long_passer_trait':'first',
 'long_shot_taker_trait':'first',
 'long_throw_in_trait':'first',
 'one_club_player_trait':'first',
 'outside_foot_shot_trait':'first',
 'playmaker_trait':'first',
 'power_free_kick_trait':'first',
 'power_header_trait':'first',
 'puncher_trait':'first',
 'rushes_out_of_goal_trait':'first',
 'saves_with_feet_trait':'first',
 'second_wind_trait':'first',
 'selfish_trait':'first',
 'skilled_dribbling_trait':'first',
 'stutter_penalty_trait':'first',
 'swerve_pass_trait':'first',
 'takes_finesse_free_kicks_trait':'first',
 'target_forward_trait':'first',
 'team_player_trait':'first',
 'technical_dribbler_trait':'first',
 'tries_to_beat_defensive_line_trait':'first',
 'poacher_speciality':'first',
 'speedster_speciality':'first',
 'aerial_threat_speciality':'first',
 'dribbler_speciality':'first',
 'playmaker_speciality':'first',
 'engine_speciality':'first',
 'distance_shooter_speciality':'first',
 'crosser_speciality':'first',
 'free_kick_specialist_speciality':'first',
 'tackling_speciality':'first',
 'tactician_speciality':'first',
 'acrobat_speciality':'first',
 'strength_speciality':'first',
 'clinical_finisher_speciality':'first',
 'prefers_rs':'first',
 'prefers_rw':'first',
 'prefers_rf':'first',
 'prefers_ram':'first',
 'prefers_rcm':'first',
 'prefers_rm':'first',
 'prefers_rdm':'first',
 'prefers_rcb':'first',
 'prefers_rb':'first',
 'prefers_rwb':'first',
 'prefers_st':'first',
 'prefers_lw':'first',
 'prefers_cf':'first',
 'prefers_cam':'first',
 'prefers_cm':'first',
 'prefers_lm':'first',
 'prefers_cdm':'first',
 'prefers_cb':'first',
 'prefers_lb':'first',
 'prefers_lwb':'first',
 'prefers_ls':'first',
 'prefers_lf':'first',
 'prefers_lam':'first',
 'prefers_lcm':'first',
 'prefers_ldm':'first',
 'prefers_lcb':'first',
 'prefers_gk':'first',
 'Players':'first',
 'Position':'first',
 'Clubs':'first',
 'Points':'sum',  
 'Start':'sum', 
 'Sub':'sum', 
 'club':'last',
 'Position':'first',
 'Start':'sum',
 'Goals':'sum',
 'A':'sum',
 'CS':'sum',
 'CS part':'sum',
 'Yellow':'sum',
 'Red':'sum',
 'Sub':'sum',
 'CO':'sum',
 'Off':'sum',
 'Pen SV':'sum',
 'Pen M':'sum',
 'Goals conceded':'sum',
 'Conceded 1+':'sum',
 'OG':'sum',
 'Firstname':'first',
 'Apps':'sum',
 'Form':'sum'
}

# %%
Fixed1516 = (Fixed1516.groupby(['name','full_name'], sort=False, as_index=False).agg(d).reindex(columns=Fix1516.columns))
Fixed1516.head()
# Out:
#        ID          name        full_name                    club  \
# 0  192985  K. De Bruyne  Kevin De Bruyne         Manchester City
# 1  181458    I. Perisic     Ivan Perisic                   Inter
# 2  192387   C. Immobile    Ciro Immobile                   Lazio
# 3  211300    A. Martial  Anthony Martial       Manchester United
# 4  204970    F. Thauvin  Florian Thauvin  Olympique de Marseille
#
#                                  club_logo  special  age  \
# 0   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 1   https://cdn.sofifa.org/18/teams/44.png     2078   28
# 2   https://cdn.sofifa.org/18/teams/46.png     1968   27
# 3   https://cdn.sofifa.org/18/teams/11.png     2052   21
# 4  https://cdn.sofifa.org/18/teams/219.png     1966   24
#
#                    league  birth_date  height_cm    ...      CO Off  Pen SV  \
# 0  English Premier League  1991-06-28      181.0    ...       3   5       0
# 1         Italian Serie A  1989-02-02      187.0    ...       8   9       0
# 2         Italian Serie A  1990-02-20      185.0    ...       7   8       0
# 3  English Premier League  1995-12-05      181.0    ...       3   3       0
# 4          French Ligue 1  1993-01-26      179.0    ...      15   9       0
#
#   Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 0     0              0           0   0    27  6.020000      Kevin
# 1     0              0           0   0    36  7.676471       Ivan
# 2     1              0           0   0    22  6.214286       Ciro
# 3     0              0           0   0    34  6.698925    Anthony
# 4     0              0           0   0    29  3.278846    Florian
#
# [5 rows x 210 columns]

# %%
Fixed1516[['full_name','club','Players','Clubs','Points']]
# Out:
#                full_name                    club               Players  \
# 0        Kevin De Bruyne         Manchester City       Kevin De Bruyne
# 1           Ivan Perisic                   Inter          Ivan Perisic
# 2          Ciro Immobile                   Lazio         Ciro Immobile
# 3        Anthony Martial       Manchester United       Anthony Martial
# 4        Florian Thauvin  Olympique de Marseille       Florian Thauvin
# 5          Heung Min Son       Tottenham Hotspur         Heung Min Son
# 6          Juan Cuadrado                Juventus         Juan Cuadrado
# 7         Federico Fazio                    Roma        Federico Fazio
# 8       Javier Hernandez         West Ham United      Javier Hernandez
# 9         Gonzalo Castro       Borussia Dortmund        Gonzalo Castro
# 10       Andrej Kramaric     TSG 1899 Hoffenheim       Andrej Kramaric
# 11       Pablo Hernandez        RC Celta de Vigo       Pablo Hernandez
# 12        Kingsley Coman        FC Bayern Munich        Kingsley Coman
# 13        Nordin Amrabat              CD Leganes        Nordin Amrabat
# 14    Abdoulaye Doucoure                 Watford    Abdoulaye Doucoure
# 15          Takashi Inui                SD Eibar          Takashi Inui
# 16          Simone Verdi                 Bologna          Simone Verdi
# 17          Wahbi Khazri        Stade Rennais FC          Wahbi Khazri
# 18  Emanuele Giaccherini                  Napoli  Emanuele Giaccherini
# 19       Marco Andreolli                Cagliari       Marco Andreolli
# 20          Mario Lemina             Southampton          Mario Lemina
# 21          Mauro Zarate                 Watford          Mauro Zarate
# 22          Jhon Cordoba              1. FC Koln          Jhon Cordoba
# 23       Mathieu Debuchy                 Arsenal       Mathieu Debuchy
# 24         Adnan Januzaj           Real Sociedad         Adnan Januzaj
# 25          Henri Saivet        Newcastle United          Henri Saivet
# 26      Alberto Paloschi          Ferrara (SPAL)      Alberto Paloschi
# 27          Ola Toivonen             Toulouse FC          Ola Toivonen
# 28       Claudio Beauvue              CD Leganes       Claudio Beauvue
# 29          Adama Traore               AS Monaco          Adama Traore
# 30         Milan Bisevac                 FC Metz         Milan Bisevac
# 31        Franck Tabanou    En Avant de Guingamp        Franck Tabanou
# 32     Cristiano Biraghi              Fiorentina     Cristiano Biraghi
#
#       Clubs  Points
# 0      MCFC     116
# 1       VFL     117
# 2      SEVI      72
# 3      MUFC     133
# 4      NEWU      49
# 5     SPURS      66
# 6      CHEL      78
# 7     SPURS       5
# 8      MUFC     139
# 9       BD1      76
# 10   LEICSC      57
# 11     RAVA     141
# 12      BM1      83
# 13      WFC      32
# 14     STRE      71
# 15       EF      70
# 16      NaN      35
# 17     SUND     114
# 18     SUND      83
# 19     SEVI       5
# 20     JUVE      28
# 21  WESTHAM      72
# 22      NaN      65
# 23     ARSL      19
# 24     MUFC      20
# 25     NEWU      48
# 26     SWAN     111
# 27     SUND      27
# 28     RCCV      88
# 29   AVILLA      24
# 30     LAZI      56
# 31     SWAN      16
# 32     CHIE      47

# %%
Joined1516 = pd.concat([Join1516,Fixed1516])
Joined1516 = Joined1516.reset_index()

# %%
Joined1516.drop(Joined1516.columns[[0]], axis=1, inplace=True)

# %%
Joined1516.head()
# Out:
#        ID               name                     full_name  \
# 0   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 1  158023           L. Messi                  Lionel Messi
# 2  190871             Neymar    Neymar da Silva Santos Jr.
# 3  176580          L. Suarez                   Luis Suarez
# 4  167495           M. Neuer                  Manuel Neuer
#
#                   club                                club_logo  special  age  \
# 0       Real Madrid CF  https://cdn.sofifa.org/18/teams/243.png     2228   32
# 1         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2158   30
# 2  Paris Saint-Germain   https://cdn.sofifa.org/18/teams/73.png     2100   25
# 3         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2291   30
# 4     FC Bayern Munich   https://cdn.sofifa.org/18/teams/21.png     1493   31
#
#                      league  birth_date  height_cm    ...      CO Off  Pen SV  \
# 0  Spanish Primera Division  1985-02-05      185.0    ...       0   2       0
# 1  Spanish Primera Division  1987-06-24      170.0    ...       2   2       0
# 2            French Ligue 1  1992-02-05      175.0    ...       0   1       0
# 3  Spanish Primera Division  1987-01-24      182.0    ...       0   0       0
# 4         German Bundesliga  1986-03-27      193.0    ...       0   1       0
#
#   Pen M Goals conceded Conceded 1+  OG  Apps      Form  Firstname
# 0     2              0           0   0    36  7.611111  Cristiano
# 1     3              0           0   0    33  7.060606     Lionel
# 2     2              0           0   0    34  6.382353     Neymar
# 3     2              0           0   0    35  8.800000       Luis
# 4     0             17           3   0    34  4.264706     Manuel
#
# [5 rows x 210 columns]

# %%
Joined1516.to_csv('../../data/prep/Joined1516.csv')
