# %%
import os.path
import numpy as np
import pandas as pd

# %%
BPL1314 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=449")[0]
BUN1314 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=447")[0]
LAL1314 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=461")[0]

# %%
SEA1314 = [BPL1314,BUN1314,LAL1314]
SEA1314 = pd.concat(SEA1314)
SEA1314 = SEA1314.reset_index()

# %%
SEA1314.head()
# Out:
#    index           Players  Points  Clubs    Position  Start  Goals   A CS  \
# 0      0       Luis Suarez     254  LPOOL     Forward     33     31  13  -
# 1      1        Yaya Toure     193   MCFC  Midfielder     35     20   9  -
# 2      2  Daniel Sturridge     177  LPOOL     Forward     26     21   7  -
# 3      3    Olivier Giroud     172   ARSL     Forward     36     16   8  -
# 4      4    Steven Gerrard     162  LPOOL  Midfielder     33     13  13  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    0   0    3       -     0               -           -
# 1       -  ...     0    1   0   10       -     0               -           -
# 2       -  ...     0    3   3   13       -     1               -           -
# 3       -  ...     0    1   0   16       -     0               -           -
# 4       -  ...     0    1   1    6       -     1               -           -
#
#   OG  More
# 0  0  More
# 1  0  More
# 2  0  More
# 3  0  More
# 4  0  More
#
# [5 rows x 21 columns]

# %%
SEA1314.drop(SEA1314.columns[[0,20]], axis=1, inplace=True)

# %%
SEA1314.head()
# Out:
#             Players  Points  Clubs    Position  Start  Goals   A CS CS part  \
# 0       Luis Suarez     254  LPOOL     Forward     33     31  13  -       -
# 1        Yaya Toure     193   MCFC  Midfielder     35     20   9  -       -
# 2  Daniel Sturridge     177  LPOOL     Forward     26     21   7  -       -
# 3    Olivier Giroud     172   ARSL     Forward     36     16   8  -       -
# 4    Steven Gerrard     162  LPOOL  Midfielder     33     13  13  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       6    0    0   0    3      -      0              -           -   0
# 1       4    0    1   0   10      -      0              -           -   0
# 2       2    0    3   3   13      -      1              -           -   0
# 3       4    0    1   0   16      -      0              -           -   0
# 4       7    0    1   1    6      -      1              -           -   0

# %%
SEA1314.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             298
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]
SEA1314[DashColumns] = SEA1314[DashColumns].replace('-' ,'0')

# %%
SEA1314.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1750 entries, 0 to 1749
# Data columns (total 19 columns):
# Players           1750 non-null object
# Points            1750 non-null int64
# Clubs             1452 non-null object
# Position          1750 non-null object
# Start             1750 non-null int64
# Goals             1750 non-null int64
# A                 1750 non-null int64
# CS                1750 non-null object
# CS part           1750 non-null object
# Yellow            1750 non-null int64
# Red               1750 non-null int64
# Sub               1750 non-null int64
# CO                1750 non-null int64
# Off               1750 non-null int64
# Pen SV            1750 non-null object
# Pen M             1750 non-null int64
# Goals conceded    1750 non-null object
# Conceded 1+       1750 non-null object
# OG                1750 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 259.8+ KB

# %%
SEA1314['CS'] = SEA1314['CS'].str.replace('%','').astype(np.int)
SEA1314['CS part'] = SEA1314['CS part'].str.replace('%','').astype(np.int)
SEA1314['Pen SV'] = SEA1314['Pen SV'].str.replace('%','').astype(np.int)
SEA1314['Goals conceded'] = SEA1314['Goals conceded'].str.replace('%','').astype(np.int)
SEA1314['Conceded 1+'] = SEA1314['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 1, 'FirstInitial'] = SEA1314['Players'].astype(str).str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 1, 'Firstname'] = SEA1314['Players'].str.split().str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 1, 'Surname'] = SEA1314['Players'].str.split().str[0]

SEA1314.loc[SEA1314['Players'].str.split().str.len() == 2, 'FirstInitial'] = SEA1314['Players'].astype(str).str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 2, 'Firstname'] = SEA1314['Players'].str.split().str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 2, 'Surname'] = SEA1314['Players'].str.split().str[-1]

SEA1314.loc[SEA1314['Players'].str.split().str.len() == 3, 'FirstInitial'] = SEA1314['Players'].astype(str).str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 3, 'Firstname'] = SEA1314['Players'].str.split().str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 3, 'Surname'] = SEA1314['Players'].str.split().str[-1]

SEA1314.loc[SEA1314['Players'].str.split().str.len() == 4, 'FirstInitial'] = SEA1314['Players'].astype(str).str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 4, 'Firstname'] = SEA1314['Players'].str.split().str[0]
SEA1314.loc[SEA1314['Players'].str.split().str.len() == 4, 'Surname'] = SEA1314['Players'].str.split().str[-1]

# %%
SEA1314.set_index(['Surname','FirstInitial'])
# Out:
#                                      Players  Points  Clubs    Position  \
# Surname     FirstInitial
# Suarez      L                    Luis Suarez     254  LPOOL     Forward
# Toure       Y                     Yaya Toure     193   MCFC  Midfielder
# Sturridge   D               Daniel Sturridge     177  LPOOL     Forward
# Giroud      O                 Olivier Giroud     172   ARSL     Forward
# Gerrard     S                 Steven Gerrard     162  LPOOL  Midfielder
# Rooney      W                   Wayne Rooney     160   MUFC     Forward
# Lambert     R                  Ricky Lambert     158  SOTOM     Forward
# Hazard      E                    Eden Hazard     156   CHEL  Midfielder
# Lukaku      R                  Romelu Lukaku     154   CHEL     Forward
# Coleman     S                 Seamus Coleman     149   EVER    Defender
# Bony        W                  Wilfried Bony     149   SWAN     Forward
# Rodriguez   J                  Jay Rodriguez     142  SOTOM     Forward
# Aguero      S                  Sergio Aguero     140   MCFC     Forward
# Ivanovic    B             Branislav Ivanovic     139   CHEL    Defender
# Dzeko       E                     Edin Dzeko     136   MCFC     Forward
# Lallana     A                   Adam Lallana     135  SOTOM  Midfielder
# Terry       J                     John Terry     132   CHEL    Defender
# Baines      L                Leighton Baines     131   EVER    Defender
# Zabaleta    P                 Pablo Zabaleta     127   MCFC    Defender
# Cech        P                      Petr Cech     126   CHEL  Goalkeeper
# Cahill      G                    Gary Cahill     125   CHEL    Defender
# Remy        L                      Loic Remy     122   NEWU     Forward
# Szczesny    W              Wojciech Szczesny     121   ARSL  Goalkeeper
# Mertesacker P                Per Mertesacker     121   ARSL    Defender
# Howard      T                     Tim Howard     121   EVER  Goalkeeper
# Koscielny   L              Laurent Koscielny     119   ARSL    Defender
# Mirallas    K                 Kevin Mirallas     118   EVER     Forward
# Fonte       J                     Jose Fonte     118  SOTOM    Defender
# Johnson     A                   Adam Johnson     117   SUND  Midfielder
# Sagna       B                   Bacary Sagna     116   ARSL    Defender
# ...                                      ...     ...    ...         ...
# Sanchez     O                 Oliver Sanchez       0    NaN  Goalkeeper
# Sivera      A                 Antonio Sivera       0   VALA  Goalkeeper
# Pozo        J                     Jesus Pozo       0   BETI    Defender
# Burgui      B                         Burgui       0   MADR     Forward
# Ruiz        S                  Salvador Ruiz       0   VALA    Defender
# Kaak        L                      Lion Kaak       0   VALA  Midfielder
# Aquino      D                    Dani Aquino       0    NaN     Forward
# Suarez      G                 Gonzalo Suarez       0   SEVI     Forward
# Kameni      C                  Carlos Kameni       0   MALA  Goalkeeper
# Lopez       S             Sergio Ayala Lopez       0   VALA    Defender
# Vazquez     L                  Lucas Vazquez       0   MADR  Midfielder
# Mascarell   O                 Omar Mascarell       0   MADR  Midfielder
# Tomas       R                  Raul de Tomas       0   MADR     Forward
# Success     I                  Isaac Success       0    NaN     Forward
# Aranda      C                  Carlos Aranda       0    NaN     Forward
# Kaka        K                           Kaka       0   MADR  Midfielder
# Parreno     G                 German Parreno      -1   RCDE  Goalkeeper
# Silva       M                  Marcelo Silva      -1    NaN    Defender
# Lopez       P                    Pedro Lopez      -1   BETI  Goalkeeper
# Chen        R                   Roberto Chen      -1   MALA    Defender
# Martinez    H               Hansley Martinez      -1    NaN    Defender
# Casado      J             Jose Manuel Casado      -1   MALA    Defender
# Galeano     L                 Leonal Galeano      -2   RAVA    Defender
# Lopez       B                    Borja Lopez      -2   RAVA    Defender
# Lopo        A                   Alberto Lopo      -2    NaN    Defender
# Caro        J                      Jose Caro      -2   BETI    Defender
# Aranzubia   D               Daniel Aranzubia      -2    NaN  Goalkeeper
# Steinhofer  M              Markus Steinhofer      -3   BETI    Defender
# Rodri       S                   Sergio Rodri      -3   RAVA    Defender
# Cobeno      D                   David Cobeno      -7   RAVA  Goalkeeper
#
#                           Start  Goals   A  CS  CS part  Yellow  Red  Sub  CO  \
# Surname     FirstInitial
# Suarez      L                33     31  13   0        0       6    0    0   0
# Toure       Y                35     20   9   0        0       4    0    1   0
# Sturridge   D                26     21   7   0        0       2    0    3   3
# Giroud      O                36     16   8   0        0       4    0    1   0
# Gerrard     S                33     13  13   0        0       7    0    1   1
# Rooney      W                27     17   9   0        0       8    0    2   2
# Lambert     R                31     13   9   0        0       2    0    6   6
# Hazard      E                32     14   7   0        0       2    0    3   3
# Lukaku      R                29     15   6   0        0       1    0    5   4
# Coleman     S                36      6   2  15        0       3    0    1   0
# Bony        W                27     16   4   0        0       4    0    8   7
# Rodriguez   J                30     15   2   0        0       2    0    3   3
# Aguero      S                20     17   6   0        0       4    0    3   3
# Ivanovic    B                36      3   1  16        0       8    0    0   0
# Dzeko       E                23     16   2   0        0       4    0   14   8
# Lallana     A                37      9   6   0        0       3    0    1   1
# Terry       J                34      2   1  16        0       3    0    0   0
# Baines      L                32      5   4  13        0       6    0    0   0
# Zabaleta    P                34      1   6  15        0      11    0    2   1
# Cech        P                34      0   0  16        0       0    0    0   0
# Cahill      G                29      1   1  16        1       2    0    8   1
# Remy        L                24     14   3   0        0       2    1    2   2
# Szczesny    W                37      0   0  16        0       2    0    1   0
# Mertesacker P                35      2   0  16        0       3    0    0   0
# Howard      T                37      0   1  15        0       4    1    0   0
# Koscielny   L                32      2   0  16        0       2    0    0   0
# Mirallas    K                28      8   8   0        0       6    0    7   4
# Fonte       J                35      3   0  15        0       7    0    3   1
# Johnson     A                28      8   5   0        0       2    0    9   8
# Sagna       B                34      1   2  15        1       6    0    1   1
# ...                         ...    ...  ..  ..      ...     ...  ...  ...  ..
# Sanchez     O                 0      0   0   0        0       0    0    1   0
# Sivera      A                 0      0   0   0        0       0    0    2   0
# Pozo        J                 0      0   0   0        0       0    0    3   0
# Burgui      B                 0      0   0   0        0       0    0    1   0
# Ruiz        S                 0      0   0   0        0       0    0    1   0
# Kaak        L                 0      0   0   0        0       0    0    1   0
# Aquino      D                 0      0   0   0        0       0    0    1   0
# Suarez      G                 0      0   0   0        0       0    0    1   0
# Kameni      C                 0      0   0   0        0       0    0   37   0
# Lopez       S                 0      0   0   0        0       0    0    1   0
# Vazquez     L                 0      0   0   0        0       0    0    1   0
# Mascarell   O                 0      0   0   0        0       0    0    1   0
# Tomas       R                 0      0   0   0        0       0    0    1   0
# Success     I                 0      0   0   0        0       0    0    2   0
# Aranda      C                 0      0   0   0        0       0    0    1   0
# Kaka        K                 0      0   0   0        0       0    0    2   0
# Parreno     G                 1      0   0   0        0       0    0   37   0
# Silva       M                 1      0   0   0        0       0    0   21   1
# Lopez       P                 0      0   0   0        0       0    0    7   1
# Chen        R                 2      0   0   0        0       1    0   11   0
# Martinez    H                 1      0   0   0        0       0    0    5   0
# Casado      J                 0      0   0   0        1       0    0    8   2
# Galeano     L                 7      0   0   0        1       4    0    7   0
# Lopez       B                 3      0   0   0        0       0    0    0   0
# Lopo        A                 1      0   0   0        0       0    0    8   2
# Caro        J                 1      0   0   0        1       0    0    7   3
# Aranzubia   D                 1      0   0   0        0       0    1   31   0
# Steinhofer  M                 2      0   0   0        0       0    0    4   1
# Rodri       S                 1      0   0   0        0       1    0    3   0
# Cobeno      D                 3      0   0   0        0       2    0   34   1
#
#                           Off  Pen SV  Pen M  Goals conceded  Conceded 1+  OG  \
# Surname     FirstInitial
# Suarez      L               3       0      0               0            0   0
# Toure       Y              10       0      0               0            0   0
# Sturridge   D              13       0      1               0            0   0
# Giroud      O              16       0      0               0            0   0
# Gerrard     S               6       0      1               0            0   0
# Rooney      W               4       0      0               0            0   0
# Lambert     R              11       0      0               0            0   0
# Hazard      E              11       0      0               0            0   0
# Lukaku      R               9       0      0               0            0   0
# Coleman     S               1       0      0              34           13   1
# Bony        W               8       0      0               0            0   0
# Rodriguez   J              12       0      0               0            0   0
# Aguero      S              15       0      1               0            0   0
# Ivanovic    B               1       0      0              27            7   0
# Dzeko       E              13       0      0               0            0   0
# Lallana     A              19       0      0               0            0   0
# Terry       J               0       0      0              25            7   1
# Baines      L               2       0      0              35           16   0
# Zabaleta    P               0       0      0              34           14   0
# Cech        P               0       0      0              24            6   0
# Cahill      G               0       0      0              19            6   0
# Remy        L               7       0      1               0            0   0
# Szczesny    W               0       1      0              41           20   0
# Mertesacker P               0       0      0              39           20   0
# Howard      T               0       2      0              38           16   1
# Koscielny   L               3       0      0              33           17   0
# Mirallas    K              17       0      0               0            0   0
# Fonte       J               0       0      0              42           21   0
# Johnson     A              15       0      0               0            0   0
# Sagna       B               1       0      0              39           20   0
# ...                       ...     ...    ...             ...          ...  ..
# Sanchez     O               0       0      0               0            0   0
# Sivera      A               0       0      0               0            0   0
# Pozo        J               0       0      0               0            0   0
# Burgui      B               0       0      0               0            0   0
# Ruiz        S               0       0      0               0            0   0
# Kaak        L               0       0      0               0            0   0
# Aquino      D               0       0      0               0            0   0
# Suarez      G               0       0      0               0            0   0
# Kameni      C               0       0      0               0            0   0
# Lopez       S               0       0      0               0            0   0
# Vazquez     L               0       0      0               0            0   0
# Mascarell   O               0       0      0               0            0   0
# Tomas       R               0       0      0               0            0   0
# Success     I               0       0      0               0            0   0
# Aranda      C               0       0      0               0            0   0
# Kaka        K               0       0      0               0            0   0
# Parreno     G               0       0      0               4            3   0
# Silva       M               1       0      0               6            4   0
# Lopez       P               0       0      0               3            2   0
# Chen        R               0       0      0               6            4   0
# Martinez    H               0       0      0               4            3   0
# Casado      J               0       0      1               4            3   0
# Galeano     L               4       0      0              20           14   0
# Lopez       B               1       0      0              11            8   0
# Lopo        A               0       0      0               9            6   0
# Caro        J               1       0      0              12            9   0
# Aranzubia   D               0       0      0               2            1   0
# Steinhofer  M               1       0      0              11            8   0
# Rodri       S               0       0      0               5            4   0
# Cobeno      D               0       0      0              16           12   0
#
#                           Firstname
# Surname     FirstInitial
# Suarez      L                  Luis
# Toure       Y                  Yaya
# Sturridge   D                Daniel
# Giroud      O               Olivier
# Gerrard     S                Steven
# Rooney      W                 Wayne
# Lambert     R                 Ricky
# Hazard      E                  Eden
# Lukaku      R                Romelu
# Coleman     S                Seamus
# Bony        W              Wilfried
# Rodriguez   J                   Jay
# Aguero      S                Sergio
# Ivanovic    B             Branislav
# Dzeko       E                  Edin
# Lallana     A                  Adam
# Terry       J                  John
# Baines      L              Leighton
# Zabaleta    P                 Pablo
# Cech        P                  Petr
# Cahill      G                  Gary
# Remy        L                  Loic
# Szczesny    W              Wojciech
# Mertesacker P                   Per
# Howard      T                   Tim
# Koscielny   L               Laurent
# Mirallas    K                 Kevin
# Fonte       J                  Jose
# Johnson     A                  Adam
# Sagna       B                Bacary
# ...                             ...
# Sanchez     O                Oliver
# Sivera      A               Antonio
# Pozo        J                 Jesus
# Burgui      B                Burgui
# Ruiz        S              Salvador
# Kaak        L                  Lion
# Aquino      D                  Dani
# Suarez      G               Gonzalo
# Kameni      C                Carlos
# Lopez       S                Sergio
# Vazquez     L                 Lucas
# Mascarell   O                  Omar
# Tomas       R                  Raul
# Success     I                 Isaac
# Aranda      C                Carlos
# Kaka        K                  Kaka
# Parreno     G                German
# Silva       M               Marcelo
# Lopez       P                 Pedro
# Chen        R               Roberto
# Martinez    H               Hansley
# Casado      J                  Jose
# Galeano     L                Leonal
# Lopez       B                 Borja
# Lopo        A               Alberto
# Caro        J                  Jose
# Aranzubia   D                Daniel
# Steinhofer  M                Markus
# Rodri       S                Sergio
# Cobeno      D                 David
#
# [1750 rows x 20 columns]

# %%
SEA1314.to_csv('../../data/prep/FANTASY1314.csv')
