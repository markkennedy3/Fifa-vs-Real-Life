# %%
import os.path
import numpy as np
import pandas as pd

# %%
BPL1415 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=481")[0]
BUN1415 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=483")[0]
LAL1415 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=485")[0]

# %%
SEA1415 = [BPL1415,BUN1415,LAL1415]
SEA1415 = pd.concat(SEA1415)
SEA1415 = SEA1415.reset_index()

# %%
SEA1415.head()
# Out:
#    index         Players  Points  Clubs    Position  Start  Goals  A CS  \
# 0      0   Sergio Aguero     211   MCFC     Forward     30     26  8  -
# 1      1      Harry Kane     170  SPURS     Forward     28     21  4  -
# 2      2     Eden Hazard     169   CHEL  Midfielder     38     14  9  -
# 3      3  Alexis Sanchez     167   ARSL     Forward     34     16  8  -
# 4      4  Charlie Austin     166    QPR     Forward     35     18  5  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    3   3   12       -     1               -           -
# 1       -  ...     0    8   6    6       -     1               -           -
# 2       -  ...     0    0   0   12       -     1               -           -
# 3       -  ...     0    2   1   12       -     1               -           -
# 4       -  ...     0    0   0    3       -     2               -           -
#
#   OG  More
# 0  0  More
# 1  1  More
# 2  0  More
# 3  0  More
# 4  0  More
#
# [5 rows x 21 columns]

# %%
SEA1415.drop(SEA1415.columns[[0,20]], axis=1, inplace=True)

# %%
SEA1415.head()
# Out:
#           Players  Points  Clubs    Position  Start  Goals  A CS CS part  \
# 0   Sergio Aguero     211   MCFC     Forward     30     26  8  -       -
# 1      Harry Kane     170  SPURS     Forward     28     21  4  -       -
# 2     Eden Hazard     169   CHEL  Midfielder     38     14  9  -       -
# 3  Alexis Sanchez     167   ARSL     Forward     34     16  8  -       -
# 4  Charlie Austin     166    QPR     Forward     35     18  5  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       4    0    3   3   12      -      1              -           -   0
# 1       4    0    8   6    6      -      1              -           -   1
# 2       2    0    0   0   12      -      1              -           -   0
# 3       4    0    2   1   12      -      1              -           -   0
# 4       5    0    0   0    3      -      2              -           -   0

# %%
SEA1415.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             353
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]
SEA1415[DashColumns] = SEA1415[DashColumns].replace('-' ,'0')

# %%
SEA1415.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1726 entries, 0 to 1725
# Data columns (total 19 columns):
# Players           1726 non-null object
# Points            1726 non-null int64
# Clubs             1373 non-null object
# Position          1726 non-null object
# Start             1726 non-null int64
# Goals             1726 non-null int64
# A                 1726 non-null int64
# CS                1726 non-null object
# CS part           1726 non-null object
# Yellow            1726 non-null int64
# Red               1726 non-null int64
# Sub               1726 non-null int64
# CO                1726 non-null int64
# Off               1726 non-null int64
# Pen SV            1726 non-null object
# Pen M             1726 non-null int64
# Goals conceded    1726 non-null object
# Conceded 1+       1726 non-null object
# OG                1726 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 256.3+ KB

# %%
SEA1415['CS'] = SEA1415['CS'].str.replace('%','').astype(np.int)
SEA1415['CS part'] = SEA1415['CS part'].str.replace('%','').astype(np.int)
SEA1415['Pen SV'] = SEA1415['Pen SV'].str.replace('%','').astype(np.int)
SEA1415['Goals conceded'] = SEA1415['Goals conceded'].str.replace('%','').astype(np.int)
SEA1415['Conceded 1+'] = SEA1415['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 1, 'FirstInitial'] = SEA1415['Players'].astype(str).str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 1, 'Firstname'] = SEA1415['Players'].str.split().str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 1, 'Surname'] = SEA1415['Players'].str.split().str[0]

SEA1415.loc[SEA1415['Players'].str.split().str.len() == 2, 'FirstInitial'] = SEA1415['Players'].astype(str).str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 2, 'Firstname'] = SEA1415['Players'].str.split().str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 2, 'Surname'] = SEA1415['Players'].str.split().str[-1]

SEA1415.loc[SEA1415['Players'].str.split().str.len() == 3, 'FirstInitial'] = SEA1415['Players'].astype(str).str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 3, 'Firstname'] = SEA1415['Players'].str.split().str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 3, 'Surname'] = SEA1415['Players'].str.split().str[-1]

SEA1415.loc[SEA1415['Players'].str.split().str.len() == 4, 'FirstInitial'] = SEA1415['Players'].astype(str).str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 4, 'Firstname'] = SEA1415['Players'].str.split().str[0]
SEA1415.loc[SEA1415['Players'].str.split().str.len() == 4, 'Surname'] = SEA1415['Players'].str.split().str[-1]

# %%
SEA1415.set_index(['Surname','FirstInitial'])
# Out:
#                                       Players  Points    Clubs    Position  \
# Surname    FirstInitial
# Aguero     S                    Sergio Aguero     211     MCFC     Forward
# Kane       H                       Harry Kane     170    SPURS     Forward
# Hazard     E                      Eden Hazard     169     CHEL  Midfielder
# Sanchez    A                   Alexis Sanchez     167     ARSL     Forward
# Austin     C                   Charlie Austin     166      QPR     Forward
# Ivanovic   B               Branislav Ivanovic     157     CHEL    Defender
# Terry      J                       John Terry     153     CHEL    Defender
# Costa      D                      Diego Costa     151     CHEL     Forward
# Berahino   S                   Saido Berahino     141     WBFC     Forward
# Silva      D                      David Silva     137     MCFC  Midfielder
# Pelle      G                   Graziano Pelle     135    SOTOM     Forward
# Cazorla    S                    Santi Cazorla     133     ARSL  Midfielder
# Rooney     W                     Wayne Rooney     131     MUFC     Forward
# Ings       D                       Danny Ings     131      BUR     Forward
# Chadli     N                     Nacer Chadli     130    SPURS  Midfielder
# Lukaku     R                    Romelu Lukaku     128     EVER     Forward
# Eriksen    C                Christian Eriksen     127    SPURS  Midfielder
# Sigurdsson G                 Gylfi Sigurdsson     127     SWAN  Midfielder
# Ulloa      L                   Leonardo Ulloa     124   LEICSC     Forward
# Henderson  J                 Jordan Henderson     124    LPOOL  Midfielder
# Fonte      J                       Jose Fonte     122    SOTOM    Defender
# Benteke    C                Christian Benteke     122   AVILLA     Forward
# Downing    S                  Stewart Downing     122  WESTHAM  Midfielder
# Fabregas   F                Francesc Fabregas     122     CHEL  Midfielder
# Bertrand   R                    Ryan Bertrand     121    SOTOM    Defender
# Cahill     G                      Gary Cahill     121     CHEL    Defender
# Hart       J                         Joe Hart     120     MCFC  Goalkeeper
# Sterling   R                  Raheem Sterling     120    LPOOL  Midfielder
# Giroud     O                   Olivier Giroud     119     ARSL     Forward
# Diouf      M                 Mame Biram Diouf     119   STOKEC     Forward
# ...                                       ...     ...      ...         ...
# Barragan   B                 Bernabe Barragan       0      NaN  Goalkeeper
# Alonso     X                      Xabi Alonso       0     MADR  Midfielder
# Cristoforo S             Sebastian Cristoforo       0     SEVI  Midfielder
# Angel      J                       Jose Angel       0      NaN  Midfielder
# Lopez      B                      Borja Lopez       0     RCDC    Defender
# Ferreira   F                  Flavio Ferreira       0     MALA  Midfielder
# Iglesias   D                    Dani Iglesias       0     RCDC     Forward
# Sanchez    I                     Ivan Sanchez       0      NaN  Midfielder
# Blanco     R                     Ruben Blanco       0     RCCV  Goalkeeper
# Took       C                     Charlie Took       0      NaN    Defender
# Llorente   D                   Diego Llorente       0     MADR    Defender
# Villalon   P                   Pablo Villalon       0      NaN    Defender
# Keita      S                      Sekou Keita       0      NaN  Midfielder
# Pedraza    A                  Alfonso Pedraza       0     VIAL  Midfielder
# Portillo   A                    Alex Portillo       0     MALA     Forward
# Mayoral    B                    Borja Mayoral       0     MADR     Forward
# Pacheco    F                 Fernando Pacheco       0     MADR  Goalkeeper
# Serrano    F                     Fran Serrano       0      NaN    Defender
# Shvets     A                     Anton Shvets       0     VIAL  Midfielder
# Echaide    I                      Ion Echaide       0      NaN    Defender
# Morante    F                Francisco Morante       0      NaN    Defender
# Porcar     N                     Nacho Porcar       0      NaN    Defender
# Alende     D                     Diego Alende       0     RCCV    Defender
# Diop       P                 Pape Cheikh Diop       0     RCCV  Midfielder
# Vazquez    K                    Kevin Vazquez       0     RCCV    Defender
# Marin      A                    Antonio Marin      -1      NaN    Defender
# Lopez      P                        Pau Lopez      -3     RCDE  Goalkeeper
# Bouzon     I                      Iago Bouzon      -3      NaN    Defender
# Diakite    M                   Modibo Diakite      -4     RCDC    Defender
# Martins    L                     Luis Martins      -5      NaN    Defender
#
#                          Start  Goals   A  CS  CS part  Yellow  Red  Sub  CO  \
# Surname    FirstInitial
# Aguero     S                30     26   8   0        0       4    0    3   3
# Kane       H                28     21   4   0        0       4    0    8   6
# Hazard     E                38     14   9   0        0       2    0    0   0
# Sanchez    A                34     16   8   0        0       4    0    2   1
# Austin     C                35     18   5   0        0       5    0    0   0
# Ivanovic   B                38      4   5  17        0      11    0    0   0
# Terry      J                38      5   0  17        0       2    0    0   0
# Costa      D                24     20   3   0        0       8    0    2   2
# Berahino   S                32     14   1   0        0       2    0    6   6
# Silva      D                32     12   7   0        0       8    0    0   0
# Pelle      G                37     12   2   0        0       6    0    1   1
# Cazorla    S                33      7  11   0        0       5    0    5   4
# Rooney     W                33     12   5   0        0       5    1    0   0
# Ings       D                35     11   4   0        0       6    0    0   0
# Chadli     N                28     11   5   0        0       3    0    8   7
# Lukaku     R                32     10   5   0        0       2    0    4   4
# Eriksen    C                37     10   2   0        0       4    0    1   1
# Sigurdsson G                32      7  10   0        0       2    0    0   0
# Ulloa      L                29     11   2   0        0       3    0    9   8
# Henderson  J                36      6   9   0        0       6    0    1   1
# Fonte      J                37      0   1  15        0       5    0    0   0
# Benteke    C                26     13   2   0        0       1    1    3   3
# Downing    S                37      6   7   0        0       3    0    0   0
# Fabregas   F                33      3  18   0        0      11    1    1   1
# Bertrand   R                34      2   2  13        0       3    1    0   0
# Cahill     G                33      1   1  14        2       5    0    5   3
# Hart       J                36      0   0  14        0       1    0    2   0
# Sterling   R                34      7   7   0        0       5    0    2   1
# Giroud     O                21     14   3   0        0       5    1    6   6
# Diouf      M                28     11   3   0        0       7    0    7   6
# ...                        ...    ...  ..  ..      ...     ...  ...  ...  ..
# Barragan   B                 0      0   0   0        0       0    0    2   0
# Alonso     X                 0      0   0   0        0       0    0    1   0
# Cristoforo S                 0      0   0   0        0       0    0    1   0
# Angel      J                 0      0   0   0        0       0    0    2   0
# Lopez      B                 0      0   0   0        0       0    0    3   0
# Ferreira   F                 0      0   0   0        0       0    0    1   0
# Iglesias   D                 0      0   0   0        0       0    0    1   0
# Sanchez    I                 0      0   0   0        0       0    0    2   0
# Blanco     R                 0      0   0   0        0       0    0   38   1
# Took       C                 0      0   0   0        0       0    0    2   0
# Llorente   D                 0      0   0   0        0       0    0    3   0
# Villalon   P                 0      0   0   0        0       0    0    1   0
# Keita      S                 0      0   0   0        0       0    0    1   0
# Pedraza    A                 0      0   0   0        0       0    0    2   0
# Portillo   A                 0      0   0   0        0       0    0    1   0
# Mayoral    B                 0      0   0   0        0       0    0    1   0
# Pacheco    F                 0      0   0   0        0       0    0    1   0
# Serrano    F                 1      0   0   0        0       0    0    0   0
# Shvets     A                 0      0   0   0        0       0    0    2   0
# Echaide    I                 1      0   0   0        0       0    0    0   0
# Morante    F                 0      0   0   0        0       0    0    1   0
# Porcar     N                 0      0   0   0        0       0    0    3   0
# Alende     D                 0      0   0   0        0       0    0    1   0
# Diop       P                 0      0   0   0        0       0    0    1   0
# Vazquez    K                 0      0   0   0        0       0    0    1   0
# Marin      A                 1      0   0   0        0       0    0    5   1
# Lopez      P                 1      0   0   0        0       0    0   36   1
# Bouzon     I                 3      0   0   0        0       3    0    9   0
# Diakite    M                 2      0   0   0        0       0    0    7   0
# Martins    L                 1      0   0   0        0       1    0    5   2
#
#                          Off  Pen SV  Pen M  Goals conceded  Conceded 1+  OG  \
# Surname    FirstInitial
# Aguero     S              12       0      1               0            0   0
# Kane       H               6       0      1               0            0   1
# Hazard     E              12       0      1               0            0   0
# Sanchez    A              12       0      1               0            0   0
# Austin     C               3       0      2               0            0   0
# Ivanovic   B               0       0      0              32           11   0
# Terry      J               0       0      0              32           11   1
# Costa      D              17       0      0               0            0   0
# Berahino   S              12       0      0               0            0   0
# Silva      D              15       0      0               0            0   0
# Pelle      G               4       0      0               0            0   0
# Cazorla    S               5       0      0               0            0   0
# Rooney     W               4       0      1               0            0   0
# Ings       D              10       0      0               0            0   0
# Chadli     N              16       0      0               0            0   0
# Lukaku     R              10       0      0               0            0   1
# Eriksen    C              11       0      0               0            0   0
# Sigurdsson G              15       0      0               0            0   0
# Ulloa      L              18       0      0               0            0   0
# Henderson  J               0       0      0               0            0   0
# Fonte      J               0       0      0              32           10   0
# Benteke    C               2       0      0               0            0   0
# Downing    S               2       0      0               0            0   0
# Fabregas   F               8       0      0               0            0   0
# Bertrand   R               1       0      0              30            9   0
# Cahill     G               1       0      0              31           11   0
# Hart       J               0       1      0              34           12   0
# Sterling   R               9       0      0               0            0   0
# Giroud     O              10       0      0               0            0   0
# Diouf      M              11       0      0               0            0   0
# ...                      ...     ...    ...             ...          ...  ..
# Barragan   B               0       0      0               0            0   0
# Alonso     X               0       0      0               0            0   0
# Cristoforo S               0       0      0               0            0   0
# Angel      J               0       0      0               0            0   0
# Lopez      B               0       0      0               0            0   0
# Ferreira   F               0       0      0               0            0   0
# Iglesias   D               0       0      0               0            0   0
# Sanchez    I               0       0      0               0            0   0
# Blanco     R               0       0      0               2            1   0
# Took       C               0       0      0               0            0   0
# Llorente   D               0       0      0               0            0   0
# Villalon   P               0       0      0               0            0   0
# Keita      S               0       0      0               0            0   0
# Pedraza    A               0       0      0               0            0   0
# Portillo   A               0       0      0               0            0   0
# Mayoral    B               0       0      0               0            0   0
# Pacheco    F               0       0      0               0            0   0
# Serrano    F               0       0      0               3            2   0
# Shvets     A               0       0      0               0            0   0
# Echaide    I               0       0      0               3            2   0
# Morante    F               0       0      0               0            0   0
# Porcar     N               0       0      0               0            0   0
# Alende     D               0       0      0               0            0   0
# Diop       P               0       0      0               0            0   0
# Vazquez    K               0       0      0               0            0   0
# Marin      A               0       0      0               6            4   0
# Lopez      P               0       0      0               5            3   1
# Bouzon     I               1       0      0               9            6   0
# Diakite    M               0       0      0              10            8   0
# Martins    L               0       0      0              11            8   0
#
#                          Firstname
# Surname    FirstInitial
# Aguero     S                Sergio
# Kane       H                 Harry
# Hazard     E                  Eden
# Sanchez    A                Alexis
# Austin     C               Charlie
# Ivanovic   B             Branislav
# Terry      J                  John
# Costa      D                 Diego
# Berahino   S                 Saido
# Silva      D                 David
# Pelle      G              Graziano
# Cazorla    S                 Santi
# Rooney     W                 Wayne
# Ings       D                 Danny
# Chadli     N                 Nacer
# Lukaku     R                Romelu
# Eriksen    C             Christian
# Sigurdsson G                 Gylfi
# Ulloa      L              Leonardo
# Henderson  J                Jordan
# Fonte      J                  Jose
# Benteke    C             Christian
# Downing    S               Stewart
# Fabregas   F              Francesc
# Bertrand   R                  Ryan
# Cahill     G                  Gary
# Hart       J                   Joe
# Sterling   R                Raheem
# Giroud     O               Olivier
# Diouf      M                  Mame
# ...                            ...
# Barragan   B               Bernabe
# Alonso     X                  Xabi
# Cristoforo S             Sebastian
# Angel      J                  Jose
# Lopez      B                 Borja
# Ferreira   F                Flavio
# Iglesias   D                  Dani
# Sanchez    I                  Ivan
# Blanco     R                 Ruben
# Took       C               Charlie
# Llorente   D                 Diego
# Villalon   P                 Pablo
# Keita      S                 Sekou
# Pedraza    A               Alfonso
# Portillo   A                  Alex
# Mayoral    B                 Borja
# Pacheco    F              Fernando
# Serrano    F                  Fran
# Shvets     A                 Anton
# Echaide    I                   Ion
# Morante    F             Francisco
# Porcar     N                 Nacho
# Alende     D                 Diego
# Diop       P                  Pape
# Vazquez    K                 Kevin
# Marin      A               Antonio
# Lopez      P                   Pau
# Bouzon     I                  Iago
# Diakite    M                Modibo
# Martins    L                  Luis
#
# [1726 rows x 20 columns]

# %%
SEA1415.to_csv('../../data/prep/FANTASY1415.csv')
