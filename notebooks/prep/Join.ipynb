# %%
import os.path
import numpy as np
import pandas as pd

# %%
Fifa = pd.read_csv("FIFADS.csv")

# %% [markdown]
# # 1617

# %%
Fantasy1617 = pd.read_csv("FANTASY1617DS.csv")

# %%
Join1617 = pd.merge(Fifa, Fantasy1617, on=['Surname','FirstInitial'])

# %%
Join1617.drop(Join1617.columns[[0]], axis=1, inplace=True)

# %%
i = 0
array = []

while i <= 1982:
    if Join1617['Firstname'][i] in Join1617['name'][i] or Join1617['Firstname'][i] in Join1617['full_name'][i]:
        array.append(True)
        i+=1
    else:
        array.append(False)
        i+=1

# %%
array = np.array(array)

# %%
Join1617 = Join1617[array]

# %%
Error1617 = Join1617[(Join1617['Players'].isin(Join1617['Players'][Join1617['Players'].duplicated()]) | Join1617['full_name'].isin(Join1617['full_name'][Join1617['full_name'].duplicated()]))]

# %%
leagues = ['German Bundesliga','Spanish Primera Division','English Premier League']
TopLeagues1617 = Error1617[(Error1617.league.str.contains('|'.join(leagues)) == True) | Error1617['league'].isnull()]

# %%
TopLeagues1617[TopLeagues1617['Clubs'].isnull()]
# Out:
#           ID         name                      full_name  \
# 312   146760     Juanfran    Juan Francisco Torres Belen
# 314   188135     Juanfran  Juan Francisco Moreno Fuertes
# 910   208141      Gabriel           Gabriel Appelt Pires
# 1305  221452         Nano        Alexander Mesa Travieso
# 1335  232805     Bernardo             Bernardo Fernandes
# 1394  145889         Tito         Roberto Roman Triguero
# 1805  235365  Juan Moreno          Juan Moreno Fernandez
#
#                            club                                   club_logo  \
# 312             Atletico Madrid     https://cdn.sofifa.org/18/teams/240.png
# 314   RC Deportivo de La Coruna     https://cdn.sofifa.org/18/teams/242.png
# 910                  CD Leganes  https://cdn.sofifa.org/18/teams/100888.png
# 1305                 Levante UD    https://cdn.sofifa.org/18/teams/1853.png
# 1335                 RB Leipzig  https://cdn.sofifa.org/18/teams/112172.png
# ...

# %%
Fix1617 = TopLeagues1617[(TopLeagues1617['Players'].isin(TopLeagues1617['Players'][TopLeagues1617['Players'].duplicated()]) | TopLeagues1617['full_name'].isin(TopLeagues1617['full_name'][TopLeagues1617['full_name'].duplicated()]))]

# %%
Fix1617 = Fix1617.drop(Fix1617.index[[2,4,5,6,7,11,13,15,16,18,25,26,31,32]])

# %%
d = {
 'ID' : 'first',
 'club_logo':'first',
 'special':'first',
 'age':'first',
 'league':'first',
 'birth_date':'first',
 'height_cm':'first',
 'weight_kg':'first',
 'body_type':'first',
 'real_face':'first',
 'flag':'first',
 'nationality':'first',
 'photo':'first',
 'eur_value':'first',
 'eur_wage':'first',
 'eur_release_clause':'first',
 'overall':'first',
 'potential':'first',
 'pac':'first',
 'sho':'first',
 'pas':'first',
 'dri':'first',
 'def':'first',
 'phy':'first',
 'international_reputation':'first',
 'skill_moves':'first',
 'weak_foot':'first',
 'work_rate_att':'first',
 'work_rate_def':'first',
 'preferred_foot':'first',
 'crossing':'first',
 'finishing':'first',
 'heading_accuracy':'first',
 'short_passing':'first',
 'volleys':'first',
 'dribbling':'first',
 'curve':'first',
 'free_kick_accuracy':'first',
 'long_passing':'first',
 'ball_control':'first',
 'acceleration':'first',
 'sprint_speed':'first',
 'agility':'first',
 'reactions':'first',
 'balance':'first',
 'shot_power':'first',
 'jumping':'first',
 'stamina':'first',
 'strength':'first',
 'long_shots':'first',
 'aggression':'first',
 'interceptions':'first',
 'positioning':'first',
 'vision':'first',
 'penalties':'first',
 'composure':'first',
 'marking':'first',
 'standing_tackle':'first',
 'sliding_tackle':'first',
 'gk_diving':'first',
 'gk_handling':'first',
 'gk_kicking':'first',
 'gk_positioning':'first',
 'gk_reflexes':'first',
 'rs':'first',
 'rw':'first',
 'rf':'first',
 'ram':'first',
 'rcm':'first',
 'rm':'first',
 'rdm':'first',
 'rcb':'first',
 'rb':'first',
 'rwb':'first',
 'st':'first',
 'lw':'first',
 'cf':'first',
 'cam':'first',
 'cm':'first',
 'lm':'first',
 'cdm':'first',
 'cb':'first',
 'lb':'first',
 'lwb':'first',
 'ls':'first',
 'lf':'first',
 'lam':'first',
 'lcm':'first',
 'ldm':'first',
 'lcb':'first',
 'gk':'first',
 '1_on_1_rush_trait':'first',
 'acrobatic_clearance_trait':'first',
 'argues_with_officials_trait':'first',
 'avoids_using_weaker_foot_trait':'first',
 'backs_into_player_trait':'first',
 'bicycle_kicks_trait':'first',
 'cautious_with_crosses_trait':'first',
 'chip_shot_trait':'first',
 'chipped_penalty_trait':'first',
 'comes_for_crosses_trait':'first',
 'corner_specialist_trait':'first',
 'diver_trait':'first',
 'dives_into_tackles_trait':'first',
 'diving_header_trait':'first',
 'driven_pass_trait':'first',
 'early_crosser_trait':'first',
 "fan's_favourite_trait":'first',
 'fancy_flicks_trait':'first',
 'finesse_shot_trait':'first',
 'flair_trait':'first',
 'flair_passes_trait':'first',
 'gk_flat_kick_trait':'first',
 'gk_long_throw_trait':'first',
 'gk_up_for_corners_trait':'first',
 'giant_throw_in_trait':'first',
 'inflexible_trait':'first',
 'injury_free_trait':'first',
 'injury_prone_trait':'first',
 'leadership_trait':'first',
 'long_passer_trait':'first',
 'long_shot_taker_trait':'first',
 'long_throw_in_trait':'first',
 'one_club_player_trait':'first',
 'outside_foot_shot_trait':'first',
 'playmaker_trait':'first',
 'power_free_kick_trait':'first',
 'power_header_trait':'first',
 'puncher_trait':'first',
 'rushes_out_of_goal_trait':'first',
 'saves_with_feet_trait':'first',
 'second_wind_trait':'first',
 'selfish_trait':'first',
 'skilled_dribbling_trait':'first',
 'stutter_penalty_trait':'first',
 'swerve_pass_trait':'first',
 'takes_finesse_free_kicks_trait':'first',
 'target_forward_trait':'first',
 'team_player_trait':'first',
 'technical_dribbler_trait':'first',
 'tries_to_beat_defensive_line_trait':'first',
 'poacher_speciality':'first',
 'speedster_speciality':'first',
 'aerial_threat_speciality':'first',
 'dribbler_speciality':'first',
 'playmaker_speciality':'first',
 'engine_speciality':'first',
 'distance_shooter_speciality':'first',
 'crosser_speciality':'first',
 'free_kick_specialist_speciality':'first',
 'tackling_speciality':'first',
 'tactician_speciality':'first',
 'acrobat_speciality':'first',
 'strength_speciality':'first',
 'clinical_finisher_speciality':'first',
 'prefers_rs':'first',
 'prefers_rw':'first',
 'prefers_rf':'first',
 'prefers_ram':'first',
 'prefers_rcm':'first',
 'prefers_rm':'first',
 'prefers_rdm':'first',
 'prefers_rcb':'first',
 'prefers_rb':'first',
 'prefers_rwb':'first',
 'prefers_st':'first',
 'prefers_lw':'first',
 'prefers_cf':'first',
 'prefers_cam':'first',
 'prefers_cm':'first',
 'prefers_lm':'first',
 'prefers_cdm':'first',
 'prefers_cb':'first',
 'prefers_lb':'first',
 'prefers_lwb':'first',
 'prefers_ls':'first',
 'prefers_lf':'first',
 'prefers_lam':'first',
 'prefers_lcm':'first',
 'prefers_ldm':'first',
 'prefers_lcb':'first',
 'prefers_gk':'first',
 'Players':'first',
 'Position':'first',
 'Clubs':'first',
 'Points':'sum',  
 'Start':'sum', 
 'Sub':'sum', 
 'club':'last',
 'Position':'first',
 'Start':'sum',
 'Goals':'sum',
 'A':'sum',
 'CS':'sum',
 'CS part':'sum',
 'Yellow':'sum',
 'Red':'sum',
 'Sub':'sum',
 'CO':'sum',
 'Off':'sum',
 'Pen SV':'sum',
 'Pen M':'sum',
 'Goals conceded':'sum',
 'Conceded 1+':'sum',
 'OG':'sum',
 'Firstname':'first'}

# %%
Fixed1617 = (Fix1617.groupby(['name','full_name'], sort=False, as_index=False).agg(d).reindex(columns=Fix1617.columns))

# %%
Fixed1617.head(5)
# Out:
#        ID        name                    full_name               club  \
# 0  192227  S. Mustafi             Shkodran Mustafi            Arsenal
# 1  200228       Bruno       Bruno Gonzalez Cabrera          Getafe CF
# 2  174543    C. Bravo                Claudio Bravo    Manchester City
# 3  171919       Naldo  Ronaldo Aparecido Rodrigues      FC Schalke 04
# 4  167431   G. Castro               Gonzalo Castro  Borussia Dortmund
#
#                                   club_logo  special  age  \
# 0     https://cdn.sofifa.org/18/teams/1.png     1942   25
# 1  https://cdn.sofifa.org/18/teams/1860.png     1533   27
# 2    https://cdn.sofifa.org/18/teams/10.png     1464   34
# 3    https://cdn.sofifa.org/18/teams/34.png     1949   34
# 4    https://cdn.sofifa.org/18/teams/22.png     2156   30
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0    English Premier League  1992-04-17      184.0    ...        0   2   1
# ...

# %%
Delete1617 = Error1617[Error1617.league.str.contains('|'.join(leagues)) == False]

# %%
Join1617 = Join1617[(~(Join1617.full_name.isin(Delete1617.full_name) & Join1617.birth_date.isin(Delete1617.birth_date)))]
Join1617 = Join1617[(~(Join1617.full_name.isin(Fix1617.full_name) & Join1617.birth_date.isin(Fix1617.birth_date)))]

# %%
Joined1617 = pd.concat([Join1617,Fixed1617])
Joined1617 = Joined1617.reset_index()

# %%
Joined1617.drop(Joined1617.columns[[0]], axis=1, inplace=True)

# %% [markdown]
# # 1516

# %%
Fantasy1516 = pd.read_csv("FANTASY1516DS.csv")

# %%
Join1516 = pd.merge(Fifa, Fantasy1516, on=['Surname','FirstInitial'])

# %%
Join1516.drop(Join1516.columns[[0]], axis=1, inplace=True)

# %%
i = 0
array = []

while i <= 1895:
    if Join1516['Firstname'][i] in Join1516['name'][i] or Join1516['Firstname'][i] in Join1516['full_name'][i]:
        array.append(True)
        i+=1
    else:
        array.append(False)
        i+=1

# %%
array = np.array(array)

# %%
Join1516 = Join1516[array]

# %%
Error1516 = Join1516[(Join1516['Players'].isin(Join1516['Players'][Join1516['Players'].duplicated()]) | Join1516['full_name'].isin(Join1516['full_name'][Join1516['full_name'].duplicated()]))]

# %%
TopLeagues1516 = Error1516[(Error1516.league.str.contains('|'.join(leagues)) == True) | Error1516['league'].isnull()]

# %%
TopLeagues1516[TopLeagues1516['Clubs'].isnull()].head(3)
# Out:
#          ID      name                    full_name                       club  \
# 224  208421      Saul         Saul Niguez Esclapez            Atletico Madrid
# 225  219709      Saul          Saul Garcia Cabrero  RC Deportivo de La Coruna
# 312  146760  Juanfran  Juan Francisco Torres Belen            Atletico Madrid
#
#                                    club_logo  special  age  \
# 224  https://cdn.sofifa.org/18/teams/240.png     2092   22
# 225  https://cdn.sofifa.org/18/teams/242.png     1719   22
# 312  https://cdn.sofifa.org/18/teams/240.png     2070   32
#
#                        league  birth_date  height_cm    ...      Red Sub  CO  \
# 224  Spanish Primera Division  1994-11-21      181.0    ...        0  19  13
# 225  Spanish Primera Division  1994-11-09      183.0    ...        0  19  13
# 312  Spanish Primera Division  1985-01-09      180.0    ...        0   2   1
#
#     Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# ...

# %%
Fix1516 = TopLeagues1516[(TopLeagues1516['Players'].isin(TopLeagues1516['Players'][TopLeagues1516['Players'].duplicated()]) | TopLeagues1516['full_name'].isin(TopLeagues1516['full_name'][TopLeagues1516['full_name'].duplicated()]))]

# %%
Fixed1516 = (Fix1516.groupby(['name','full_name'], sort=False, as_index=False).agg(d).reindex(columns=Fix1516.columns))

# %%
Delete1516 = Error1516[Error1516.league.str.contains('|'.join(leagues)) == False]

# %%
Join1516 = Join1516[(~(Join1516.full_name.isin(Delete1516.full_name) & Join1516.birth_date.isin(Delete1516.birth_date)))]
Join1516 = Join1516[(~(Join1516.full_name.isin(Fix1516.full_name) & Join1516.birth_date.isin(Fix1516.birth_date)))]

# %%
Joined1516 = pd.concat([Join1516,Fixed1516])
Joined1516 = Joined1516.reset_index()

# %%
Joined1516.drop(Joined1516.columns[[0]], axis=1, inplace=True)

# %%
Joined1516.head(5)
# Out:
#        ID               name                     full_name  \
# 0   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 1  158023           L. Messi                  Lionel Messi
# 2  190871             Neymar    Neymar da Silva Santos Jr.
# 3  176580          L. Suarez                   Luis Suarez
# 4  167495           M. Neuer                  Manuel Neuer
#
#                   club                                club_logo  special  age  \
# 0       Real Madrid CF  https://cdn.sofifa.org/18/teams/243.png     2228   32
# 1         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2158   30
# 2  Paris Saint-Germain   https://cdn.sofifa.org/18/teams/73.png     2100   25
# 3         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2291   30
# 4     FC Bayern Munich   https://cdn.sofifa.org/18/teams/21.png     1493   31
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# ...

# %%
Fixed1516.head(3)
# Out:
#        ID          name                full_name             club  \
# 0  192985  K. De Bruyne          Kevin De Bruyne  Manchester City
# 1  176676       Marcelo  Marcelo Vieira da Silva   Real Madrid CF
# 2  184120         Bruno      Bruno Soriano Llido    Villarreal CF
#
#                                  club_logo  special  age  \
# 0   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 1  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 2  https://cdn.sofifa.org/18/teams/483.png     2059   33
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0    English Premier League  1991-06-28      181.0    ...        0   4   3
# 1  Spanish Primera Division  1988-05-12      174.0    ...        0   4   2
# 2  Spanish Primera Division  1984-06-12      184.0    ...        0   2   0
#
#   Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# 0   5      0     0               0            0   0      Kevin
# ...

# %% [markdown]
# # 1415

# %%
Fantasy1415 = pd.read_csv("FANTASY1415DS.csv")

# %%
Join1415 = pd.merge(Fifa, Fantasy1415, on=['Surname','FirstInitial'])

# %%
Join1415.drop(Join1415.columns[[0]], axis=1, inplace=True)

# %%
i = 0
array = []

while i <= 1769:
    if Join1415['Firstname'][i] in Join1415['name'][i] or Join1415['Firstname'][i] in Join1415['full_name'][i]:
        array.append(True)
        i+=1
    else:
        array.append(False)
        i+=1

# %%
array = np.array(array)

# %%
Join1415 = Join1415[array]

# %%
Error1415 = Join1415[(Join1415['Players'].isin(Join1415['Players'][Join1415['Players'].duplicated()]) | Join1415['full_name'].isin(Join1415['full_name'][Join1415['full_name'].duplicated()]))]

# %%
TopLeagues1415 = Error1415[(Error1415.league.str.contains('|'.join(leagues)) == True) | Error1415['league'].isnull()]

# %%
TopLeagues1415[TopLeagues1415['Clubs'].isnull()].head(3)
# Out:
#          ID   name                    full_name                       club  \
# 186  208421   Saul         Saul Niguez Esclapez            Atletico Madrid
# 187  219709   Saul          Saul Garcia Cabrero  RC Deportivo de La Coruna
# 250  171919  Naldo  Ronaldo Aparecido Rodrigues              FC Schalke 04
#
#                                    club_logo  special  age  \
# 186  https://cdn.sofifa.org/18/teams/240.png     2092   22
# 187  https://cdn.sofifa.org/18/teams/242.png     1719   22
# 250   https://cdn.sofifa.org/18/teams/34.png     1949   34
#
#                        league  birth_date  height_cm    ...      Red Sub  CO  \
# 186  Spanish Primera Division  1994-11-21      181.0    ...        0   5   4
# 187  Spanish Primera Division  1994-11-09      183.0    ...        0   5   4
# 250         German Bundesliga  1982-09-10      198.0    ...        0   7   2
#
#     Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# ...

# %%
Fix1415 = TopLeagues1415[(TopLeagues1415['Players'].isin(TopLeagues1415['Players'][TopLeagues1415['Players'].duplicated()]) | TopLeagues1415['full_name'].isin(TopLeagues1415['full_name'][TopLeagues1415['full_name'].duplicated()]))]

# %%
Delete1415 = Error1415[Error1415.league.str.contains('|'.join(leagues)) == False]

# %%
Fixed1415 = (Fix1415.groupby(['name','full_name'], sort=False, as_index=False).agg(d).reindex(columns=Fix1415.columns))

# %%
Join1415 = Join1415[(~(Join1415.full_name.isin(Delete1415.full_name) & Join1415.birth_date.isin(Delete1415.birth_date)))]
Join1415 = Join1415[(~(Join1415.full_name.isin(Fix1415.full_name) & Join1415.birth_date.isin(Fix1415.birth_date)))]

# %%
Joined1415 = pd.concat([Join1415,Fixed1415])
Joined1415 = Joined1415.reset_index()

# %%
Joined1415.drop(Joined1415.columns[[0]], axis=1, inplace=True)

# %%
Joined1415.head(30)
# Out:
#         ID               name                     full_name  \
# 0    20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 1   158023           L. Messi                  Lionel Messi
# 2   190871             Neymar    Neymar da Silva Santos Jr.
# 3   176580          L. Suarez                   Luis Suarez
# 4   167495           M. Neuer                  Manuel Neuer
# 5   188545     R. Lewandowski            Robert Lewandowski
# 6   193080             De Gea         David De Gea Quintana
# 7   183277          E. Hazard                   Eden Hazard
# 8   182521           T. Kroos                    Toni Kroos
# 9   155862       Sergio Ramos           Sergio Ramos Garcia
# 10  192985       K. De Bruyne               Kevin De Bruyne
# 11  192119        T. Courtois              Thibaut Courtois
# 12  184941         A. Sanchez                Alexis Sanchez
# 13  177003          L. Modric                   Luka Modric
# 14  173731            G. Bale                   Gareth Bale
# ...

# %%
Fixed1415.head(3)
# Out:
#        ID       name                 full_name               club  \
# 0  176676    Marcelo   Marcelo Vieira da Silva     Real Madrid CF
# 1  189358  S. Kagawa             Shinji Kagawa  Borussia Dortmund
# 2  188152      Oscar  Oscar dos Santos Emboaba                NaN
#
#                                  club_logo  special  age  \
# 0  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 1   https://cdn.sofifa.org/18/teams/22.png     1874   28
# 2                                      NaN     1961   25
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0  Spanish Primera Division  1988-05-12      174.0    ...        0   5   1
# 1         German Bundesliga  1989-03-17      175.0    ...        0  11   5
# 2                       NaN  1991-09-09      179.0    ...        0   5   2
#
#   Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# 0   6      0     0              86           39   1    Marcelo
# ...

# %% [markdown]
# # 1314

# %%
Fantasy1314 = pd.read_csv("FANTASY1314DS.csv")

# %%
Join1314 = pd.merge(Fifa, Fantasy1314, on=['Surname','FirstInitial'])

# %%
Join1314.drop(Join1314.columns[[0]], axis=1, inplace=True)

# %%
i = 0
array = []

while i <= 1641:
    if Join1314['Firstname'][i] in Join1314['name'][i] or Join1314['Firstname'][i] in Join1314['full_name'][i]:
        array.append(True)
        i+=1
    else:
        array.append(False)
        i+=1

# %%
array = np.array(array)

# %%
Join1314 = Join1314[array]

# %%
Error1314 = Join1314[(Join1314['Players'].isin(Join1314['Players'][Join1314['Players'].duplicated()]) | Join1314['full_name'].isin(Join1314['full_name'][Join1314['full_name'].duplicated()]))]

# %%
TopLeagues1314 = Error1314[(Error1314.league.str.contains('|'.join(leagues)) == True) | Error1314['league'].isnull()]

# %%
TopLeagues1314[TopLeagues1314['Clubs'].isnull()].head(3)
# Out:
#          ID      name                      full_name  \
# 251  146760  Juanfran    Juan Francisco Torres Belen
# 252  146760  Juanfran    Juan Francisco Torres Belen
# 254  188135  Juanfran  Juan Francisco Moreno Fuertes
#
#                           club                                club_logo  \
# 251            Atletico Madrid  https://cdn.sofifa.org/18/teams/240.png
# 252            Atletico Madrid  https://cdn.sofifa.org/18/teams/240.png
# 254  RC Deportivo de La Coruna  https://cdn.sofifa.org/18/teams/242.png
#
#      special  age                    league  birth_date  height_cm    ...      \
# 251     2070   32  Spanish Primera Division  1985-01-09      180.0    ...
# 252     2070   32  Spanish Primera Division  1985-01-09      180.0    ...
# 254     2061   28  Spanish Primera Division  1988-09-11      180.0    ...
#
#      Red Sub  CO Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# 251    2   1   0   0      0     0              22            6   1   Juanfran
# ...

# %%
Fix1314 = TopLeagues1314[(TopLeagues1314['Players'].isin(TopLeagues1314['Players'][TopLeagues1314['Players'].duplicated()]) | TopLeagues1314['full_name'].isin(TopLeagues1314['full_name'][TopLeagues1314['full_name'].duplicated()]))]

# %%
Delete1314 = Error1314[Error1314.league.str.contains('|'.join(leagues)) == False]

# %%
Fixed1314 = (Fix1314.groupby(['name','full_name'], sort=False, as_index=False).agg(d).reindex(columns=Fix1314.columns))

# %%
Join1314 = Join1314[(~(Join1314.full_name.isin(Delete1314.full_name) & Join1314.birth_date.isin(Delete1314.birth_date)))]
Join1314 = Join1314[(~(Join1314.full_name.isin(Fix1314.full_name) & Join1314.birth_date.isin(Fix1314.birth_date)))]

# %%
Joined1314 = pd.concat([Join1314,Fixed1314])
Joined1314 = Joined1314.reset_index()

# %%
Joined1314.drop(Joined1314.columns[[0]], axis=1, inplace=True)

# %%
Joined1314.head(3)
# Out:
#        ID               name                     full_name  \
# 0   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 1  158023           L. Messi                  Lionel Messi
# 2  190871             Neymar    Neymar da Silva Santos Jr.
#
#                   club                                club_logo  special  age  \
# 0       Real Madrid CF  https://cdn.sofifa.org/18/teams/243.png     2228   32
# 1         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2158   30
# 2  Paris Saint-Germain   https://cdn.sofifa.org/18/teams/73.png     2100   25
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0  Spanish Primera Division  1985-02-05      185.0    ...        1   0   0
# 1  Spanish Primera Division  1987-06-24      170.0    ...        0   2   2
# 2            French Ligue 1  1992-02-05      175.0    ...        0  10   7
#
#   Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# ...

# %%
Fixed1314.head(5)
# Out:
#        ID          name                 full_name             club  \
# 0  192985  K. De Bruyne           Kevin De Bruyne  Manchester City
# 1  176635       M. Ozil                Mesut Ozil          Arsenal
# 2  176676       Marcelo   Marcelo Vieira da Silva   Real Madrid CF
# 3  188152         Oscar  Oscar dos Santos Emboaba              NaN
# 4  239335         Oscar    Oscar Rodriguez Arnaiz   Real Madrid CF
#
#                                  club_logo  special  age  \
# 0   https://cdn.sofifa.org/18/teams/10.png     2162   26
# 1    https://cdn.sofifa.org/18/teams/1.png     1927   28
# 2  https://cdn.sofifa.org/18/teams/243.png     2214   29
# 3                                      NaN     1961   25
# 4  https://cdn.sofifa.org/18/teams/243.png     1667   19
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0    English Premier League  1991-06-28      181.0    ...        0   7   1
# ...

# %% [markdown]
# # 1213

# %%
Fantasy1213 = pd.read_csv("FANTASY1213DS.csv")

# %%
Join1213 = pd.merge(Fifa, Fantasy1213, on=['Surname','FirstInitial'])

# %%
Join1213.drop(Join1213.columns[[0]], axis=1, inplace=True)

# %%
i = 0
array = []

while i <= 1550:
    if Join1213['Firstname'][i] in Join1213['name'][i] or Join1213['Firstname'][i] in Join1213['full_name'][i]:
        array.append(True)
        i+=1
    else:
        array.append(False)
        i+=1

# %%
array = np.array(array)

# %%
Join1213 = Join1213[array]

# %%
Error1213 = Join1213[(Join1213['Players'].isin(Join1213['Players'][Join1213['Players'].duplicated()]) | Join1213['full_name'].isin(Join1213['full_name'][Join1213['full_name'].duplicated()]))]

# %%
TopLeagues1213 = Error1213[(Error1213.league.str.contains('|'.join(leagues)) == True) | Error1213['league'].isnull()]

# %%
TopLeagues1213[TopLeagues1213['Clubs'].isnull()].head(3)
# Out:
#          ID      name                      full_name  \
# 233  146760  Juanfran    Juan Francisco Torres Belen
# 234  146760  Juanfran    Juan Francisco Torres Belen
# 235  188135  Juanfran  Juan Francisco Moreno Fuertes
#
#                           club                                club_logo  \
# 233            Atletico Madrid  https://cdn.sofifa.org/18/teams/240.png
# 234            Atletico Madrid  https://cdn.sofifa.org/18/teams/240.png
# 235  RC Deportivo de La Coruna  https://cdn.sofifa.org/18/teams/242.png
#
#      special  age                    league  birth_date  height_cm    ...      \
# 233     2070   32  Spanish Primera Division  1985-01-09      180.0    ...
# 234     2070   32  Spanish Primera Division  1985-01-09      180.0    ...
# 235     2061   28  Spanish Primera Division  1988-09-11      180.0    ...
#
#      Red Sub  CO Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# 233    0   0   0   0      0     0              29           13   2   Juanfran
# ...

# %%
Fix1213 = TopLeagues1213[(TopLeagues1213['Players'].isin(TopLeagues1213['Players'][TopLeagues1213['Players'].duplicated()]) | TopLeagues1213['full_name'].isin(TopLeagues1213['full_name'][TopLeagues1213['full_name'].duplicated()]))]

# %%
Delete1213 = Error1213[Error1213.league.str.contains('|'.join(leagues)) == False]

# %%
Fixed1213 = (Fix1213.groupby(['name','full_name'], sort=False, as_index=False).agg(d).reindex(columns=Fix1213.columns))

# %%
Join1213 = Join1213[(~(Join1213.full_name.isin(Delete1213.full_name) & Join1213.birth_date.isin(Delete1213.birth_date)))]
Join1213 = Join1213[(~(Join1213.full_name.isin(Fix1213.full_name) & Join1213.birth_date.isin(Fix1213.birth_date)))]

# %%
Joined1213 = pd.concat([Join1213,Fixed1213])
Joined1213 = Joined1213.reset_index()

# %%
Joined1213.drop(Joined1213.columns[[0]], axis=1, inplace=True)

# %%
Joined1213.head(3)
# Out:
#        ID               name                     full_name            club  \
# 0   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro  Real Madrid CF
# 1  158023           L. Messi                  Lionel Messi    FC Barcelona
# 2  176580          L. Suarez                   Luis Suarez    FC Barcelona
#
#                                  club_logo  special  age  \
# 0  https://cdn.sofifa.org/18/teams/243.png     2228   32
# 1  https://cdn.sofifa.org/18/teams/241.png     2158   30
# 2  https://cdn.sofifa.org/18/teams/241.png     2291   30
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0  Spanish Primera Division  1985-02-05      185.0    ...        0   4   4
# 1  Spanish Primera Division  1987-06-24      170.0    ...        0   4   4
# 2  Spanish Primera Division  1987-01-24      182.0    ...        0   0   0
#
#   Off Pen SV Pen M  Goals conceded  Conceded 1+  OG  Firstname
# 0   5      0     1               0            0   1  Cristiano
# ...

# %%
Fixed1213.head(4)
# Out:
#        ID   name                 full_name                       club  \
# 0  188152  Oscar  Oscar dos Santos Emboaba                        NaN
# 1  239335  Oscar    Oscar Rodriguez Arnaiz             Real Madrid CF
# 2  208421   Saul      Saul Niguez Esclapez            Atletico Madrid
# 3  219709   Saul       Saul Garcia Cabrero  RC Deportivo de La Coruna
#
#                                  club_logo  special  age  \
# 0                                      NaN     1961   25
# 1  https://cdn.sofifa.org/18/teams/243.png     1667   19
# 2  https://cdn.sofifa.org/18/teams/240.png     2092   22
# 3  https://cdn.sofifa.org/18/teams/242.png     1719   22
#
#                      league  birth_date  height_cm    ...      Red Sub  CO  \
# 0                       NaN  1991-09-09      179.0    ...        0  18  12
# 1  Spanish Primera Division  1998-06-28      174.0    ...        0  18  12
# 2  Spanish Primera Division  1994-11-21      181.0    ...        0   1   0
# ...
