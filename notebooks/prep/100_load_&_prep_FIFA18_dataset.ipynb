# %%
import os.path
import numpy as np
import pandas as pd

# %%
FIFA18 = pd.read_csv("../../data/raw/complete.csv")

# %%
FIFA18.head()
# Out:
#        ID               name                     full_name  \
# 0   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 1  158023           L. Messi                  Lionel Messi
# 2  190871             Neymar    Neymar da Silva Santos Jr.
# 3  176580          L. Suárez                   Luis Suárez
# 4  167495           M. Neuer                  Manuel Neuer
#
#                   club                                club_logo  special  age  \
# 0       Real Madrid CF  https://cdn.sofifa.org/18/teams/243.png     2228   32
# 1         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2158   30
# 2  Paris Saint-Germain   https://cdn.sofifa.org/18/teams/73.png     2100   25
# 3         FC Barcelona  https://cdn.sofifa.org/18/teams/241.png     2291   30
# 4     FC Bayern Munich   https://cdn.sofifa.org/18/teams/21.png     1493   31
#
#                      league  birth_date  height_cm     ...      prefers_cb  \
# 0  Spanish Primera División  1985-02-05      185.0     ...           False
# 1  Spanish Primera División  1987-06-24      170.0     ...           False
# 2            French Ligue 1  1992-02-05      175.0     ...           False
# 3  Spanish Primera División  1987-01-24      182.0     ...           False
# 4         German Bundesliga  1986-03-27      193.0     ...           False
#
#   prefers_lb  prefers_lwb prefers_ls prefers_lf prefers_lam  prefers_lcm  \
# 0      False        False      False      False       False        False
# 1      False        False      False      False       False        False
# 2      False        False      False      False       False        False
# 3      False        False      False      False       False        False
# 4      False        False      False      False       False        False
#
#    prefers_ldm  prefers_lcb  prefers_gk
# 0        False        False       False
# 1        False        False       False
# 2        False        False       False
# 3        False        False       False
# 4        False        False        True
#
# [5 rows x 185 columns]

# %%
FIFA18.columns.tolist()
# Out:
# ['ID',
#  'name',
#  'full_name',
#  'club',
#  'club_logo',
#  'special',
#  'age',
#  'league',
#  'birth_date',
#  'height_cm',
#  'weight_kg',
#  'body_type',
#  'real_face',
#  'flag',
#  'nationality',
#  'photo',
#  'eur_value',
#  'eur_wage',
#  'eur_release_clause',
#  'overall',
#  'potential',
#  'pac',
#  'sho',
#  'pas',
#  'dri',
#  'def',
#  'phy',
#  'international_reputation',
#  'skill_moves',
#  'weak_foot',
#  'work_rate_att',
#  'work_rate_def',
#  'preferred_foot',
#  'crossing',
#  'finishing',
#  'heading_accuracy',
#  'short_passing',
#  'volleys',
#  'dribbling',
#  'curve',
#  'free_kick_accuracy',
#  'long_passing',
#  'ball_control',
#  'acceleration',
#  'sprint_speed',
#  'agility',
#  'reactions',
#  'balance',
#  'shot_power',
#  'jumping',
#  'stamina',
#  'strength',
#  'long_shots',
#  'aggression',
#  'interceptions',
#  'positioning',
#  'vision',
#  'penalties',
#  'composure',
#  'marking',
#  'standing_tackle',
#  'sliding_tackle',
#  'gk_diving',
#  'gk_handling',
#  'gk_kicking',
#  'gk_positioning',
#  'gk_reflexes',
#  'rs',
#  'rw',
#  'rf',
#  'ram',
#  'rcm',
#  'rm',
#  'rdm',
#  'rcb',
#  'rb',
#  'rwb',
#  'st',
#  'lw',
#  'cf',
#  'cam',
#  'cm',
#  'lm',
#  'cdm',
#  'cb',
#  'lb',
#  'lwb',
#  'ls',
#  'lf',
#  'lam',
#  'lcm',
#  'ldm',
#  'lcb',
#  'gk',
#  '1_on_1_rush_trait',
#  'acrobatic_clearance_trait',
#  'argues_with_officials_trait',
#  'avoids_using_weaker_foot_trait',
#  'backs_into_player_trait',
#  'bicycle_kicks_trait',
#  'cautious_with_crosses_trait',
#  'chip_shot_trait',
#  'chipped_penalty_trait',
#  'comes_for_crosses_trait',
#  'corner_specialist_trait',
#  'diver_trait',
#  'dives_into_tackles_trait',
#  'diving_header_trait',
#  'driven_pass_trait',
#  'early_crosser_trait',
#  "fan's_favourite_trait",
#  'fancy_flicks_trait',
#  'finesse_shot_trait',
#  'flair_trait',
#  'flair_passes_trait',
#  'gk_flat_kick_trait',
#  'gk_long_throw_trait',
#  'gk_up_for_corners_trait',
#  'giant_throw_in_trait',
#  'inflexible_trait',
#  'injury_free_trait',
#  'injury_prone_trait',
#  'leadership_trait',
#  'long_passer_trait',
#  'long_shot_taker_trait',
#  'long_throw_in_trait',
#  'one_club_player_trait',
#  'outside_foot_shot_trait',
#  'playmaker_trait',
#  'power_free_kick_trait',
#  'power_header_trait',
#  'puncher_trait',
#  'rushes_out_of_goal_trait',
#  'saves_with_feet_trait',
#  'second_wind_trait',
#  'selfish_trait',
#  'skilled_dribbling_trait',
#  'stutter_penalty_trait',
#  'swerve_pass_trait',
#  'takes_finesse_free_kicks_trait',
#  'target_forward_trait',
#  'team_player_trait',
#  'technical_dribbler_trait',
#  'tries_to_beat_defensive_line_trait',
#  'poacher_speciality',
#  'speedster_speciality',
#  'aerial_threat_speciality',
#  'dribbler_speciality',
#  'playmaker_speciality',
#  'engine_speciality',
#  'distance_shooter_speciality',
#  'crosser_speciality',
#  'free_kick_specialist_speciality',
#  'tackling_speciality',
#  'tactician_speciality',
#  'acrobat_speciality',
#  'strength_speciality',
#  'clinical_finisher_speciality',
#  'prefers_rs',
#  'prefers_rw',
#  'prefers_rf',
#  'prefers_ram',
#  'prefers_rcm',
#  'prefers_rm',
#  'prefers_rdm',
#  'prefers_rcb',
#  'prefers_rb',
#  'prefers_rwb',
#  'prefers_st',
#  'prefers_lw',
#  'prefers_cf',
#  'prefers_cam',
#  'prefers_cm',
#  'prefers_lm',
#  'prefers_cdm',
#  'prefers_cb',
#  'prefers_lb',
#  'prefers_lwb',
#  'prefers_ls',
#  'prefers_lf',
#  'prefers_lam',
#  'prefers_lcm',
#  'prefers_ldm',
#  'prefers_lcb',
#  'prefers_gk']

# %%
FIFA18.isnull().sum()
# Out:
# ID                                 0
# name                               0
# full_name                          0
# club                             253
# club_logo                        253
# special                            0
# age                                0
# league                           253
# birth_date                         0
# height_cm                          0
# weight_kg                          0
# body_type                          0
# real_face                          0
# flag                               0
# nationality                        0
# photo                              0
# eur_value                          0
# eur_wage                           0
# eur_release_clause              1494
# overall                            0
# potential                          0
# pac                                0
# sho                                0
# pas                                0
# dri                                0
# def                                0
# phy                                0
# international_reputation           0
# skill_moves                        0
# weak_foot                          0
#                                 ...
# acrobat_speciality                 0
# strength_speciality                0
# clinical_finisher_speciality       0
# prefers_rs                         0
# prefers_rw                         0
# prefers_rf                         0
# prefers_ram                        0
# prefers_rcm                        0
# prefers_rm                         0
# prefers_rdm                        0
# prefers_rcb                        0
# prefers_rb                         0
# prefers_rwb                        0
# prefers_st                         0
# prefers_lw                         0
# prefers_cf                         0
# prefers_cam                        0
# prefers_cm                         0
# prefers_lm                         0
# prefers_cdm                        0
# prefers_cb                         0
# prefers_lb                         0
# prefers_lwb                        0
# prefers_ls                         0
# prefers_lf                         0
# prefers_lam                        0
# prefers_lcm                        0
# prefers_ldm                        0
# prefers_lcb                        0
# prefers_gk                         0
# Length: 185, dtype: int64

# %%
FIFA18.loc[FIFA18['league'].isnull(), 'league'] = 'Rest Of The World'
FIFA18.loc[FIFA18['club'].isnull(), 'club'] = 'Free Agent'

# %%
cols = FIFA18.select_dtypes(include=[np.object]).columns
FIFA18[cols] = FIFA18[cols].apply(lambda x: x.str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8'))

# %%
FIFA18.loc[FIFA18['name'].str.split().str.len() == 1, 'FirstInitial'] = FIFA18['name'].astype(str).str[0]
FIFA18.loc[FIFA18['name'].str.split().str.len() == 1, 'Surname'] = FIFA18['name'].str.split().str[-1]

FIFA18.loc[FIFA18['name'].str.split().str.len() == 2, 'FirstInitial'] = FIFA18['name'].astype(str).str[0]
FIFA18.loc[FIFA18['name'].str.split().str.len() == 2, 'Surname'] = FIFA18['name'].str.split().str[-1]

FIFA18.loc[FIFA18['name'].str.split().str.len() == 3, 'FirstInitial'] = FIFA18['name'].astype(str).str[0]
FIFA18.loc[FIFA18['name'].str.split().str.len() == 3, 'Surname'] = FIFA18['name'].str.split().str[-1]

FIFA18.loc[FIFA18['name'].str.split().str.len() == 4, 'FirstInitial'] = FIFA18['name'].astype(str).str[0]
FIFA18.loc[FIFA18['name'].str.split().str.len() == 4, 'Surname'] = FIFA18['name'].str.split().str[-1]

# %%
FIFA18.set_index(['Surname','FirstInitial'])
# Out:
#                                 ID               name  \
# Surname       FirstInitial
# Ronaldo       C              20801  Cristiano Ronaldo
# Messi         L             158023           L. Messi
# Neymar        N             190871             Neymar
# Suarez        L             176580          L. Suarez
# Neuer         M             167495           M. Neuer
# Lewandowski   R             188545     R. Lewandowski
# Gea           D             193080             De Gea
# Hazard        E             183277          E. Hazard
# Kroos         T             182521           T. Kroos
# Higuain       G             167664         G. Higuain
# Ramos         S             155862       Sergio Ramos
# Bruyne        K             192985       K. De Bruyne
# Courtois      T             192119        T. Courtois
# Sanchez       A             184941         A. Sanchez
# Modric        L             177003          L. Modric
# Bale          G             173731            G. Bale
# Aguero        S             153079          S. Aguero
# Chiellini     G             138956       G. Chiellini
# Buffon        G               1179          G. Buffon
# Dybala        P             211110          P. Dybala
# Oblak         J             200389           J. Oblak
# Griezmann     A             194765       A. Griezmann
# Thiago        T             189509             Thiago
# Aubameyang    P             188567      P. Aubameyang
# Bonucci       L             184344         L. Bonucci
# Boateng       J             183907         J. Boateng
# Godin         D             182493           D. Godin
# Hummels       M             178603         M. Hummels
# Ozil          M             176635            M. Ozil
# Lloris        H             167948          H. Lloris
# ...                            ...                ...
# Robinson      T             225778        T. Robinson
# Clarke        D             241142          D. Clarke
# Hughes        R             231928          R. Hughes
# Mohammed      Z             240381        Z. Mohammed
# Peppard       D             236807         D. Peppard
# Rogers        C             237859          C. Rogers
# McLaughlin    N             225319      N. McLaughlin
# Manley        G             238217          G. Manley
# Phillips      P             238985        P. Phillips
# Byrne         A             238219           A. Byrne
# Fujikawa      K             238477        K. Fujikawa
# Egan          K             231824            K. Egan
# Brownsword    T             237974      T. Brownsword
# Prohart       F             236954         F. Prohart
# Jones         L             229046           L. Jones
# Kilgour       A             231107         A. Kilgour
# White         R             240325           R. White
# Conway        A             238306          A. Conway
# Clifton       H             234497         H. Clifton
# Whelan        M             240146          M. Whelan
# Sawyer        T             240403          T. Sawyer
# Keeble        J             240404          J. Keeble
# McKenzie-Lyle K             229429   K. McKenzie-Lyle
# Sheron        N             234040          N. Sheron
# Kaemodel      T             235352        T. Kaemodel
# Kelsey        A             237463          A. Kelsey
# Richardson    B              11728      B. Richardson
# Young         J             231381           J. Young
# Lundstram     J             238813       J. Lundstram
# Sackey        L             238308          L. Sackey
#
#                                                full_name  \
# Surname       FirstInitial
# Ronaldo       C             C. Ronaldo dos Santos Aveiro
# Messi         L                             Lionel Messi
# Neymar        N               Neymar da Silva Santos Jr.
# Suarez        L                              Luis Suarez
# Neuer         M                             Manuel Neuer
# Lewandowski   R                       Robert Lewandowski
# Gea           D                    David De Gea Quintana
# Hazard        E                              Eden Hazard
# Kroos         T                               Toni Kroos
# Higuain       G                          Gonzalo Higuain
# Ramos         S                      Sergio Ramos Garcia
# Bruyne        K                          Kevin De Bruyne
# Courtois      T                         Thibaut Courtois
# Sanchez       A                           Alexis Sanchez
# Modric        L                              Luka Modric
# Bale          G                              Gareth Bale
# Aguero        S                            Sergio Aguero
# Chiellini     G                        Giorgio Chiellini
# Buffon        G                         Gianluigi Buffon
# Dybala        P                             Paulo Dybala
# Oblak         J                                Jan Oblak
# Griezmann     A                        Antoine Griezmann
# Thiago        T                         Thiago Alcantara
# Aubameyang    P                Pierre-Emerick Aubameyang
# Bonucci       L                         Leonardo Bonucci
# Boateng       J                           Jerome Boateng
# Godin         D                              Diego Godin
# Hummels       M                             Mats Hummels
# Ozil          M                               Mesut Ozil
# Lloris        H                              Hugo Lloris
# ...                                                  ...
# Robinson      T                          Tyrell Robinson
# Clarke        D                            Darren Clarke
# Hughes        R                             Ronan Hughes
# Mohammed      Z                            Zehn Mohammed
# Peppard       D                          Dominic Peppard
# Rogers        C                            Calvin Rogers
# McLaughlin    N                          Neil McLaughlin
# Manley        G                             Garan Manley
# Phillips      P                          Pierce Phillips
# Byrne         A                               Alec Byrne
# Fujikawa      K                          Kotaro Fujikawa
# Egan          K                                Kyle Egan
# Brownsword    T                         Tyler Brownsword
# Prohart       F                          Florian Prohart
# Jones         L                              Louis Jones
# Kilgour       A                            Alfie Kilgour
# White         R                               Ryan White
# Conway        A                             Aaron Conway
# Clifton       H                            Harry Clifton
# Whelan        M                             Mikey Whelan
# Sawyer        T                               Tom Sawyer
# Keeble        J                              Jack Keeble
# McKenzie-Lyle K                        Kai McKenzie-Lyle
# Sheron        N                            Nathan Sheron
# Kaemodel      T                           Tommy Kaemodel
# Kelsey        A                              Adam Kelsey
# Richardson    B                         Barry Richardson
# Young         J                             Jordan Young
# Lundstram     J                           Josh Lundstram
# Sackey        L                            Leslie Sackey
#
#                                               club  \
# Surname       FirstInitial
# Ronaldo       C                     Real Madrid CF
# Messi         L                       FC Barcelona
# Neymar        N                Paris Saint-Germain
# Suarez        L                       FC Barcelona
# Neuer         M                   FC Bayern Munich
# Lewandowski   R                   FC Bayern Munich
# Gea           D                  Manchester United
# Hazard        E                            Chelsea
# Kroos         T                     Real Madrid CF
# Higuain       G                           Juventus
# Ramos         S                     Real Madrid CF
# Bruyne        K                    Manchester City
# Courtois      T                            Chelsea
# Sanchez       A                            Arsenal
# Modric        L                     Real Madrid CF
# Bale          G                     Real Madrid CF
# Aguero        S                    Manchester City
# Chiellini     G                           Juventus
# Buffon        G                           Juventus
# Dybala        P                           Juventus
# Oblak         J                    Atletico Madrid
# Griezmann     A                    Atletico Madrid
# Thiago        T                   FC Bayern Munich
# Aubameyang    P                  Borussia Dortmund
# Bonucci       L                              Milan
# Boateng       J                   FC Bayern Munich
# Godin         D                    Atletico Madrid
# Hummels       M                   FC Bayern Munich
# Ozil          M                            Arsenal
# Lloris        H                  Tottenham Hotspur
# ...                                            ...
# Robinson      T                      Bradford City
# Clarke        D                    Shamrock Rovers
# Hughes        R             Hamilton Academical FC
# Mohammed      Z                 Accrington Stanley
# Peppard       D                        Bohemian FC
# Rogers        C                     Bray Wanderers
# McLaughlin    N               Partick Thistle F.C.
# Manley        G                          Cork City
# Phillips      P                          Cork City
# Byrne         A                          Cork City
# Fujikawa      K                       Jubilo Iwata
# Egan          K                        Exeter City
# Brownsword    T                          Morecambe
# Prohart       F                     Wolfsberger AC
# Jones         L                   Doncaster Rovers
# Kilgour       A                     Bristol Rovers
# White         R                   Bolton Wanderers
# Conway        A                      Galway United
# Clifton       H                       Grimsby Town
# Whelan        M                      Galway United
# Sawyer        T                       Grimsby Town
# Keeble        J                       Grimsby Town
# McKenzie-Lyle K                             Barnet
# Sheron        N                     Fleetwood Town
# Kaemodel      T                  FC Erzgebirge Aue
# Kelsey        A                  Scunthorpe United
# Richardson    B                  Wycombe Wanderers
# Young         J                       Swindon Town
# Lundstram     J                    Crewe Alexandra
# Sackey        L                  Scunthorpe United
#
#                                                              club_logo  \
# Surname       FirstInitial
# Ronaldo       C                https://cdn.sofifa.org/18/teams/243.png
# Messi         L                https://cdn.sofifa.org/18/teams/241.png
# Neymar        N                 https://cdn.sofifa.org/18/teams/73.png
# Suarez        L                https://cdn.sofifa.org/18/teams/241.png
# Lundstram     J             1999-02-19      176.0     ...           False
# Sackey        L             1998-11-29      182.0     ...            True
#
#                            prefers_lb  prefers_lwb prefers_ls prefers_lf  \
# Surname       FirstInitial
# Ronaldo       C                 False        False      False      False
# Messi         L                 False        False      False      False
# Neymar        N                 False        False      False      False
# Suarez        L                 False        False      False      False
# Neuer         M                 False        False      False      False
# Lewandowski   R                 False        False      False      False
# Gea           D                 False        False      False      False
# Hazard        E                 False        False      False      False
# Kroos         T                 False        False      False      False
# Higuain       G                 False        False      False      False
# Ramos         S                 False        False      False      False
# Bruyne        K                 False        False      False      False
# Courtois      T                 False        False      False      False
# Sanchez       A                 False        False      False      False
# Modric        L                 False        False      False      False
# Bale          G                 False        False      False      False
# Aguero        S                 False        False      False      False
# Chiellini     G                 False        False      False      False
# Buffon        G                 False        False      False      False
# Dybala        P                 False        False      False      False
# Oblak         J                 False        False      False      False
# Griezmann     A                 False        False      False      False
# Thiago        T                 False        False      False      False
# Aubameyang    P                 False        False      False      False
# Bonucci       L                 False        False      False      False
# Boateng       J                 False        False      False      False
# Godin         D                 False        False      False      False
# Hummels       M                 False        False      False      False
# Ozil          M                 False        False      False      False
# Lloris        H                 False        False      False      False
# ...                               ...          ...        ...        ...
# Robinson      T                 False        False      False      False
# Clarke        D                 False        False      False      False
# Hughes        R                 False        False      False      False
# Mohammed      Z                 False        False      False      False
# Peppard       D                 False        False      False      False
# Rogers        C                 False        False      False      False
# McLaughlin    N                 False        False      False      False
# Manley        G                 False        False      False      False
# Phillips      P                 False        False      False      False
# Byrne         A                 False        False      False      False
# Fujikawa      K                 False        False      False      False
# Egan          K                 False        False      False      False
# Brownsword    T                 False        False      False      False
# Prohart       F                 False        False      False      False
# Jones         L                 False        False      False      False
# Kilgour       A                 False        False      False      False
# White         R                 False        False      False      False
# Conway        A                  True         True      False      False
# Clifton       H                 False        False      False      False
# Whelan        M                  True        False      False      False
# Sawyer        T                 False        False      False      False
# Keeble        J                 False        False      False      False
# McKenzie-Lyle K                 False        False      False      False
# Sheron        N                 False        False      False      False
# Kaemodel      T                 False        False      False      False
# Kelsey        A                 False        False      False      False
# Richardson    B                 False        False      False      False
# Young         J                 False        False      False      False
# Lundstram     J                 False        False      False      False
# Sackey        L                 False        False      False      False
#
#                            prefers_lam  prefers_lcm  prefers_ldm  prefers_lcb  \
# Surname       FirstInitial
# Ronaldo       C                  False        False        False        False
# Messi         L                  False        False        False        False
# Neymar        N                  False        False        False        False
# Suarez        L                  False        False        False        False
# Neuer         M                  False        False        False        False
# Lewandowski   R                  False        False        False        False
# Gea           D                  False        False        False        False
# Hazard        E                  False        False        False        False
# Kroos         T                  False        False        False        False
# Higuain       G                  False        False        False        False
# Ramos         S                  False        False        False        False
# Bruyne        K                  False        False        False        False
# Courtois      T                  False        False        False        False
# Sanchez       A                  False        False        False        False
# Modric        L                  False        False        False        False
# Bale          G                  False        False        False        False
# Aguero        S                  False        False        False        False
# Chiellini     G                  False        False        False        False
# Buffon        G                  False        False        False        False
# Dybala        P                  False        False        False        False
# Oblak         J                  False        False        False        False
# Griezmann     A                  False        False        False        False
# Thiago        T                  False        False        False        False
# Aubameyang    P                  False        False        False        False
# Bonucci       L                  False        False        False        False
# Boateng       J                  False        False        False        False
# Godin         D                  False        False        False        False
# Hummels       M                  False        False        False        False
# Ozil          M                  False        False        False        False
# Lloris        H                  False        False        False        False
# ...                                ...          ...          ...          ...
# Robinson      T                  False        False        False        False
# Clarke        D                  False        False        False        False
# Hughes        R                  False        False        False        False
# Mohammed      Z                  False        False        False        False
# Peppard       D                  False        False        False        False
# Rogers        C                  False        False        False        False
# McLaughlin    N                  False        False        False        False
# Manley        G                  False        False        False        False
# Phillips      P                  False        False        False        False
# Byrne         A                  False        False        False        False
# Fujikawa      K                  False        False        False        False
# Egan          K                  False        False        False        False
# Brownsword    T                  False        False        False        False
# Prohart       F                  False        False        False        False
# Jones         L                  False        False        False        False
# Kilgour       A                  False        False        False        False
# White         R                  False        False        False        False
# Conway        A                  False        False        False        False
# Clifton       H                  False        False        False        False
# Whelan        M                  False        False        False        False
# Sawyer        T                  False        False        False        False
# Keeble        J                  False        False        False        False
# McKenzie-Lyle K                  False        False        False        False
# Sheron        N                  False        False        False        False
# Kaemodel      T                  False        False        False        False
# Kelsey        A                  False        False        False        False
# Richardson    B                  False        False        False        False
# Young         J                  False        False        False        False
# Lundstram     J                  False        False        False        False
# Sackey        L                  False        False        False        False
#
#                             prefers_gk
# Surname       FirstInitial
# Ronaldo       C                  False
# Messi         L                  False
# Neymar        N                  False
# Suarez        L                  False
# Neuer         M                   True
# Lewandowski   R                  False
# Gea           D                   True
# Hazard        E                  False
# Kroos         T                  False
# Higuain       G                  False
# Ramos         S                  False
# Bruyne        K                  False
# Courtois      T                   True
# Sanchez       A                  False
# Modric        L                  False
# Bale          G                  False
# Aguero        S                  False
# Chiellini     G                  False
# Buffon        G                   True
# Dybala        P                  False
# Oblak         J                   True
# Griezmann     A                  False
# Thiago        T                  False
# Aubameyang    P                  False
# Bonucci       L                  False
# Boateng       J                  False
# Godin         D                  False
# Hummels       M                  False
# Ozil          M                  False
# Lloris        H                   True
# ...                                ...
# Robinson      T                  False
# Clarke        D                  False
# Hughes        R                  False
# Mohammed      Z                  False
# Peppard       D                  False
# Rogers        C                  False
# McLaughlin    N                  False
# Manley        G                  False
# Phillips      P                  False
# Byrne         A                  False
# Fujikawa      K                  False
# Egan          K                  False
# Brownsword    T                  False
# Prohart       F                  False
# Jones         L                   True
# Kilgour       A                  False
# White         R                  False
# Conway        A                  False
# Clifton       H                  False
# Whelan        M                  False
# Sawyer        T                  False
# Keeble        J                  False
# McKenzie-Lyle K                   True
# Sheron        N                  False
# Kaemodel      T                  False
# Kelsey        A                   True
# Richardson    B                   True
# Young         J                  False
# Lundstram     J                  False
# Sackey        L                  False
#
# [17994 rows x 185 columns]

# %%
FIFA18.to_csv('../../data/prep/FIFA18.csv')
