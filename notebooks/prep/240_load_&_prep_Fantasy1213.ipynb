# %%
import os.path
import numpy as np
import pandas as pd

# %%
BPL1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=415")[0]
BUN1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=416")[0]
LAL1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=413")[0]

# %%
SEA1213 = [BPL1213,BUN1213,LAL1213]
SEA1213 = pd.concat(SEA1213)
SEA1213 = SEA1213.reset_index()

# %%
SEA1213.head()
# Out:
#    index            Players  Points   Clubs    Position  Start  Goals   A CS  \
# 0      0   Robin van Persie     225    MUFC     Forward     35     26  10  -
# 1      1        Luis Suarez     186   LPOOL     Forward     33     23   5  -
# 2      2        Gareth Bale     180   SPURS  Midfielder     33     21   6  -
# 3      3  Christian Benteke     165  AVILLA     Forward     32     19   4  -
# 4      4      Santi Cazorla     164    ARSL  Midfielder     37     12  10  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    3   3    4       -     1               -           -
# 1       -  ...     0    0   0    2       -     0               -           -
# 2       -  ...     0    0   0    4       -     0               -           -
# 3       -  ...     0    2   2    4       -     0               -           -
# 4       -  ...     0    1   1   11       -     0               -           -
#
#   OG  More
# 0  0  More
# 1  0  More
# 2  1  More
# 3  0  More
# 4  0  More
#
# [5 rows x 21 columns]

# %%
SEA1213.drop(SEA1213.columns[[0,20]], axis=1, inplace=True)

# %%
SEA1213.head()
# Out:
#              Players  Points   Clubs    Position  Start  Goals   A CS CS part  \
# 0   Robin van Persie     225    MUFC     Forward     35     26  10  -       -
# 1        Luis Suarez     186   LPOOL     Forward     33     23   5  -       -
# 2        Gareth Bale     180   SPURS  Midfielder     33     21   6  -       -
# 3  Christian Benteke     165  AVILLA     Forward     32     19   4  -       -
# 4      Santi Cazorla     164    ARSL  Midfielder     37     12  10  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       6    0    3   3    4      -      1              -           -   0
# 1      10    0    0   0    2      -      0              -           -   0
# 2       6    0    0   0    4      -      0              -           -   1
# 3       8    0    2   2    4      -      0              -           -   0
# 4       1    0    1   1   11      -      0              -           -   0

# %%
SEA1213.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             284
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]
SEA1213[DashColumns] = SEA1213[DashColumns].replace('-' ,'0')

# %%
SEA1213.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1774 entries, 0 to 1773
# Data columns (total 19 columns):
# Players           1774 non-null object
# Points            1774 non-null int64
# Clubs             1490 non-null object
# Position          1774 non-null object
# Start             1774 non-null int64
# Goals             1774 non-null int64
# A                 1774 non-null int64
# CS                1774 non-null object
# CS part           1774 non-null object
# Yellow            1774 non-null int64
# Red               1774 non-null int64
# Sub               1774 non-null int64
# CO                1774 non-null int64
# Off               1774 non-null int64
# Pen SV            1774 non-null object
# Pen M             1774 non-null int64
# Goals conceded    1774 non-null object
# Conceded 1+       1774 non-null object
# OG                1774 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 263.4+ KB

# %%
SEA1213['CS'] = SEA1213['CS'].str.replace('%','').astype(np.int)
SEA1213['CS part'] = SEA1213['CS part'].str.replace('%','').astype(np.int)
SEA1213['Pen SV'] = SEA1213['Pen SV'].str.replace('%','').astype(np.int)
SEA1213['Goals conceded'] = SEA1213['Goals conceded'].str.replace('%','').astype(np.int)
SEA1213['Conceded 1+'] = SEA1213['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 1, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 1, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 1, 'Surname'] = SEA1213['Players'].str.split().str[0]

SEA1213.loc[SEA1213['Players'].str.split().str.len() == 2, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 2, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 2, 'Surname'] = SEA1213['Players'].str.split().str[-1]

SEA1213.loc[SEA1213['Players'].str.split().str.len() == 3, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 3, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 3, 'Surname'] = SEA1213['Players'].str.split().str[-1]

SEA1213.loc[SEA1213['Players'].str.split().str.len() == 4, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 4, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 4, 'Surname'] = SEA1213['Players'].str.split().str[-1]

# %%
SEA1213.set_index(['Surname','FirstInitial'])
# Out:
#                                       Players  Points   Clubs    Position  \
# Surname      FirstInitial
# Persie       R               Robin van Persie     225    MUFC     Forward
# Suarez       L                    Luis Suarez     186   LPOOL     Forward
# Bale         G                    Gareth Bale     180   SPURS  Midfielder
# Benteke      C              Christian Benteke     165  AVILLA     Forward
# Cazorla      S                  Santi Cazorla     164    ARSL  Midfielder
# Mata         J                      Juan Mata     162    CHEL  Midfielder
# Lambert      R                  Ricky Lambert     161   SOTOM     Forward
# Michu        M                          Michu     160    SWAN     Forward
# Walcott      T                   Theo Walcott     150    ARSL     Forward
# Berbatov     D               Dimitar Berbatov     148    MUFC     Forward
# Lukaku       R                  Romelu Lukaku     147    WBFC     Forward
# Ba           D                       Demba Ba     145    NEWU     Forward
# Tevez        C                   Carlos Tevez     144    MCFC     Forward
# Hazard       E                    Eden Hazard     141    CHEL  Midfielder
# Hart         J                       Joe Hart     139    MCFC  Goalkeeper
# Podolski     L                 Lukas Podolski     139    ARSL     Forward
# Baines       L                Leighton Baines     137    EVER    Defender
# Kone         A                    Arouna Kone     136    WAFC     Forward
# Gerrard      S                 Steven Gerrard     134   LPOOL  Midfielder
# Evra         P                   Patrice Evra     129    MUFC    Defender
# Rooney       W                   Wayne Rooney     127    MUFC     Forward
# Fellaini     M              Marouane Fellaini     126    EVER  Midfielder
# Dzeko        E                     Edin Dzeko     124    MCFC     Forward
# Lampard      F                  Frank Lampard     124    CHEL  Midfielder
# Defoe        J                  Jermain Defoe     124   SPURS     Forward
# Johnson      G                   Glen Johnson     123   LPOOL    Defender
# Ivanovic     B             Branislav Ivanovic     123    CHEL    Defender
# Torres       F                Fernando Torres     123    CHEL     Forward
# Mertesacker  P                Per Mertesacker     122    ARSL    Defender
# Maloney      S                  Shaun Maloney     121    WAFC  Midfielder
# ...                                       ...     ...     ...         ...
# Masip        J                    Jordi Masip       0    BARC  Goalkeeper
# Cubillas     D                 David Cubillas       0    RCDE     Forward
# Quintanilla  A               Alex Quintanilla       0    VALA    Defender
# Delgado      C                 Carlos Delgado       0    VALA    Defender
# Thomas       T                         Thomas       0     NaN  Midfielder
# Varela       F               Francisco Varela       0    BETI    Defender
# Puerta       A                 Antonio Puerta       0     NaN     Forward
# Felipe       F                         Felipe       0    VALA  Goalkeeper
# Olazabal     O                  Oier Olazabal       0    BARC  Goalkeeper
# Robles       J                    Joel Robles       0     NaN  Goalkeeper
# Company      G                Gabriel Company       0    MALL    Defender
# Amo          J                Jonathan de Amo       0    RCDE  Midfielder
# Gonzalez     Q                Quique Gonzalez       0    VALL     Forward
# Arrizabalaga K              Kepa Arrizabalaga       0    ATBI  Goalkeeper
# Bifouma      T                 Thievy Bifouma       0    RCDE  Midfielder
# Jurado       J                         Jurado       0    MALA    Defender
# Caro         J                      Jose Caro       0    BETI    Defender
# Alberto      A                        Alberto       0     NaN  Goalkeeper
# Jason        J                          Jason       0     NaN     Forward
# Aketxe       A                    Ager Aketxe       0    ATBI  Midfielder
# Mino         R                     Ruben Mino      -1    MALL  Goalkeeper
# Roderick     R                       Roderick      -1    RCDC    Defender
# Insua        P                    Pablo Insua      -1    RCDC    Defender
# Lanzaro      M               Maurizio Lanzaro      -1    REZA    Defender
# Lopez        I                     Ivan Lopez      -1     NaN    Defender
# Ricardo      R                        Ricardo      -2    OSAS  Goalkeeper
# Garcia       U                    Unai Garcia      -2    OSAS    Defender
# Riesgo       A                   Asier Riesgo      -2    OSAS  Goalkeeper
# Onyewu       O                  Oguchi Onyewu      -3    MALA    Defender
# Pinto        T                    Tiago Pinto      -3    RCDC    Defender
#
#                            Start  Goals   A  CS  CS part  Yellow  Red  Sub  \
# Surname      FirstInitial
# Persie       R                35     26  10   0        0       6    0    3
# Suarez       L                33     23   5   0        0      10    0    0
# Bale         G                33     21   6   0        0       6    0    0
# Benteke      C                32     19   4   0        0       8    0    2
# Cazorla      S                37     12  10   0        0       1    0    1
# Mata         J                31     12  13   0        0       3    0    4
# Lambert      R                35     15   5   0        0       2    0    3
# Michu        M                35     18   2   0        0       6    0    1
# Walcott      T                24     14   9   0        0       3    0    9
# Berbatov     D                32     15   3   0        0       1    0    2
# Lukaku       R                20     17   4   0        0       3    0   15
# Ba           D                30     15   3   0        0       0    0    8
# Tevez        C                28     11  10   0        0       3    0    9
# Hazard       E                31      9  11   0        0       2    0    3
# Hart         J                38      0   0  18        0       0    0    0
# Podolski     L                25     11   9   0        0       1    0   10
# Baines       L                38      5   5  11        0       4    0    0
# Kone         A                32     11   5   0        0       0    0    2
# Gerrard      S                36      9   9   0        0       5    0    0
# Evra         P                34      4   6  10        0       3    0    2
# Rooney       W                22     12  10   0        0       7    0    5
# Fellaini     M                31     11   6   0        0       9    0    0
# Dzeko        E                16     14   4   0        0       4    0   22
# Lampard      F                21     15   1   0        0       2    0   10
# Defoe        J                27     11   4   0        0       4    0    8
# Johnson      G                36      1   3  16        0       7    0    0
# Ivanovic     B                33      5   1  12        0       4    1    5
# Torres       F                28      8   8   0        0       5    0   10
# Mertesacker  P                33      3   0  14        0       3    1    3
# Maloney      S                34      6   9   0        0       6    0    2
# ...                          ...    ...  ..  ..      ...     ...  ...  ...
# Masip        J                 0      0   0   0        0       0    0    2
# Cubillas     D                 0      0   0   0        0       0    0    1
# Quintanilla  A                 0      0   0   0        0       0    0    1
# Delgado      C                 0      0   0   0        0       0    0    1
# Thomas       T                 0      0   0   0        0       0    0    1
# Varela       F                 0      0   0   0        0       0    0    1
# Puerta       A                 0      0   0   0        0       0    0    1
# Felipe       F                 0      0   0   0        0       0    0    1
# Olazabal     O                 0      0   0   0        0       0    0    5
# Robles       J                 0      0   0   0        0       0    0    1
# Company      G                 0      0   0   0        0       0    0    2
# Amo          J                 0      0   0   0        0       0    0    1
# Gonzalez     Q                 0      0   0   0        0       0    0    1
# Arrizabalaga K                 0      0   0   0        0       0    0    1
# Bifouma      T                 0      0   0   0        0       0    0    1
# Jurado       J                 0      0   0   0        0       0    0    1
# Caro         J                 0      0   0   0        0       0    0    1
# Alberto      A                 0      0   0   0        0       0    0    5
# Jason        J                 0      0   0   0        0       0    0    1
# Aketxe       A                 0      0   0   0        0       0    0    1
# Mino         R                 0      0   0   0        0       0    0   15
# Roderick     R                 3      0   0   0        0       0    0    5
# Insua        P                 2      0   0   0        0       0    0    5
# Lanzaro      M                 0      0   0   0        0       1    0    6
# Lopez        I                 0      0   0   0        0       1    0    6
# Ricardo      R                 0      0   0   0        0       0    0   10
# Garcia       U                 1      0   0   0        0       1    0    0
# Riesgo       A                 1      0   0   0        0       1    0   27
# Onyewu       O                 1      0   0   0        0       0    0   17
# Pinto        T                 1      0   0   0        0       1    0    1
#
#                            CO  Off  Pen SV  Pen M  Goals conceded  \
# Surname      FirstInitial
# Persie       R              3    4       0      1               0
# Suarez       L              0    2       0      0               0
# Bale         G              0    4       0      0               0
# Benteke      C              2    4       0      0               0
# Cazorla      S              1   11       0      0               0
# Mata         J              4   18       0      0               0
# Lambert      R              3    8       0      0               0
# Michu        M              0   13       0      0               0
# Walcott      T              8    9       0      0               0
# Berbatov     D              1    5       0      0               0
# Lukaku       R             15   13       0      1               0
# Ba           D              4   11       0      0               0
# Tevez        C              6   19       0      0               0
# Hazard       E              3   17       0      0               0
# Hart         J              0    0       1      0              34
# Podolski     L              8   23       0      0               0
# Baines       L              0    0       0      0              40
# Kone         A              2    3       0      0               0
# Gerrard      S              0    1       0      1               0
# Evra         P              0    0       0      0              38
# Rooney       W              5    9       0      1               0
# Fellaini     M              0    2       0      0               0
# Dzeko        E             16    6       0      1               0
# Lampard      F              8    5       0      1               0
# Defoe        J              7   10       0      0               0
# Johnson      G              0    1       0      0              40
# Ivanovic     B              1    1       0      0              35
# Torres       F              8    6       0      0               0
# Mertesacker  P              1    0       0      0              30
# Maloney      S              2    9       0      0               0
# ...                        ..  ...     ...    ...             ...
# Masip        J              0    0       0      0               0
# Cubillas     D              0    0       0      0               0
# Quintanilla  A              0    0       0      0               0
# Delgado      C              0    0       0      0               0
# Thomas       T              0    0       0      0               0
# Varela       F              0    0       0      0               0
# Puerta       A              0    0       0      0               0
# Felipe       F              0    0       0      0               0
# Olazabal     O              0    0       0      0               0
# Robles       J              0    0       0      0               0
# Company      G              0    0       0      0               0
# Amo          J              0    0       0      0               0
# Gonzalez     Q              0    0       0      0               0
# Arrizabalaga K              0    0       0      0               0
# Bifouma      T              0    0       0      0               0
# Jurado       J              0    0       0      0               0
# Caro         J              0    0       0      0               0
# Alberto      A              0    0       0      0               0
# Jason        J              0    0       0      0               0
# Aketxe       A              0    0       0      0               0
# Mino         R              1    0       0      0               3
# Roderick     R              0    2       0      0              10
# Insua        P              1    0       0      0               9
# Lanzaro      M              1    0       0      0               2
# Lopez        I              0    0       0      0               0
# Ricardo      R              1    0       0      0               4
# Garcia       U              0    0       0      0               4
# Riesgo       A              0    1       0      0               4
# Onyewu       O              1    0       0      0               8
# Pinto        T              0    0       0      0               5
#
#                            Conceded 1+  OG  Firstname
# Surname      FirstInitial
# Persie       R                       0   0      Robin
# Suarez       L                       0   0       Luis
# Bale         G                       0   1     Gareth
# Benteke      C                       0   0  Christian
# Cazorla      S                       0   0      Santi
# Mata         J                       0   0       Juan
# Lambert      R                       0   0      Ricky
# Michu        M                       0   0      Michu
# Walcott      T                       0   0       Theo
# Berbatov     D                       0   0    Dimitar
# Lukaku       R                       0   0     Romelu
# Ba           D                       0   1      Demba
# Tevez        C                       0   0     Carlos
# Hazard       E                       0   0       Eden
# Hart         J                      14   0        Joe
# Podolski     L                       0   0      Lukas
# Baines       L                      13   2   Leighton
# Kone         A                       0   0     Arouna
# Gerrard      S                       0   1     Steven
# Evra         P                      14   0    Patrice
# Rooney       W                       0   1      Wayne
# Fellaini     M                       0   0   Marouane
# Dzeko        E                       0   0       Edin
# Lampard      F                       0   0      Frank
# Defoe        J                       0   0    Jermain
# Johnson      G                      20   0       Glen
# Ivanovic     B                      13   0  Branislav
# Torres       F                       0   0   Fernando
# Mertesacker  P                      10   0        Per
# Maloney      S                       0   0      Shaun
# ...                                ...  ..        ...
# Masip        J                       0   0      Jordi
# Cubillas     D                       0   0      David
# Quintanilla  A                       0   0       Alex
# Delgado      C                       0   0     Carlos
# Thomas       T                       0   0     Thomas
# Varela       F                       0   0  Francisco
# Puerta       A                       0   0    Antonio
# Felipe       F                       0   0     Felipe
# Olazabal     O                       0   0       Oier
# Robles       J                       0   0       Joel
# Company      G                       0   0    Gabriel
# Amo          J                       0   0   Jonathan
# Gonzalez     Q                       0   0     Quique
# Arrizabalaga K                       0   0       Kepa
# Bifouma      T                       0   0     Thievy
# Jurado       J                       0   0     Jurado
# Caro         J                       0   0       Jose
# Alberto      A                       0   0    Alberto
# Jason        J                       0   0      Jason
# Aketxe       A                       0   0       Ager
# Mino         R                       2   0      Ruben
# Roderick     R                       7   0   Roderick
# Insua        P                       6   0      Pablo
# Lanzaro      M                       1   0   Maurizio
# Lopez        I                       0   0       Ivan
# Ricardo      R                       3   0    Ricardo
# Garcia       U                       3   0       Unai
# Riesgo       A                       3   0      Asier
# Onyewu       O                       6   0     Oguchi
# Pinto        T                       4   0      Tiago
#
# [1774 rows x 20 columns]

# %%
SEA1213.to_csv('../../data/prep/FANTASY1213.csv')
