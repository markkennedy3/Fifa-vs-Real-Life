# %%
import os.path
import numpy as np
import pandas as pd

# %%
BPL1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=415")[0]
BUN1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=416")[0]
LAL1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=413")[0]
SEI1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=414")[0]
FRA1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=412")[0]

# %%
SEA1213 = [BPL1213,BUN1213,LAL1213,SEI1213,FRA1213]
SEA1213 = pd.concat(SEA1213)
SEA1213 = SEA1213.reset_index()

# %%
SEA1213.head()
# Out:
#    index            Players  Points   Clubs    Position  Start  Goals   A CS  \
# 0      0   Robin van Persie     225    MUFC     Forward     35     26  10  -
# 1      1        Luis Suarez     186   LPOOL     Forward     33     23   5  -
# 2      2        Gareth Bale     180   SPURS  Midfielder     33     21   6  -
# 3      3  Christian Benteke     165  AVILLA     Forward     32     19   4  -
# 4      4      Santi Cazorla     164    ARSL  Midfielder     37     12  10  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    3   3    4       -     1               -           -
# 1       -  ...     0    0   0    2       -     0               -           -
# 2       -  ...     0    0   0    4       -     0               -           -
# 3       -  ...     0    2   2    4       -     0               -           -
# 4       -  ...     0    1   1   11       -     0               -           -
#
#   OG  More
# 0  0  More
# 1  0  More
# 2  1  More
# 3  0  More
# 4  0  More
#
# [5 rows x 21 columns]

# %%
SEA1213.drop(SEA1213.columns[[0,20]], axis=1, inplace=True)

# %%
SEA1213.head()
# Out:
#              Players  Points   Clubs    Position  Start  Goals   A CS CS part  \
# 0   Robin van Persie     225    MUFC     Forward     35     26  10  -       -
# 1        Luis Suarez     186   LPOOL     Forward     33     23   5  -       -
# 2        Gareth Bale     180   SPURS  Midfielder     33     21   6  -       -
# 3  Christian Benteke     165  AVILLA     Forward     32     19   4  -       -
# 4      Santi Cazorla     164    ARSL  Midfielder     37     12  10  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       6    0    3   3    4      -      1              -           -   0
# 1      10    0    0   0    2      -      0              -           -   0
# 2       6    0    0   0    4      -      0              -           -   1
# 3       8    0    2   2    4      -      0              -           -   0
# 4       1    0    1   1   11      -      0              -           -   0

# %%
SEA1213.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             688
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]
SEA1213[DashColumns] = SEA1213[DashColumns].replace('-' ,'0')

# %%
SEA1213.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3096 entries, 0 to 3095
# Data columns (total 19 columns):
# Players           3096 non-null object
# Points            3096 non-null int64
# Clubs             2408 non-null object
# Position          3096 non-null object
# Start             3096 non-null int64
# Goals             3096 non-null int64
# A                 3096 non-null int64
# CS                3096 non-null object
# CS part           3096 non-null object
# Yellow            3096 non-null int64
# Red               3096 non-null int64
# Sub               3096 non-null int64
# CO                3096 non-null int64
# Off               3096 non-null int64
# Pen SV            3096 non-null object
# Pen M             3096 non-null int64
# Goals conceded    3096 non-null object
# Conceded 1+       3096 non-null object
# OG                3096 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 459.6+ KB

# %%
SEA1213['CS'] = SEA1213['CS'].str.replace('%','').astype(np.int)
SEA1213['CS part'] = SEA1213['CS part'].str.replace('%','').astype(np.int)
SEA1213['Pen SV'] = SEA1213['Pen SV'].str.replace('%','').astype(np.int)
SEA1213['Goals conceded'] = SEA1213['Goals conceded'].str.replace('%','').astype(np.int)
SEA1213['Conceded 1+'] = SEA1213['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 1, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 1, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 1, 'Surname'] = SEA1213['Players'].str.split().str[0]

SEA1213.loc[SEA1213['Players'].str.split().str.len() == 2, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 2, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 2, 'Surname'] = SEA1213['Players'].str.split().str[-1]

SEA1213.loc[SEA1213['Players'].str.split().str.len() == 3, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 3, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 3, 'Surname'] = SEA1213['Players'].str.split().str[-1]

SEA1213.loc[SEA1213['Players'].str.split().str.len() == 4, 'FirstInitial'] = SEA1213['Players'].astype(str).str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 4, 'Firstname'] = SEA1213['Players'].str.split().str[0]
SEA1213.loc[SEA1213['Players'].str.split().str.len() == 4, 'Surname'] = SEA1213['Players'].str.split().str[-1]

# %%
SEA1213.set_index(['Surname','FirstInitial'])
# Out:
#                                             Players  Points   Clubs  \
# Surname        FirstInitial
# Persie         R                   Robin van Persie     225    MUFC
# Suarez         L                        Luis Suarez     186   LPOOL
# Bale           G                        Gareth Bale     180   SPURS
# Benteke        C                  Christian Benteke     165  AVILLA
# Cazorla        S                      Santi Cazorla     164    ARSL
# Mata           J                          Juan Mata     162    CHEL
# Lambert        R                      Ricky Lambert     161   SOTOM
# Michu          M                              Michu     160    SWAN
# Walcott        T                       Theo Walcott     150    ARSL
# Berbatov       D                   Dimitar Berbatov     148    MUFC
# Lukaku         R                      Romelu Lukaku     147    WBFC
# Ba             D                           Demba Ba     145    NEWU
# Tevez          C                       Carlos Tevez     144    MCFC
# Hazard         E                        Eden Hazard     141    CHEL
# Hart           J                           Joe Hart     139    MCFC
# Podolski       L                     Lukas Podolski     139    ARSL
# Baines         L                    Leighton Baines     137    EVER
# Kone           A                        Arouna Kone     136    WAFC
# Gerrard        S                     Steven Gerrard     134   LPOOL
# Evra           P                       Patrice Evra     129    MUFC
# Rooney         W                       Wayne Rooney     127    MUFC
# Fellaini       M                  Marouane Fellaini     126    EVER
# Dzeko          E                         Edin Dzeko     124    MCFC
# Lampard        F                      Frank Lampard     124    CHEL
# Defoe          J                      Jermain Defoe     124   SPURS
# Johnson        G                       Glen Johnson     123   LPOOL
# Ivanovic       B                 Branislav Ivanovic     123    CHEL
# Torres         F                    Fernando Torres     123    CHEL
# Mertesacker    P                    Per Mertesacker     122    ARSL
# Maloney        S                      Shaun Maloney     121    WAFC
# ...                                             ...     ...     ...
# Andonian       G                      Gael Andonian       0    OLMA
# Labidi         Z                     Zakarie Labidi       0    OLLY
# M'Bow          P                         Pape M'Bow       0    OLMA
# Frick          J                       Jeremy Frick       0    OLLY
# Ongenda        H                     Hervin Ongenda       0     PSG
# Achilli        R                     Romain Achilli       0    SCBA
# Mason          R                         Ryan Mason       0    LORI
# Camacho        R                       Rudy Camacho       0     NaN
# Vena           G                          Gael Vena       0    TOUL
# Michel         J                      Julian Michel       0    LILL
# Crepel         K                       Kevin Crepel       0     NaN
# Staerck-Weille N             Nicolas Staerck-Weille       0     NaN
# Legras         G                   Guillaume Legras       0    MHSC
# Said           W                        Wesley Said       0    STRE
# Astier         J                      Jordan Astier       0    NICE
# Rousseau       V                    Victor Rousseau       0     NaN
# Hamzaoui       M                  Mohammad Hamzaoui       0    MHSC
# Busin          A                       Alexis Busin       0     NaN
# Hunou          A                       Adrien Hunou       0    STRE
# Kembo-Ekoko    J                  Jires Kembo-Ekoko      -1    STRE
# Leca           J                    Jean-Louis Leca      -1     NaN
# Chardonnet     B                 Brendan Chardonnet      -1     NaN
# Sans           M                      Matthieu Sans      -2    SCBA
# Rougeaux       L                     Lucas Rougeaux      -2    NICE
# Beauverger     K                   Kevin Beauverger      -2    STRE
# Crom           R                      Ronan Le Crom      -2     PSG
# Emeghara       I                  Innocent Emeghara      -2    LORI
# Cappone        L                     Lionel Cappone      -2     NaN
# Hartock        J                       Joan Hartock      -3     NaN
# Oberhauser     D                   David Oberhauser      -4    AJAC
#
#                                Position  Start  Goals   A  CS  CS part  \
# Surname        FirstInitial
# Persie         R                Forward     35     26  10   0        0
# Suarez         L                Forward     33     23   5   0        0
# Bale           G             Midfielder     33     21   6   0        0
# Benteke        C                Forward     32     19   4   0        0
# Cazorla        S             Midfielder     37     12  10   0        0
# Mata           J             Midfielder     31     12  13   0        0
# Lambert        R                Forward     35     15   5   0        0
# Michu          M                Forward     35     18   2   0        0
# Walcott        T                Forward     24     14   9   0        0
# Berbatov       D                Forward     32     15   3   0        0
# Lukaku         R                Forward     20     17   4   0        0
# Ba             D                Forward     30     15   3   0        0
# Tevez          C                Forward     28     11  10   0        0
# Hazard         E             Midfielder     31      9  11   0        0
# Hart           J             Goalkeeper     38      0   0  18        0
# Podolski       L                Forward     25     11   9   0        0
# Baines         L               Defender     38      5   5  11        0
# Kone           A                Forward     32     11   5   0        0
# Gerrard        S             Midfielder     36      9   9   0        0
# Evra           P               Defender     34      4   6  10        0
# Rooney         W                Forward     22     12  10   0        0
# Fellaini       M             Midfielder     31     11   6   0        0
# Dzeko          E                Forward     16     14   4   0        0
# Lampard        F             Midfielder     21     15   1   0        0
# Defoe          J                Forward     27     11   4   0        0
# Johnson        G               Defender     36      1   3  16        0
# Ivanovic       B               Defender     33      5   1  12        0
# Torres         F                Forward     28      8   8   0        0
# Mertesacker    P               Defender     33      3   0  14        0
# Maloney        S             Midfielder     34      6   9   0        0
# ...                                 ...    ...    ...  ..  ..      ...
# Andonian       G               Defender      0      0   0   0        0
# Labidi         Z             Midfielder      0      0   0   0        0
# M'Bow          P               Defender      0      0   0   0        0
# Frick          J             Goalkeeper      0      0   0   0        0
# Ongenda        H                Forward      0      0   0   0        0
# Achilli        R             Midfielder      0      0   0   0        0
# Mason          R             Midfielder      0      0   0   0        0
# Camacho        R               Defender      0      0   0   0        0
# Vena           G               Defender      0      0   0   0        0
# Michel         J             Midfielder      0      0   0   0        0
# Crepel         K             Goalkeeper      0      0   0   0        0
# Staerck-Weille N             Midfielder      0      0   0   0        0
# Legras         G             Midfielder      0      0   0   0        0
# Said           W                Forward      0      0   0   0        0
# Astier         J                Forward      0      0   0   0        0
# Rousseau       V             Midfielder      0      0   0   0        0
# Hamzaoui       M             Midfielder      0      0   0   0        0
# Busin          A             Midfielder      0      0   0   0        0
# Hunou          A             Midfielder      0      0   0   0        0
# Kembo-Ekoko    J                Forward      1      0   0   0        0
# Leca           J             Goalkeeper      0      0   0   0        0
# Chardonnet     B               Defender      0      0   0   0        0
# Sans           M               Defender      2      0   0   0        0
# Rougeaux       L               Defender      0      0   0   0        0
# Beauverger     K               Defender      0      0   0   0        0
# Crom           R             Goalkeeper      0      0   0   0        0
# Emeghara       I                Forward      0      0   0   0        0
# Cappone        L             Goalkeeper      0      0   0   0        0
# Hartock        J             Goalkeeper      2      0   0   0        0
# Oberhauser     D             Goalkeeper      0      0   0   0        0
#
#                              Yellow  Red  Sub  CO  Off  Pen SV  Pen M  \
# Surname        FirstInitial
# Persie         R                  6    0    3   3    4       0      1
# Suarez         L                 10    0    0   0    2       0      0
# Bale           G                  6    0    0   0    4       0      0
# Benteke        C                  8    0    2   2    4       0      0
# Cazorla        S                  1    0    1   1   11       0      0
# Mata           J                  3    0    4   4   18       0      0
# Lambert        R                  2    0    3   3    8       0      0
# Michu          M                  6    0    1   0   13       0      0
# Walcott        T                  3    0    9   8    9       0      0
# Berbatov       D                  1    0    2   1    5       0      0
# Lukaku         R                  3    0   15  15   13       0      1
# Ba             D                  0    0    8   4   11       0      0
# Tevez          C                  3    0    9   6   19       0      0
# Hazard         E                  2    0    3   3   17       0      0
# Hart           J                  0    0    0   0    0       1      0
# Podolski       L                  1    0   10   8   23       0      0
# Baines         L                  4    0    0   0    0       0      0
# Kone           A                  0    0    2   2    3       0      0
# Gerrard        S                  5    0    0   0    1       0      1
# Evra           P                  3    0    2   0    0       0      0
# Rooney         W                  7    0    5   5    9       0      1
# Fellaini       M                  9    0    0   0    2       0      0
# Dzeko          E                  4    0   22  16    6       0      1
# Lampard        F                  2    0   10   8    5       0      1
# Defoe          J                  4    0    8   7   10       0      0
# Johnson        G                  7    0    0   0    1       0      0
# Ivanovic       B                  4    1    5   1    1       0      0
# Torres         F                  5    0   10   8    6       0      0
# Mertesacker    P                  3    1    3   1    0       0      0
# Maloney        S                  6    0    2   2    9       0      0
# ...                             ...  ...  ...  ..  ...     ...    ...
# Andonian       G                  0    0    1   0    0       0      0
# Labidi         Z                  0    0    1   0    0       0      0
# M'Bow          P                  0    0   12   0    0       0      0
# Frick          J                  0    0    1   0    0       0      0
# Ongenda        H                  0    0    1   0    0       0      0
# Achilli        R                  0    0    1   0    0       0      0
# Mason          R                  0    0    1   0    0       0      0
# Camacho        R                  0    0    1   1    0       0      0
# Vena           G                  0    0    2   0    0       0      0
# Michel         J                  0    0    1   0    0       0      0
# Crepel         K                  0    0    1   0    0       0      0
# Staerck-Weille N                  0    0    1   0    0       0      0
# Legras         G                  0    0    3   0    0       0      0
# Said           W                  0    0    2   0    0       0      0
# Astier         J                  0    0    1   0    0       0      0
# Rousseau       V                  0    0    2   0    0       0      0
# Hamzaoui       M                  0    0    1   0    0       0      0
# Busin          A                  0    0    1   0    0       0      0
# Hunou          A                  0    0    1   0    0       0      0
# Kembo-Ekoko    J                  0    1    0   0    0       0      0
# Leca           J                  1    0   34   0    0       0      0
# Chardonnet     B                  0    0    2   1    0       0      0
# Sans           M                  1    0    8   4    0       0      0
# Rougeaux       L                  0    0    4   1    0       0      0
# Beauverger     K                  0    0    1   1    0       0      0
# Crom           R                  0    1    2   1    0       0      0
# Emeghara       I                  0    1    2   1    0       0      0
# Cappone        L                  0    0    7   1    0       0      0
# Hartock        J                  0    1   31   0    0       0      0
# Oberhauser     D                  0    0    7   1    0       0      0
#
#                              Goals conceded  Conceded 1+  OG   Firstname
# Surname        FirstInitial
# Persie         R                          0            0   0       Robin
# Suarez         L                          0            0   0        Luis
# Bale           G                          0            0   1      Gareth
# Benteke        C                          0            0   0   Christian
# Cazorla        S                          0            0   0       Santi
# Mata           J                          0            0   0        Juan
# Lambert        R                          0            0   0       Ricky
# Michu          M                          0            0   0       Michu
# Walcott        T                          0            0   0        Theo
# Berbatov       D                          0            0   0     Dimitar
# Lukaku         R                          0            0   0      Romelu
# Ba             D                          0            0   1       Demba
# Tevez          C                          0            0   0      Carlos
# Hazard         E                          0            0   0        Eden
# Hart           J                         34           14   0         Joe
# Podolski       L                          0            0   0       Lukas
# Baines         L                         40           13   2    Leighton
# Kone           A                          0            0   0      Arouna
# Gerrard        S                          0            0   1      Steven
# Evra           P                         38           14   0     Patrice
# Rooney         W                          0            0   1       Wayne
# Fellaini       M                          0            0   0    Marouane
# Dzeko          E                          0            0   0        Edin
# Lampard        F                          0            0   0       Frank
# Defoe          J                          0            0   0     Jermain
# Johnson        G                         40           20   0        Glen
# Ivanovic       B                         35           13   0   Branislav
# Torres         F                          0            0   0    Fernando
# Mertesacker    P                         30           10   0         Per
# Maloney        S                          0            0   0       Shaun
# ...                                     ...          ...  ..         ...
# Andonian       G                          0            0   0        Gael
# Labidi         Z                          0            0   0     Zakarie
# M'Bow          P                          0            0   0        Pape
# Frick          J                          0            0   0      Jeremy
# Ongenda        H                          0            0   0      Hervin
# Achilli        R                          0            0   0      Romain
# Mason          R                          0            0   0        Ryan
# Camacho        R                          2            1   0        Rudy
# Vena           G                          0            0   0        Gael
# Michel         J                          0            0   0      Julian
# Crepel         K                          0            0   0       Kevin
# Staerck-Weille N                          0            0   0     Nicolas
# Legras         G                          0            0   0   Guillaume
# Said           W                          0            0   0      Wesley
# Astier         J                          0            0   0      Jordan
# Rousseau       V                          0            0   0      Victor
# Hamzaoui       M                          0            0   0    Mohammad
# Busin          A                          0            0   0      Alexis
# Hunou          A                          0            0   0      Adrien
# Kembo-Ekoko    J                          0            0   0       Jires
# Leca           J                          0            0   0  Jean-Louis
# Chardonnet     B                          3            2   0     Brendan
# Sans           M                         15            9   0    Matthieu
# Rougeaux       L                          4            3   0       Lucas
# Beauverger     K                          4            3   0       Kevin
# Crom           R                          1            0   0       Ronan
# Emeghara       I                          0            0   0    Innocent
# Cappone        L                          4            3   0      Lionel
# Hartock        J                          6            4   0        Joan
# Oberhauser     D                          3            2   1       David
#
# [3096 rows x 20 columns]

# %%
SEA1213.to_csv('../../data/prep/FANTASY1213.csv')
