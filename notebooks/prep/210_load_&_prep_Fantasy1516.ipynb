# %%
import os.path
import numpy as np
import pandas as pd

# %%
BPL1516 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=515")[0]
BUN1516 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=516")[0]
LAL1516 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=518")[0]

# %%
SEA1516 = [BPL1516,BUN1516,LAL1516]
SEA1516 = pd.concat(SEA1516)
SEA1516 = SEA1516.reset_index()

# %%
SEA1516.head()
# Out:
#    index        Players  Points   Clubs    Position  Start  Goals   A CS  \
# 0      0    Jamie Vardy     202  LEICSC     Forward     36     24   6  -
# 1      1     Harry Kane     199   SPURS     Forward     38     25   2  -
# 2      2   Riyad Mahrez     189  LEICSC  Midfielder     36     17  12  -
# 3      3  Sergio Aguero     182    MCFC     Forward     29     24   2  -
# 4      4  Romelu Lukaku     179    EVER     Forward     36     18   7  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    0   0    7       -     1               -           -
# 1       -  ...     0    0   0    9       -     0               -           -
# 2       -  ...     0    2   1   24       -     2               -           -
# 3       -  ...     0    3   1   16       -     1               -           -
# 4       -  ...     0    2   1    8       -     1               -           -
#
#   OG  More
# 0  0  More
# 1  1  More
# 2  0  More
# 3  0  More
# 4  0  More
#
# [5 rows x 21 columns]

# %%
SEA1516.drop(SEA1516.columns[[0,20]], axis=1, inplace=True)

# %%
SEA1516.head()
# Out:
#          Players  Points   Clubs    Position  Start  Goals   A CS CS part  \
# 0    Jamie Vardy     202  LEICSC     Forward     36     24   6  -       -
# 1     Harry Kane     199   SPURS     Forward     38     25   2  -       -
# 2   Riyad Mahrez     189  LEICSC  Midfielder     36     17  12  -       -
# 3  Sergio Aguero     182    MCFC     Forward     29     24   2  -       -
# 4  Romelu Lukaku     179    EVER     Forward     36     18   7  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       6    0    0   0    7      -      1              -           -   0
# 1       5    0    0   0    9      -      0              -           -   1
# 2       1    0    2   1   24      -      2              -           -   0
# 3       1    0    3   1   16      -      1              -           -   0
# 4       3    0    2   1    8      -      1              -           -   0

# %%
SEA1516.head()
# Out:
#          Players  Points   Clubs    Position  Start  Goals   A CS CS part  \
# 0    Jamie Vardy     202  LEICSC     Forward     36     24   6  -       -
# 1     Harry Kane     199   SPURS     Forward     38     25   2  -       -
# 2   Riyad Mahrez     189  LEICSC  Midfielder     36     17  12  -       -
# 3  Sergio Aguero     182    MCFC     Forward     29     24   2  -       -
# 4  Romelu Lukaku     179    EVER     Forward     36     18   7  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       6    0    0   0    7      -      1              -           -   0
# 1       5    0    0   0    9      -      0              -           -   1
# 2       1    0    2   1   24      -      2              -           -   0
# 3       1    0    3   1   16      -      1              -           -   0
# 4       3    0    2   1    8      -      1              -           -   0

# %%
SEA1516.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             326
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]
SEA1516[DashColumns] = SEA1516[DashColumns].replace('-' ,'0')

# %%
SEA1516.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1784 entries, 0 to 1783
# Data columns (total 19 columns):
# Players           1784 non-null object
# Points            1784 non-null int64
# Clubs             1458 non-null object
# Position          1784 non-null object
# Start             1784 non-null int64
# Goals             1784 non-null int64
# A                 1784 non-null int64
# CS                1784 non-null object
# CS part           1784 non-null object
# Yellow            1784 non-null int64
# Red               1784 non-null int64
# Sub               1784 non-null int64
# CO                1784 non-null int64
# Off               1784 non-null int64
# Pen SV            1784 non-null object
# Pen M             1784 non-null int64
# Goals conceded    1784 non-null object
# Conceded 1+       1784 non-null object
# OG                1784 non-null int64
# dtypes: int64(11), object(8)
# memory usage: 264.9+ KB

# %%
SEA1516['CS'] = SEA1516['CS'].str.replace('%','').astype(np.int)
SEA1516['CS part'] = SEA1516['CS part'].str.replace('%','').astype(np.int)
SEA1516['Pen SV'] = SEA1516['Pen SV'].str.replace('%','').astype(np.int)
SEA1516['Goals conceded'] = SEA1516['Goals conceded'].str.replace('%','').astype(np.int)
SEA1516['Conceded 1+'] = SEA1516['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 1, 'FirstInitial'] = SEA1516['Players'].astype(str).str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 1, 'Firstname'] = SEA1516['Players'].str.split().str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 1, 'Surname'] = SEA1516['Players'].str.split().str[0]

SEA1516.loc[SEA1516['Players'].str.split().str.len() == 2, 'FirstInitial'] = SEA1516['Players'].astype(str).str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 2, 'Firstname'] = SEA1516['Players'].str.split().str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 2, 'Surname'] = SEA1516['Players'].str.split().str[-1]

SEA1516.loc[SEA1516['Players'].str.split().str.len() == 3, 'FirstInitial'] = SEA1516['Players'].astype(str).str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 3, 'Firstname'] = SEA1516['Players'].str.split().str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 3, 'Surname'] = SEA1516['Players'].str.split().str[-1]

SEA1516.loc[SEA1516['Players'].str.split().str.len() == 4, 'FirstInitial'] = SEA1516['Players'].astype(str).str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 4, 'Firstname'] = SEA1516['Players'].str.split().str[0]
SEA1516.loc[SEA1516['Players'].str.split().str.len() == 4, 'Surname'] = SEA1516['Players'].str.split().str[-1]

# %%
SEA1516.set_index(['Surname','FirstInitial'])
# Out:
#                                            Players  Points    Clubs  \
# Surname      FirstInitial
# Vardy        J                         Jamie Vardy     202   LEICSC
# Kane         H                          Harry Kane     199    SPURS
# Mahrez       R                        Riyad Mahrez     189   LEICSC
# Aguero       S                       Sergio Aguero     182     MCFC
# Lukaku       R                       Romelu Lukaku     179     EVER
# Giroud       O                      Olivier Giroud     157     ARSL
# Deeney       T                         Troy Deeney     155      WFC
# Ighalo       O                        Odion Ighalo     153      WFC
# Ozil         M                          Mesut Ozil     153     ARSL
# Bellerin     H                     Hector Bellerin     152     ARSL
# Wijnaldum    G                 Georginio Wijnaldum     143     NEWU
# Alderweireld T                   Toby Alderweireld     141    SPURS
# Arnautovic   M                    Marko Arnautovic     141   STOKEC
# Sanchez      A                      Alexis Sanchez     137     ARSL
# Payet        D                       Dimitri Payet     137  WESTHAM
# Barkley      R                        Ross Barkley     137     EVER
# Monreal      N                       Nacho Monreal     136     ARSL
# Defoe        J                       Jermain Defoe     136     SUND
# Eriksen      C                   Christian Eriksen     135    SPURS
# Ayew         A                          Andre Ayew     135     SWAN
# Mane         S                          Sadio Mane     133    SOTOM
# Morgan       W                          Wes Morgan     133   LEICSC
# Alli         D                           Dele Alli     131    SPURS
# Tadic        D                         Dusan Tadic     130    SOTOM
# Koscielny    L                   Laurent Koscielny     129     ARSL
# Huth         R                         Robert Huth     128   LEICSC
# Sigurdsson   G                    Gylfi Sigurdsson     126     SWAN
# Costa        D                         Diego Costa     125     CHEL
# Martial      A                     Anthony Martial     125     MUFC
# Fuchs        C                     Christian Fuchs     124   LEICSC
# ...                                            ...     ...      ...
# Cabrera      C             Carlos Gonzalez Cabrera       0     LASP
# Tejero       A                       Alvaro Tejero       0     MADR
# Galan        B                         Borja Galan       0      NaN
# Ivi          I                                 Ivi       0     SEVI
# Pareja       N                      Nicolas Pareja       0     SEVI
# Carmona      D                       David Carmona       0     SEVI
# Gayoso       A                        Ander Gayoso       0      NaN
# Diedhiou     A               Amath Ndiaye Diedhiou       0      NaN
# Soriano      J                        Juan Soriano       0     SEVI
# Cifu         C                                Cifu       0     MALA
# Fernandez    L                      Luis Fernandez       0     RCDC
# Cabello      D                       Diego Cabello       0     VALA
# Lopez        P                         Pedro Lopez       0     BETI
# Oscar        O                               Oscar       0     RCDC
# Lasso        B                         Borja Lasso       0     SEVI
# Soler        C                        Carlos Soler       0     VALA
# Odriozola    A                    Alvaro Odriozola       0     RESO
# Latorre      A                     Antonio Latorre       0     VALA
# Lopez        L                         Lluis Lopez       0     RCDE
# Mainz        D                         Diego Mainz      -1      NaN
# Pablo        M                        Manuel Pablo      -1     RCDC
# Goldar       D                        David Goldar      -1     RCCV
# Rober        R                               Rober      -1     RCDC
# Kelava       I                         Ivan Kelava      -1      NaN
# Ruiz         S                       Salvador Ruiz      -2      NaN
# Herrerin     I                       Iago Herrerin      -3     ATBI
# Lichnovsky   I                     Igor Lichnovsky      -3      NaN
# Pereira      A                      Alvaro Pereira      -5      NaN
# Ciani        M                       Michael Ciani      -5     RCDE
# Arlauskis    G                  Giedrius Arlauskis      -6     RCDE
#
#                              Position  Start  Goals   A  CS  CS part  Yellow  \
# Surname      FirstInitial
# Vardy        J                Forward     36     24   6   0        0       6
# Kane         H                Forward     38     25   2   0        0       5
# Mahrez       R             Midfielder     36     17  12   0        0       1
# Aguero       S                Forward     29     24   2   0        0       1
# Lukaku       R                Forward     36     18   7   0        0       3
# Giroud       O                Forward     26     16   6   0        0       2
# Deeney       T                Forward     36     13   9   0        0       6
# Ighalo       O                Forward     36     15   3   0        0       4
# Ozil         M             Midfielder     35      6  19   0        0       4
# Bellerin     H               Defender     36      1   7  18        0       3
# Wijnaldum    G             Midfielder     36     11   5   0        0       1
# Alderweireld T               Defender     38      4   2  13        0       3
# Arnautovic   M             Midfielder     33     11   7   0        0       2
# Sanchez      A                Forward     28     13   5   0        0       1
# Payet        D             Midfielder     29      9  12   0        0       3
# Barkley      R             Midfielder     36      8   9   0        0       4
# Monreal      N               Defender     36      0   3  17        1       1
# Defoe        J                Forward     28     15   1   0        0       3
# Eriksen      C             Midfielder     33      6  13   0        0       2
# Ayew         A                Forward     34     12   4   0        0       5
# Mane         S             Midfielder     30     11   7   0        0       5
# Morgan       W               Defender     38      2   1  15        0       3
# Alli         D             Midfielder     28     10   9   0        0       7
# Tadic        D             Midfielder     27      7  12   0        0       2
# Koscielny    L               Defender     33      4   0  15        0       3
# Huth         R               Defender     35      3   1  15        0       8
# Sigurdsson   G             Midfielder     32     11   3   0        0       6
# Costa        D                Forward     27     12   6   0        0       8
# Martial      A             Midfielder     29     11   4   0        0       2
# Fuchs        C               Defender     30      0   4  15        0       4
# ...                               ...    ...    ...  ..  ..      ...     ...
# Cabrera      C                Forward      0      0   0   0        0       0
# Tejero       A               Defender      0      0   0   0        0       0
# Galan        B                Forward      0      0   0   0        0       0
# Ivi          I                Forward      0      0   0   0        0       0
# Pareja       N               Defender      1      0   0   0        0       0
# Carmona      D               Defender      1      0   0   0        0       0
# Gayoso       A               Defender      0      0   0   0        0       0
# Diedhiou     A                Forward      0      0   0   0        0       0
# Soriano      J             Goalkeeper      0      0   0   0        0       0
# Cifu         C               Defender      0      0   0   0        0       0
# Fernandez    L                Forward      0      0   0   0        0       0
# Cabello      D               Defender      0      0   0   0        0       0
# Lopez        P             Goalkeeper      0      0   0   0        0       0
# Oscar        O             Midfielder      0      0   0   0        0       0
# Lasso        B             Midfielder      0      0   0   0        0       0
# Soler        C             Midfielder      0      0   0   0        0       0
# Odriozola    A               Defender      0      0   0   0        0       0
# Latorre      A               Defender      0      0   0   0        0       0
# Lopez        L               Defender      0      0   0   0        0       0
# Mainz        D               Defender      4      0   0   0        0       1
# Pablo        M               Defender      2      0   0   0        0       0
# Goldar       D               Defender      1      0   0   0        0       1
# Rober        R               Defender      0      0   0   0        0       0
# Kelava       I             Goalkeeper      0      0   0   0        0       1
# Ruiz         S               Defender      1      0   0   0        0       0
# Herrerin     I             Goalkeeper      1      0   0   0        0       0
# Lichnovsky   I               Defender      2      0   0   0        0       0
# Pereira      A               Defender      6      0   0   0        0       3
# Ciani        M               Defender      2      0   0   0        0       0
# Arlauskis    G             Goalkeeper      3      0   0   0        0       0
#
#                            Red  Sub  CO  Off  Pen SV  Pen M  Goals conceded  \
# Surname      FirstInitial
# Vardy        J               0    0   0    7       0      1               0
# Kane         H               0    0   0    9       0      0               0
# Mahrez       R               0    2   1   24       0      2               0
# Aguero       S               0    3   1   16       0      1               0
# Lukaku       R               0    2   1    8       0      1               0
# Giroud       O               0   12  12    8       0      0               0
# Deeney       T               0    2   2    3       0      1               0
# Ighalo       O               0    1   1    8       0      0               0
# Ozil         M               0    0   0   14       0      0               0
# Bellerin     H               0    0   0    0       0      0              33
# Wijnaldum    G               0    2   2    7       0      0               0
# Alderweireld T               0    0   0    1       0      0              35
# Arnautovic   M               0    1   1   14       0      0               0
# Sanchez      A               0    2   2   12       0      0               0
# Payet        D               0    1   1    6       0      0               0
# Barkley      R               0    2   2   14       0      0               0
# Monreal      N               0    2   1    0       0      0              34
# Defoe        J               0    9   5    5       0      0               0
# Eriksen      C               0    2   2   10       0      0               0
# Ayew         A               0    1   0   15       0      0               0
# Mane         S               1    8   7   15       0      1               0
# Morgan       W               0    0   0    0       0      0              36
# Alli         D               0    6   5   17       0      0               0
# Tadic        D               0   11   7   19       0      0               0
# Koscielny    L               0    1   0    2       0      0              32
# Huth         R               0    0   0    0       0      0              32
# Sigurdsson   G               0    4   4    6       0      0               0
# Costa        D               0    2   1    6       0      0               0
# Martial      A               0    2   2    2       0      0               0
# Fuchs        C               0    4   2    1       0      0              23
# ...                        ...  ...  ..  ...     ...    ...             ...
# Cabrera      C               0    1   0    0       0      0               0
# Tejero       A               0    1   0    0       0      0               0
# Galan        B               0    1   0    0       0      0               0
# Ivi          I               0    1   0    0       0      0               0
# Pareja       N               0    1   1    1       0      0               5
# Carmona      D               0    0   0    0       0      0               3
# Gayoso       A               0    1   1    0       0      0               2
# Diedhiou     A               0    1   0    0       0      0               0
# Soriano      J               0    1   0    0       0      0               0
# Cifu         C               0    3   0    0       0      0               0
# Fernandez    L               0    1   0    0       0      0               0
# Cabello      D               0    1   0    0       0      0               0
# Lopez        P               0    1   0    0       0      0               0
# Oscar        O               0    1   0    0       0      0               0
# Lasso        B               0    1   0    0       0      0               0
# Soler        C               0    1   0    0       0      0               0
# Odriozola    A               0    2   0    0       0      0               0
# Latorre      A               0    1   0    0       0      0               0
# Lopez        L               0    1   0    0       0      0               0
# Mainz        D               0    9   1    0       0      0              14
# Pablo        M               0    9   1    1       0      0               9
# Goldar       D               0    2   0    0       0      0               3
# Rober        R               0    8   2    0       0      0               5
# Kelava       I               0   24   0    0       0      0               0
# Ruiz         S               1   10   1    0       0      0               4
# Herrerin     I               0   37   1    0       0      0               8
# Lichnovsky   I               0   10   0    0       0      0               9
# Pereira      A               0    2   0    2       0      0              20
# Ciani        M               0    6   0    1       0      0              11
# Arlauskis    G               0   11   0    1       0      0              15
#
#                            Conceded 1+  OG  Firstname
# Surname      FirstInitial
# Vardy        J                       0   0      Jamie
# Kane         H                       0   1      Harry
# Mahrez       R                       0   0      Riyad
# Aguero       S                       0   0     Sergio
# Lukaku       R                       0   0     Romelu
# Giroud       O                       0   1    Olivier
# Deeney       T                       0   1       Troy
# Ighalo       O                       0   0      Odion
# Ozil         M                       0   0      Mesut
# Bellerin     H                      15   0     Hector
# Wijnaldum    G                       0   0  Georginio
# Alderweireld T                      10   0       Toby
# Arnautovic   M                       0   0      Marko
# Sanchez      A                       0   0     Alexis
# Payet        D                       0   0    Dimitri
# Barkley      R                       0   0       Ross
# Monreal      N                      15   0      Nacho
# Defoe        J                       0   0    Jermain
# Eriksen      C                       0   0  Christian
# Ayew         A                       0   0      Andre
# Mane         S                       0   0      Sadio
# Morgan       W                      13   0        Wes
# Alli         D                       0   0       Dele
# Tadic        D                       0   0      Dusan
# Koscielny    L                      14   0    Laurent
# Huth         R                      12   0     Robert
# Sigurdsson   G                       0   0      Gylfi
# Costa        D                       0   0      Diego
# Martial      A                       0   0    Anthony
# Fuchs        C                       6   0  Christian
# ...                                ...  ..        ...
# Cabrera      C                       0   0     Carlos
# Tejero       A                       0   0     Alvaro
# Galan        B                       0   0      Borja
# Ivi          I                       0   0        Ivi
# Pareja       N                       3   0    Nicolas
# Carmona      D                       2   0      David
# Gayoso       A                       1   0      Ander
# Diedhiou     A                       0   0      Amath
# Soriano      J                       0   0       Juan
# Cifu         C                       0   0       Cifu
# Fernandez    L                       0   0       Luis
# Cabello      D                       0   0      Diego
# Lopez        P                       0   0      Pedro
# Oscar        O                       0   0      Oscar
# Lasso        B                       0   0      Borja
# Soler        C                       0   0     Carlos
# Odriozola    A                       0   0     Alvaro
# Latorre      A                       0   0    Antonio
# Lopez        L                       0   0      Lluis
# Mainz        D                       9   0      Diego
# Pablo        M                       6   0     Manuel
# Goldar       D                       2   0      David
# Rober        R                       3   0      Rober
# Kelava       I                       0   0       Ivan
# Ruiz         S                       2   0   Salvador
# Herrerin     I                       6   0       Iago
# Lichnovsky   I                       7   0       Igor
# Pereira      A                      14   0     Alvaro
# Ciani        M                       9   0    Michael
# Arlauskis    G                      12   0   Giedrius
#
# [1784 rows x 20 columns]

# %%
SEA1516.to_csv('../../data/prep/FANTASY1516.csv')
