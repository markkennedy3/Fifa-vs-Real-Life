# %%
# %%capture
# %run 200_load_&_prep_Fantasy1718.ipynb
# %run 210_load_&_prep_Fantasy1617.ipynb
# %run 220_load_&_prep_Fantasy1516.ipynb
# %run 230_load_&_prep_Fantasy1415.ipynb
# %run 240_load_&_prep_Fantasy1314.ipynb
# %run 250_load_&_prep_Fantasy1213.ipynb
# %run 300_Join_FIFA_Fantasy1718.ipynb
# %run 310_Join_FIFA_Fantasy1617.ipynb
# %run 320_Join_FIFA_Fantasy1516.ipynb
# %run 330_Join_FIFA_Fantasy1415.ipynb
# %run 340_Join_FIFA_Fantasy1314.ipynb
# %run 350_Join_FIFA_Fantasy1213.ipynb
# %run 400_prep_RQ1_Dataframe.ipynb
# %run 420_prep_RQ3_Dataframe.ipynb
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/Data Science in Practice/Fifa-vs-Real-LIfe-master/notebooks/prep/420_prep_RQ3_Dataframe.ipynb in <module>()
# ----> 1 s1 = DF1.drop_duplicates([RQ3_2]).set_index(['Players','club','league','age','nationality','Position','overall','potential','Continent'])[['Form','Apps']]
#       2 s2 = DF2.drop_duplicates(['Players','club','league','age','nationality','Position','overall','potential','Continent']).set_index(['Players','club','league','age','nationality','Position','overall','potential','Continent'])[['Form','Apps']]
#       3 s3 = DF3.drop_duplicates(['Players','club','league','age','nationality','Position','overall','potential','Continent']).set_index(['Players','club','league','age','nationality','Position','overall','potential','Continent'])[['Form','Apps']]
#       4 s4 = DF4.drop_duplicates(['Players','club','league','age','nationality','Position','overall','potential','Continent']).set_index(['Players','club','league','age','nationality','Position','overall','potential','Continent'])[['Form','Apps']]
#       5 s5 = DF5.drop_duplicates(['Players','club','league','age','nationality','Position','overall','potential','Continent']).set_index(['Players','club','league','age','nationality','Position','overall','potential','Continent'])[['Form','Apps']]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop_duplicates(self, subset, keep, inplace)
#    3096         """
#    3097         inplace = validate_bool_kwarg(inplace, 'inplace')
# -> 3098         duplicated = self.duplicated(subset, keep=keep)
#    3099
#    3100         if inplace:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    3142
#    3143         vals = (self[col].values for col in subset)
# -> 3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#    3146         ids = get_group_index(labels, shape, sort=False, xnull=False)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in <genexpr>(.0)
#    3141             subset = subset,
#    3142
# -> 3143         vals = (self[col].values for col in subset)
#    3144         labels, shape = map(list, zip(*map(f, vals)))
#    3145
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1956         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1957             # either boolean or fancy integer index
# -> 1958             return self._getitem_array(key)
#    1959         elif isinstance(key, DataFrame):
#    1960             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2000             return self.take(indexer, axis=0, convert=False)
#    2001         else:
# -> 2002             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2003             return self.take(indexer, axis=1, convert=True)
#    2004
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1229                 mask = check == -1
#    1230                 if mask.any():
# -> 1231                     raise KeyError('%s not in index' % objarr[mask])
#    1232
#    1233                 return _values_from_object(indexer)
#
# KeyError: "['name' 'full_name' 'skill_moves' 'Points' 'Clubs' 'Start' 'Goals' 'A' 'CS'\n 'CS part' 'Yellow' 'Red' 'Sub' 'CO' 'Off' 'Pen SV' 'Pen M'\n 'Goals conceded' 'Conceded 1+' 'OG'] not in index"
