# %%
import os.path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
# %matplotlib inline

# %%
BPL1617 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=556")[0]
BPL1516 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=515")[0]
BPL1415 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=481")[0]
BPL1314 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=449")[0]
BPL1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=415")[0]

# %%
BUN1617 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=561")[0]
BUN1516 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=516")[0]
BUN1415 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=483")[0]
BUN1314 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=447")[0]
BUN1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=416")[0]

# %%
LAL1617 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=564")[0]
LAL1516 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=518")[0]
LAL1415 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=485")[0]
LAL1314 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=461")[0]
LAL1213 = pd.read_html("https://www.statbunker.com/competitions/FantasyFootballPlayersStats?comp_id=413")[0]

# %%
Season2017 = [BPL1617,BUN1617,LAL1617]
DB1617= pd.concat(Season2017)
DB1617 = DB1617.reset_index()

Season2016 = [BPL1516,BUN1516,LAL1516]
DB1516= pd.concat(Season2016)
DB1516 = DB1516.reset_index()

Season2015 = [BPL1415,BUN1415,LAL1415]
DB1415= pd.concat(Season2015)
DB1415 = DB1415.reset_index()

Season2014 = [BPL1314,BUN1314,LAL1314]
DB1314= pd.concat(Season2014)
DB1314 = DB1314.reset_index()

Season2013 = [BPL1213,BUN1213,LAL1213]
DB1213= pd.concat(Season2013)
DB1213 = DB1213.reset_index()

# %%
DB1617.head(5)
# Out:
#    index         Players  Points  Clubs    Position  Start  Goals   A CS  \
# 0      0      Harry Kane     220  SPURS     Forward     29     29   7  -
# 1      1  Alexis Sanchez     219   ARSL     Forward     36     24  11  -
# 2      2   Romelu Lukaku     213   EVER     Forward     36     25   6  -
# 3      3     Diego Costa     179   CHEL     Forward     35     20   7  -
# 4      4       Dele Alli     179  SPURS  Midfielder     35     18   7  -
#
#   CS part  ...   Red  Sub  CO  Off  Pen SV Pen M  Goals conceded Conceded 1+  \
# 0       -  ...     0    1   1   16       -     1               -           -
# 1       -  ...     0    2   2    8       -     1               -           -
# 2       -  ...     0    1   1    2       -     0               -           -
# 3       -  ...     0    1   0    8       -     1               -           -
# 4       -  ...     0    2   2   13       -     0               -           -
#
#   OG  More
# 0  0  More
# 1  0  More
# 2  0  More
# 3  0  More
# ...

# %%
DB1617.drop(DB1617.columns[[0,20]], axis=1, inplace=True)
DB1516.drop(DB1516.columns[[0,20]], axis=1, inplace=True)
DB1415.drop(DB1415.columns[[0,20]], axis=1, inplace=True)
DB1314.drop(DB1314.columns[[0,20]], axis=1, inplace=True)
DB1213.drop(DB1213.columns[[0,20]], axis=1, inplace=True)

# %%
DB1617.head(5)
# Out:
#           Players  Points  Clubs    Position  Start  Goals   A CS CS part  \
# 0      Harry Kane     220  SPURS     Forward     29     29   7  -       -
# 1  Alexis Sanchez     219   ARSL     Forward     36     24  11  -       -
# 2   Romelu Lukaku     213   EVER     Forward     36     25   6  -       -
# 3     Diego Costa     179   CHEL     Forward     35     20   7  -       -
# 4       Dele Alli     179  SPURS  Midfielder     35     18   7  -       -
#
#    Yellow  Red  Sub  CO  Off Pen SV  Pen M Goals conceded Conceded 1+  OG
# 0       3    0    1   1   16      -      1              -           -   0
# 1       6    0    2   2    8      -      1              -           -   0
# 2       3    0    1   1    2      -      0              -           -   0
# 3      10    0    1   0    8      -      1              -           -   0
# 4       4    0    2   2   13      -      0              -           -   0

# %%
DB1617.loc[DB1617['Players'].str.split().str.len() == 1, 'FirstInitial'] = DB1617['Players'].astype(str).str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 1, 'Firstname'] = DB1617['Players'].str.split().str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 1, 'Surname'] = DB1617['Players'].str.split().str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 2, 'FirstInitial'] = DB1617['Players'].astype(str).str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 2, 'Firstname'] = DB1617['Players'].str.split().str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 2, 'Surname'] = DB1617['Players'].str.split().str[-1]
DB1617.loc[DB1617['Players'].str.split().str.len() == 3, 'FirstInitial'] = DB1617['Players'].astype(str).str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 3, 'Firstname'] = DB1617['Players'].str.split().str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 3, 'Surname'] = DB1617['Players'].str.split().str[-1]
DB1617.loc[DB1617['Players'].str.split().str.len() == 4, 'FirstInitial'] = DB1617['Players'].astype(str).str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 4, 'Firstname'] = DB1617['Players'].str.split().str[0]
DB1617.loc[DB1617['Players'].str.split().str.len() == 4, 'Surname'] = DB1617['Players'].str.split().str[-1]

DB1516.loc[DB1516['Players'].str.split().str.len() == 1, 'FirstInitial'] = DB1516['Players'].astype(str).str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 1, 'Firstname'] = DB1516['Players'].str.split().str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 1, 'Surname'] = DB1516['Players'].str.split().str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 2, 'FirstInitial'] = DB1516['Players'].astype(str).str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 2, 'Firstname'] = DB1516['Players'].str.split().str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 2, 'Surname'] = DB1516['Players'].str.split().str[-1]
DB1516.loc[DB1516['Players'].str.split().str.len() == 3, 'FirstInitial'] = DB1516['Players'].astype(str).str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 3, 'Firstname'] = DB1516['Players'].str.split().str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 3, 'Surname'] = DB1516['Players'].str.split().str[-1]
DB1516.loc[DB1516['Players'].str.split().str.len() == 4, 'FirstInitial'] = DB1516['Players'].astype(str).str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 4, 'Firstname'] = DB1516['Players'].str.split().str[0]
DB1516.loc[DB1516['Players'].str.split().str.len() == 4, 'Surname'] = DB1516['Players'].str.split().str[-1]

DB1415.loc[DB1415['Players'].str.split().str.len() == 1, 'FirstInitial'] = DB1415['Players'].astype(str).str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 1, 'Firstname'] = DB1415['Players'].str.split().str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 1, 'Surname'] = DB1415['Players'].str.split().str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 2, 'FirstInitial'] = DB1415['Players'].astype(str).str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 2, 'Firstname'] = DB1415['Players'].str.split().str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 2, 'Surname'] = DB1415['Players'].str.split().str[-1]
DB1415.loc[DB1415['Players'].str.split().str.len() == 3, 'FirstInitial'] = DB1415['Players'].astype(str).str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 3, 'Firstname'] = DB1415['Players'].str.split().str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 3, 'Surname'] = DB1415['Players'].str.split().str[-1]
DB1415.loc[DB1415['Players'].str.split().str.len() == 4, 'FirstInitial'] = DB1415['Players'].astype(str).str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 4, 'Firstname'] = DB1415['Players'].str.split().str[0]
DB1415.loc[DB1415['Players'].str.split().str.len() == 4, 'Surname'] = DB1415['Players'].str.split().str[-1]

DB1314.loc[DB1314['Players'].str.split().str.len() == 1, 'FirstInitial'] = DB1314['Players'].astype(str).str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 1, 'Firstname'] = DB1314['Players'].str.split().str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 1, 'Surname'] = DB1314['Players'].str.split().str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 2, 'FirstInitial'] = DB1314['Players'].astype(str).str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 2, 'Firstname'] = DB1314['Players'].str.split().str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 2, 'Surname'] = DB1314['Players'].str.split().str[-1]
DB1314.loc[DB1314['Players'].str.split().str.len() == 3, 'FirstInitial'] = DB1314['Players'].astype(str).str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 3, 'Firstname'] = DB1314['Players'].str.split().str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 3, 'Surname'] = DB1314['Players'].str.split().str[-1]
DB1314.loc[DB1314['Players'].str.split().str.len() == 4, 'FirstInitial'] = DB1314['Players'].astype(str).str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 4, 'Firstname'] = DB1314['Players'].str.split().str[0]
DB1314.loc[DB1314['Players'].str.split().str.len() == 4, 'Surname'] = DB1314['Players'].str.split().str[-1]

DB1213.loc[DB1213['Players'].str.split().str.len() == 1, 'FirstInitial'] = DB1213['Players'].astype(str).str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 1, 'Firstname'] = DB1213['Players'].str.split().str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 1, 'Surname'] = DB1213['Players'].str.split().str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 2, 'FirstInitial'] = DB1213['Players'].astype(str).str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 2, 'Firstname'] = DB1213['Players'].str.split().str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 2, 'Surname'] = DB1213['Players'].str.split().str[-1]
DB1213.loc[DB1213['Players'].str.split().str.len() == 3, 'FirstInitial'] = DB1213['Players'].astype(str).str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 3, 'Firstname'] = DB1213['Players'].str.split().str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 3, 'Surname'] = DB1213['Players'].str.split().str[-1]
DB1213.loc[DB1213['Players'].str.split().str.len() == 4, 'FirstInitial'] = DB1213['Players'].astype(str).str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 4, 'Firstname'] = DB1213['Players'].str.split().str[0]
DB1213.loc[DB1213['Players'].str.split().str.len() == 4, 'Surname'] = DB1213['Players'].str.split().str[-1]

# %%
DB1617.head(5)
# Out:
#           Players  Points  Clubs    Position  Start  Goals   A CS CS part  \
# 0      Harry Kane     220  SPURS     Forward     29     29   7  -       -
# 1  Alexis Sanchez     219   ARSL     Forward     36     24  11  -       -
# 2   Romelu Lukaku     213   EVER     Forward     36     25   6  -       -
# 3     Diego Costa     179   CHEL     Forward     35     20   7  -       -
# 4       Dele Alli     179  SPURS  Midfielder     35     18   7  -       -
#
#    Yellow   ...     CO  Off  Pen SV  Pen M Goals conceded  Conceded 1+ OG  \
# 0       3   ...      1   16       -      1              -            -  0
# 1       6   ...      2    8       -      1              -            -  0
# 2       3   ...      1    2       -      0              -            -  0
# 3      10   ...      0    8       -      1              -            -  0
# 4       4   ...      2   13       -      0              -            -  0
#
#   FirstInitial  Firstname  Surname
# 0            H      Harry     Kane
# ...

# %%
DB1617.set_index(['Surname','FirstInitial'])

DB1516.set_index(['Surname','FirstInitial'])

DB1415.set_index(['Surname','FirstInitial'])

DB1314.set_index(['Surname','FirstInitial'])

DB1213.set_index(['Surname','FirstInitial'])
# Out:
#                                       Players  Points   Clubs    Position  \
# Surname      FirstInitial
# Persie       R               Robin van Persie     225    MUFC     Forward
# Suarez       L                    Luis Suarez     186   LPOOL     Forward
# Bale         G                    Gareth Bale     180   SPURS  Midfielder
# Benteke      C              Christian Benteke     165  AVILLA     Forward
# Cazorla      S                  Santi Cazorla     164    ARSL  Midfielder
# Mata         J                      Juan Mata     162    CHEL  Midfielder
# Lambert      R                  Ricky Lambert     161   SOTOM     Forward
# Michu        M                          Michu     160    SWAN     Forward
# Walcott      T                   Theo Walcott     150    ARSL     Forward
# Berbatov     D               Dimitar Berbatov     148    MUFC     Forward
# Lukaku       R                  Romelu Lukaku     147    WBFC     Forward
# ...

# %%
DB1213[DB1213['Surname'].str.contains('')]
# Out:
#                  Players  Points   Clubs    Position  Start  Goals   A  CS  \
# 0       Robin van Persie     225    MUFC     Forward     35     26  10   -
# 1            Luis Suarez     186   LPOOL     Forward     33     23   5   -
# 2            Gareth Bale     180   SPURS  Midfielder     33     21   6   -
# 3      Christian Benteke     165  AVILLA     Forward     32     19   4   -
# 4          Santi Cazorla     164    ARSL  Midfielder     37     12  10   -
# 5              Juan Mata     162    CHEL  Midfielder     31     12  13   -
# 6          Ricky Lambert     161   SOTOM     Forward     35     15   5   -
# 7                  Michu     160    SWAN     Forward     35     18   2   -
# 8           Theo Walcott     150    ARSL     Forward     24     14   9   -
# 9       Dimitar Berbatov     148    MUFC     Forward     32     15   3   -
# 10         Romelu Lukaku     147    WBFC     Forward     20     17   4   -
# ...

# %%
DB1617.isnull().sum()
# Out:
# Players             0
# Points              0
# Clubs             333
# Position            0
# Start               0
# Goals               0
# A                   0
# CS                  0
# CS part             0
# Yellow              0
# Red                 0
# Sub                 0
# CO                  0
# Off                 0
# Pen SV              0
# Pen M               0
# Goals conceded      0
# Conceded 1+         0
# OG                  0
# FirstInitial        0
# Firstname           0
# Surname             0
# dtype: int64

# %%
DashColumns = ['Goals','A','CS','CS part','Yellow','Red','Sub','CO','Off','Pen SV','Pen M','Goals conceded','Conceded 1+','OG',]

DB1617[DashColumns] = DB1617[DashColumns].replace('-' ,'0')

DB1516[DashColumns] = DB1516[DashColumns].replace('-' ,'0')

DB1415[DashColumns] = DB1415[DashColumns].replace('-' ,'0')

DB1314[DashColumns] = DB1314[DashColumns].replace('-' ,'0')

DB1213[DashColumns] = DB1213[DashColumns].replace('-' ,'0')

# %%
DB1617['CS'] = DB1617['CS'].str.replace('%','').astype(np.int)
DB1617['CS part'] = DB1617['CS part'].str.replace('%','').astype(np.int)
DB1617['Pen SV'] = DB1617['Pen SV'].str.replace('%','').astype(np.int)
DB1617['Goals conceded'] = DB1617['Goals conceded'].str.replace('%','').astype(np.int)
DB1617['Conceded 1+'] = DB1617['Conceded 1+'].str.replace('%','').astype(np.int)

DB1516['CS'] = DB1516['CS'].str.replace('%','').astype(np.int)
DB1516['CS part'] = DB1516['CS part'].str.replace('%','').astype(np.int)
DB1516['Pen SV'] = DB1516['Pen SV'].str.replace('%','').astype(np.int)
DB1516['Goals conceded'] = DB1516['Goals conceded'].str.replace('%','').astype(np.int)
DB1516['Conceded 1+'] = DB1516['Conceded 1+'].str.replace('%','').astype(np.int)

DB1415['CS'] = DB1415['CS'].str.replace('%','').astype(np.int)
DB1415['CS part'] = DB1415['CS part'].str.replace('%','').astype(np.int)
DB1415['Pen SV'] = DB1415['Pen SV'].str.replace('%','').astype(np.int)
DB1415['Goals conceded'] = DB1415['Goals conceded'].str.replace('%','').astype(np.int)
DB1415['Conceded 1+'] = DB1415['Conceded 1+'].str.replace('%','').astype(np.int)

DB1314['CS'] = DB1314['CS'].str.replace('%','').astype(np.int)
DB1314['CS part'] = DB1314['CS part'].str.replace('%','').astype(np.int)
DB1314['Pen SV'] = DB1314['Pen SV'].str.replace('%','').astype(np.int)
DB1314['Goals conceded'] = DB1314['Goals conceded'].str.replace('%','').astype(np.int)
DB1314['Conceded 1+'] = DB1314['Conceded 1+'].str.replace('%','').astype(np.int)

DB1213['CS'] = DB1213['CS'].str.replace('%','').astype(np.int)
DB1213['CS part'] = DB1213['CS part'].str.replace('%','').astype(np.int)
DB1213['Pen SV'] = DB1213['Pen SV'].str.replace('%','').astype(np.int)
DB1213['Goals conceded'] = DB1213['Goals conceded'].str.replace('%','').astype(np.int)
DB1213['Conceded 1+'] = DB1213['Conceded 1+'].str.replace('%','').astype(np.int)

# %%
DB1617.to_csv('FANTASY1617DS.csv')

DB1516.to_csv('FANTASY1516DS.csv')

DB1415.to_csv('FANTASY1415DS.csv')

DB1314.to_csv('FANTASY1314DS.csv')

DB1213.to_csv('FANTASY1213DS.csv')
